':'OFF','MSICU16_RS':'OFF','MSICU16_ST':'OFF','MSICU18_IT':'OFF','MSICU18_RS':'OFF','MSICU18_ST':'OFF','MSICU19_IT':'OFF','MSICU19_RS':'OFF','MSICU19_ST':'OFF','MSICU21_IT':'OFF','MSICU21_RS':'OFF','MSICU21_ST':'OFF','MSICU22_IT':'OFF','MSICU22_RS':'OFF','MSICU22_ST':'OFF','MSICU26_IT':'ON','MSICU26_RS':'ON','MSICU26_ST':'ON','MSICU28_IT':'OFF','MSICU28_RS':'OFF','MSICU28_ST':'OFF','MSICU29_IT':'OFF','MSICU29_RS':'OFF','MSICU29_ST':'OFF','MSICU30_IT':'OFF','MSICU30_RS':'OFF','MSICU30_ST':'OFF','NETICU01sedoff_IT':'ON','NETICU01sedoff_RS':'ON','NETICU01sedoff_ST':'ON','NETICU01sedon1_IT':'ON','NETICU01sedon1_RS':'ON','NETICU01sedon1_ST':'ON','NETICU02sedoff_IT':'OFF','NETICU02sedoff_RS':'OFF','NETICU02sedoff_ST':'OFF','NETICU02sedon1_IT':'ON','NETICU02sedon1_RS':'ON','NETICU02sedon1_ST':'ON','NETICU03sedoff_IT':'OFF','NETICU03sedoff_RS':'OFF','NETICU03sedoff_ST':'OFF','NETICU03sedon1_IT':'ON','NETICU03sedon1_RS':'ON','NETICU03sedon1_ST':'ON','NETICU04sedoff_IT':'OFF','NETICU04sedoff_RS':'OFF','NETICU04sedoff_ST':'OFF','NETICU04sedon1_IT':'ON','NETICU04sedon1_RS':'ON','NETICU04sedon1_ST':'ON','NETICU05sedoff_IT':'OFF','NETICU05sedoff_RS':'OFF','NETICU05sedoff_ST':'OFF','NETICU05sedon1_IT':'ON','NETICU05sedon1_RS':'ON','NETICU05sedon1_ST':'ON','NETICU06sedoff_IT':'OFF','NETICU06sedoff_RS':'OFF','NETICU06sedoff_ST':'OFF','NETICU06sedon1_IT':'ON','NETICU06sedon1_RS':'ON','NETICU06sedon1_ST':'ON','NETICU08sedoff_IT':'OFF','NETICU08sedoff_ST':'OFF','NETICU08sedon2_IT':'ON','NETICU08sedon2_RS':'ON','NETICU08sedon2_ST':'ON','NETICU11sedoff_IT':'OFF','NETICU11sedoff_RS':'OFF','NETICU11sedoff_ST':'OFF','NETICU11sedon1_IT':'ON','NETICU11sedon1_RS':'ON','NETICU11sedon1_ST':'ON','NETICU13sedoff_IT':'OFF','NETICU13sedoff_RS':'OFF','NETICU13sedoff_ST':'OFF','NETICU13sedon1_IT':'ON','NETICU13sedon1_RS':'ON','NETICU13sedon1_ST':'ON','NETICU15sedoff_IT':'OFF','NETICU15sedoff_RS':'OFF','NETICU15sedoff_ST':'OFF','NETICU15sedon1_IT':'ON','NETICU15sedon1_RS':'ON','NETICU15sedon1_ST':'ON','NETICU17sedoff_IT':'OFF','NETICU17sedoff_RS':'OFF','NETICU17sedoff_ST':'OFF','NETICU17sedon1_IT':'ON','NETICU17sedon1_RS':'ON','NETICU17sedon1_ST':'ON','NETICU18sedoff_RS':'OFF','NETICU18sedon1_IT':'ON','
', 'NETICU05sedon1_IT': '1', 'NETICU05sedon1_RS': '1', 'NETICU05sedon1_ST': '1', 'NETICU06sedoff_IT': '0', 'NETICU06sedoff_RS': '0', 'NETICU06sedoff_ST': '0', 'NETICU06sedon1_IT': '0', 'NETICU06sedon1_RS': '0', 'NETICU06sedon1_ST': '0', 'NETICU08sedoff_IT': '1', 'NETICU08sedoff_ST': '1', 'NETICU08sedon2_IT': '1', 'NETICU08sedon2_RS': '1', 'NETICU08sedon2_ST': '1', 'NETICU11sedoff_IT': '1', 'NETICU11sedoff_RS': '1', 'NETICU11sedoff_ST': '1', 'NETICU11sedon1_IT': '1', 'NETICU11sedon1_RS': '1', 'NETICU11sedon1_ST': '1', 'NETICU13sedoff_IT': '0', 'NETICU13sedoff_RS': '0', 'NETICU13sedoff_ST': '0', 'NETICU13sedon1_IT': '0', 'NETICU13sedon1_RS': '0', 'NETICU13sedon1_ST': '0', 'NETICU15sedoff_IT': '0', 'NETICU15sedoff_RS': '0', 'NETICU15sedoff_ST': '0', 'NETICU15sedon1_IT': '0', 'NETICU15sedon1_RS': '0', 'NETICU15sedon1_ST': '0', 'NETICU17sedoff_IT': '1', 'NETICU17sedoff_RS': '1', 'NETICU17sedoff_ST': '1', 'NETICU17sedon1_IT': '1', 'NETICU17sedon1_RS': '1', 'NETICU17sedon1_ST': '1', 'NETICU18sedoff_RS': '1', 'NETICU18sedon1_IT': '1', 'NETICU18sedon1_RS': '1', 'NETICU18sedon1_ST': '1', 'NETICU19sedoff_IT': '1', 'NETICU19sedoff_RS': '1', 'NETICU19sedoff_ST': '1', 'NETICU19sedon1_IT': '1', 'NETICU19sedon1_RS': '1', 'NETICU19sedon1_ST': '1', 'NETICU20sedoff_RS': '1', 'NETICU20sedon1_IT': '1', 'NETICU20sedon1_RS': '1', 'NETICU20sedon1_ST': '1', 'NETICU22sedoff_IT': '0', 'NETICU22sedoff_RS': '0', 'NETICU22sedoff_ST': '0', 'NETICU22sedon1_IT': '0', 'NETICU22sedon1_RS': '0', 'NETICU22sedon1_ST': '0', 'NETICU24sedoff_IT': '0', 'NETICU24sedoff_RS': '0', 'NETICU24sedoff_ST': '0', 'NETICU24sedon1_IT': '0', 'NETICU24sedon1_RS': '0', 'NETICU24sedon1_ST': '0', 'NETICU25sedoff_RS': '0', 'NETICU25sedon1_IT': '0', 'NETICU25sedon1_RS': '0', 'NETICU25sedon1_ST': '0', 'NETICU27sedoff_IT': '1', 'NETICU27sedoff_RS': '1', 'NETICU27sedoff_ST': '1', 'NETICU27sedon1_IT': '1', 'NETICU27sedon1_RS': '1', 'NETICU27sedon1_ST': '1', 'NETICU28sedoff_IT': '0', 'NETICU28sedoff_RS': '0', 'NETICU28sedoff_ST': '0', 'NETICU28sedon1_IT': '0', 'NETICU28sedon1_RS': '0', 'NETICU28sedon1_ST': '0', 'NETICU29sedoff_IT': '1', 'NETICU29sedoff_RS': '1', 'NETICU29sedoff_ST': '1', 'NETICU29sedon1_IT': '1', 'NETICU29sedon1_RS': '1', 'NETIC
'OFF', 'NETICU04sedoff_RS': 'OFF', 'NETICU04sedoff_ST': 'OFF', 'NETICU04sedon1_IT': 'ON', 'NETICU04sedon1_RS': 'ON', 'NETICU04sedon1_ST': 'ON', 'NETICU05sedoff_IT': 'OFF', 'NETICU05sedoff_RS': 'OFF', 'NETICU05sedoff_ST': 'OFF', 'NETICU05sedon1_IT': 'ON', 'NETICU05sedon1_RS': 'ON', 'NETICU05sedon1_ST': 'ON', 'NETICU06sedoff_IT': 'OFF', 'NETICU06sedoff_RS': 'OFF', 'NETICU06sedoff_ST': 'OFF', 'NETICU06sedon1_IT': 'ON', 'NETICU06sedon1_RS': 'ON', 'NETICU06sedon1_ST': 'ON', 'NETICU08sedoff_IT': 'OFF', 'NETICU08sedoff_ST': 'OFF', 'NETICU08sedon2_IT': 'ON', 'NETICU08sedon2_RS': 'ON', 'NETICU08sedon2_ST': 'ON', 'NETICU11sedoff_IT': 'OFF', 'NETICU11sedoff_RS': 'OFF', 'NETICU11sedoff_ST': 'OFF', 'NETICU11sedon1_IT': 'ON', 'NETICU11sedon1_RS': 'ON', 'NETICU11sedon1_ST': 'ON', 'NETICU13sedoff_IT': 'OFF', 'NETICU13sedoff_RS': 'OFF', 'NETICU13sedoff_ST': 'OFF', 'NETICU13sedon1_IT': 'ON', 'NETICU13sedon1_RS': 'ON', 'NETICU13sedon1_ST': 'ON', 'NETICU15sedoff_IT': 'OFF', 'NETICU15sedoff_RS': 'OFF', 'NETICU15sedoff_ST': 'OFF', 'NETICU15sedon1_IT': 'ON', 'NETICU15sedon1_RS': 'ON', 'NETICU15sedon1_ST': 'ON', 'NETICU17sedoff_IT': 'OFF', 'NETICU17sedoff_RS': 'OFF', 'NETICU17sedoff_ST': 'OFF', 'NETICU17sedon1_IT': 'ON', 'NETICU17sedon1_RS': 'ON', 'NETICU17sedon1_ST': 'ON', 'NETICU18sedoff_RS': 'OFF', 'NETICU18sedon1_IT': 'ON', 'NETICU18sedon1_RS': 'ON', 'NETICU18sedon1_ST': 'ON', 'NETICU19sedoff_IT': 'OFF', 'NETICU19sedoff_RS': 'OFF', 'NETICU19sedoff_ST': 'OFF', 'NETICU19sedon1_IT': 'ON', 'NETICU19sedon1_RS': 'ON', 'NETICU19sedon1_ST': 'ON', 'NETICU20sedoff_RS': 'OFF', 'NETICU20sedon1_IT': 'ON', 'NETICU20sedon1_RS': 'ON', 'NETICU20sedon1_ST': 'ON', 'NETICU22sedoff_IT': 'OFF', 'NETICU22sedoff_RS': 'OFF', 'NETICU22sedoff_ST': 'OFF', 'NETICU22sedon1_IT': 'ON', 'NETICU22sedon1_RS': 'ON', 'NETICU22sedon1_ST': 'ON', 'NETICU24sedoff_IT': 'OFF', 'NETICU24sedoff_RS': 'OFF', 'NETICU24sedoff_ST': 'OFF', 'NETICU24sedon1_IT': 'ON', 'NETICU24sedon1_RS': 'ON', 'NETICU24sedon1_ST': 'ON', 'NETICU25sedoff_RS': 'OFF', 'NETICU25sedon1_IT': 'ON', 'NETICU25sedon1_RS': 'ON', 'NETICU25sedon1_ST': 'ON', 'NETICU27sedoff_IT': 'OFF', 'NETICU27sedoff_RS': 'OFF', 'NETICU27sedoff_ST': 'OFF', 'NETICU27sedon1_IT': 'ON', 'NETICU27sedon1_RS': 'ON', 'NETICU27sedon1_ST': 'ON', 'NETICU28sedoff_IT': 'OFF', 'NETICU28sedoff_RS': 'OFF', 'NETICU28sedoff_ST': 'OFF', 'NETICU28sedon1_IT': 'ON', 'NETICU28sedon1_RS': 'ON', 'NETICU28sedon1_ST': 'ON', 'NETICU29sedoff_IT': 'OFF', 'NETICU29sedoff_RS': 'OFF', 'NETICU29sedoff_ST': 'OFF', 'NETICU29sedon1_IT': 'ON', 'NETICU29sedon1_RS': 'ON', 'NETICU29sedon1_ST': 'ON', 'NETICU30sedoff_IT': 'OFF', 'NETICU30sedoff_RS': 'OFF', 'NETICU30sedoff_ST': 'OFF', 'NETICU30sedon1_IT': 'ON', 'NETICU30sedon1_RS': 'ON', 'NETICU30sedon1_ST': 'ON', 'NETICU31sedoff_IT': 'OFF', 'NETICU31sedoff_RS': 'OFF', 'NETICU31sedoff_ST': 'OFF', 'NETICU31sedon1_IT': 'ON', 'NETICU31sedon1_ST': 'ON', 'NETICU31sedon2_RS': 'ON', 'NETICU33sedoff_RS': 'OFF', 'NETICU33sedon1_IT': 'ON', 'NETICU33sedon1_RS': 'ON', 'NETICU33sedon1_ST': 'ON', 'NETICU38sedon1_IT': 'ON', 'NETICU38sedon1_RS': 'ON', 'NETICU38sedon1_ST': 'ON', 'NETICU40sedoff_IT': 'OFF', 'NETICU40sedoff_RS': 'OFF', 'NETICU40sedoff_ST': 'OFF', 'NETICU40sedon1_IT': 'ON', 'NETICU40sedon1_RS': 'ON', 'NETICU40sedon1_ST': 'ON', 'NETICU41sedoff_IT': 'OFF', 'NETICU41sedoff_RS': 'OFF', 'NETICU41sedoff_ST': 'OFF', 'NETICU41sedon1_IT': 'ON', 'NETICU41sedon1_RS': 'ON', 'NETICU41sedon1_ST': 'ON', 'NETICU41sedon2_IT': 'ON', 'NETICU41sedon2_RS': 'ON', 'NETICU41sedon2_ST': 'ON', 'NETICU46sedoff_RS': 'OFF', 'NETICU46sedon1_IT': 'ON', 'NETICU46sedon1_RS': 'ON', 'NETICU46sedon1_ST': 'ON'}
GCSdic={'CCTC03_IT': '3', 'CCTC03_RS': '3', 'CCTC03_ST': '3', 'CCTC03part2_IT': '3', 'CCTC03part2_RS': '3', 'CCTC03part2_ST': '3', 'CCTC04_IT': '3', 'CCTC04_RS': '3', 'CCTC04_RSredo': '3', 'CCTC04_ST': '3', 'CCTC05_IT': '3', 'CCTC05_RS': '3', 'CCTC05_ST': '3', 'CCTC07NETICUsedoff_IT': '7', 'CCTC07NETICUsedoff_RS': '7', 'CCTC07NETICUsedoff_ST': '7', 'CCTC07NETICUsedon1_IT': '4', 'CCTC07NETICUsedon1_RS': '4', 'CCTC07NETICUsedon1_ST': '4', 'CCTC07_IT': '5', 'CCTC07_RS': '5', 'CCTC07_ST': '5',
sedoff_ST': '10', 'NETICU02sedon1_IT': '3', 'NETICU02sedon1_RS': '3', 'NETICU02sedon1_ST': '3', 'NETICU03sedoff_IT': '6', 'NETICU03sedoff_RS': '6', 'NETICU03sedoff_ST': '6', 'NETICU03sedon1_IT': '6', 'NETICU03sedon1_RS': '6', 'NETICU03sedon1_ST': '6', 'NETICU04sedoff_IT': '3', 'NETICU04sedoff_RS': '3', 'NETICU04sedoff_ST': '3', 'NETICU04sedon1_IT': '3', 'NETICU04sedon1_RS': '3', 'NETICU04sedon1_ST': '3', 'NETICU05sedoff_IT': '3', 'NETICU05sedoff_RS': '3', 'NETICU05sedoff_ST': '3', 'NETICU05sedon1_IT': '3', 'NETICU05sedon1_RS': '3', 'NETICU05sedon1_ST': '3', 'NETICU06sedoff_IT': '6', 'NETICU06sedoff_RS': '6', 'NETICU06sedoff_ST': '6', 'NETICU06sedon1_IT': '3', 'NETICU06sedon1_RS': '3', 'NETICU06sedon1_ST': '3', 'NETICU08sedoff_IT': '9', 'NETICU08sedoff_ST': '9', 'NETICU08sedon2_IT': '3', 'NETICU08sedon2_RS': '3', 'NETICU08sedon2_ST': '3', 'NETICU11sedoff_IT': '4', 'NETICU11sedoff_RS': '4', 'NETICU11sedoff_ST': '4', 'NETICU11sedon1_IT': '3', 'NETICU11sedon1_RS': '3', 'NETICU11sedon1_ST': '3', 'NETICU13sedoff_IT': '4', 'NETICU13sedoff_RS': '4', 'NETICU13sedoff_ST': '4', 'NETICU13sedon1_IT': '3', 'NETICU13sedon1_RS': '3', 'NETICU13sedon1_ST': '3', 'NETICU15sedoff_IT': '3', 'NETICU15sedoff_RS': '3', 'NETICU15sedoff_ST': '3', 'NETICU15sedon1_IT': '3', 'NETICU15sedon1_RS': '3', 'NETICU15sedon1_ST': '3', 'NETICU17sedoff_IT': '10', 'NETICU17sedoff_RS': '10', 'NETICU17sedoff_ST': '10', 'NETICU17sedon1_IT': '3', 'NETICU17sedon1_RS': '3', 'NETICU17sedon1_ST': '3', 'NETICU18sedoff_RS': '11', 'NETICU18sedon1_IT': '3', 'NETICU18sedon1_RS': '3', 'NETICU18sedon1_ST': '3', 'NETICU19sedoff_IT': '7', 'NETICU19sedoff_RS': '7', 'NETICU19sedoff_ST': '7', 'NETICU19sedon1_IT': '3', 'NETICU19sedon1_RS': '3', 'NETICU19sedon1_ST': '3', 'NETICU20sedoff_RS': '11', 'NETICU20sedon1_IT': '3', 'NETICU20sedon1_RS': '3', 'NETICU20sedon1_ST': '3', 'NETICU22sedoff_IT': '3', 'NETICU22sedoff_RS': '3', 'NETICU22sedoff_ST': '3', 'NETICU22sedon1_IT': '3', 'NETICU22sedon1_RS': '3', 'NETICU22sedon1_ST': '3', 'NETICU24sedoff_IT': '3', 'NETICU24sedoff_RS': '3', 'NETICU24sedoff_ST': '3', 'NETICU24sedon1_IT': '3', 'NETICU24sedon1_RS': '3', 'NETICU24sedon1_ST': '3', 'NETICU25sedoff_RS': '8', 'NETICU25sedon1_IT': '6', 'NETICU25sedon1_RS': '6', 'NETICU25sedon1_ST': '6', 'NETICU27sedoff_IT': '3', 'NETICU27sedoff_RS': '3', 'NETICU27sedoff_ST': '3', 'NETICU27sedon1_IT': '3', 'NETICU27sedon1_RS': '3', 'NETICU27sedon1_ST': '3', 'NETICU28sedoff_IT': '3', 'NETICU28sedoff_RS': '3', 'NETICU28sedoff_ST': '3', 'NETICU28sedon1_IT': '3', 'NETICU28sedon1_RS': '3', 'NETICU28sedon1_ST': '3', 'NETICU29sedoff_IT': '11', 'NETICU29sedoff_RS': '11', 'NETICU29sedoff_ST': '11', 'NETICU29sedon1_IT': '3', 'NETICU29sedon1_RS': '3', 'NETICU29sedon1_ST': '3', 'NETICU30sedoff_IT': '6', 'NETICU30sedoff_RS': '6', 'NETICU30sedoff_ST': '6', 'NETICU30sedon1_IT': '3', 'NETICU30sedon1_RS': '3', 'NETICU30sedon1_ST': '3', 'NETICU31sedoff_IT': '10', 'NETICU31sedoff_RS': '10', 'NETICU31sedoff_ST': '10', 'NETICU31sedon1_IT': '3', 'NETICU31sedon1_ST': '3', 'NETICU31sedon2_RS': '6', 'NETICU33sedoff_RS': '5', 'NETICU33sedon1_IT': '3', 'NETICU33sedon1_RS': '3', 'NETICU33sedon1_ST': '3', 'NETICU38sedon1_IT': '3', 'NETICU38sedon1_RS': '3', 'NETICU38sedon1_ST': '3', 'NETICU40sedoff_IT': '9', 'NETICU40sedoff_RS': '9', 'NETICU40sedoff_ST': '9', 'NETICU40sedon1_IT': '3', 'NETICU40sedon1_RS': '3', 'NETICU40sedon1_ST': '3', 'NETICU41sedoff_IT': '3', 'NETICU41sedoff_RS': '3', 'NETICU41sedoff_ST': '3', 'NETICU41sedon1_IT': '3', 'NETICU41sedon1_RS': '3', 'NETICU41sedon1_ST': '3', 'NETICU41sedon2_IT': '3', 'NETICU41sedon2_RS': '3', 'NETICU41sedon2_ST': '3', 'NETICU46sedoff_RS': '8', 'NETICU46sedon1_IT': '3', 'NETICU46sedon1_RS': '3', 'NETICU46sedon1_ST': '3'}
######################################################################################################################

# %% [markdown]
# # PART 1: Machine Learning for HC

# %% [markdown]
# # to do
# [] all figurures done
# []  all figure legends done
# [] finanasse

# %%
## updated NEWDATA
#################

#MAX's way
#####################################################################################################################    
##                                                                                                                 ##
##                 LOADING DATAFRAME & RESHAPING IT    +  NEW DICTIONARIES                                         ## 
##################################################################################################################### 
import string
measures = ['LZc','svd1','approx','sample','detrended','katz','ll','mswpen','bubben','cwpen']
Echan=['E2','E3','E4','E5','E6','E7','E9','E10','E11','E12','E13','E15','E16','E18','E19','E20','E22','E23','E24','E26','E27','E28','E29','E30','E31','E33','E34','E35','E36','E37','E39','E40','E41','E42','E45','E46','E47','E50','E51','E52','E53','E54','E55','E58','E59','E60','E61','E62','E65','E66','E67','E70','E71','E72','E75','E76','E77','E78','E79','E80','E83','E84','E85','E86','E87','E90','E91','E92','E93','E96','E97','E98','E101','E102','E103','E104','E105','E106','E108','E109','E110','E111','E112','E115','E116','E117','E118','E122','E123','E124','Vertex Reference']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
ETICU13sedon1_RS': '0', 'NETICU13sedon1_ST': '0', 'NETICU15sedoff_IT': '0', 'NETICU15sedoff_RS': '0', 'NETICU15sedoff_ST': '0', 'NETICU15sedon1_IT': '0', 'NETICU15sedon1_RS': '0', 'NETICU15sedon1_ST': '0', 'NETICU17sedoff_IT': '1', 'NETICU17sedoff_RS': '1', 'NETICU17sedoff_ST': '1', 'NETICU17sedon1_IT': '1', 'NETICU17sedon1_RS': '1', 'NETICU17sedon1_ST': '1', 'NETICU18sedoff_RS': '1', 'NETICU18sedon1_IT': '1', 'NETICU18sedon1_RS': '1', 'NETICU18sedon1_ST': '1', 'NETICU19sedoff_IT': '1', 'NETICU19sedoff_RS': '1', 'NETICU19sedoff_ST': '1', 'NETICU19sedon1_IT': '1', 'NETICU19sedon1_RS': '1', 'NETICU19sedon1_ST': '1', 'NETICU20sedoff_RS': '1', 'NETICU20sedon1_IT': '1', 'NETICU20sedon1_RS': '1', 'NETICU20sedon1_ST': '1', 'NETICU22sedoff_IT': '0', 'NETICU22sedoff_RS': '0', 'NETICU22sedoff_ST': '0', 'NETICU22sedon1_IT': '0', 'NETICU22sedon1_RS': '0', 'NETICU22sedon1_ST': '0', 'NETICU24sedoff_IT': '0', 'NETICU24sedoff_RS': '0', 'NETICU24sedoff_ST': '0', 'NETICU24sedon1_IT': '0', 'NETICU24sedon1_RS': '0', 'NETICU24sedon1_ST': '0', 'NETICU25sedoff_RS': '0', 'NETICU25sedon1_IT': '0', 'NETICU25sedon1_RS': '0', 'NETICU25sedon1_ST': '0', 'NETICU27sedoff_IT': '1', 'NETICU27sedoff_RS': '1', 'NETICU27sedoff_ST': '1', 'NETICU27sedon1_IT': '1', 'NETICU27sedon1_RS': '1', 'NETICU27sedon1_ST': '1', 'NETICU28sedoff_IT': '0', 'NETICU28sedoff_RS': '0', 'NETICU28sedoff_ST': '0', 'NETICU28sedon1_IT': '0', 'NETICU28sedon1_RS': '0', 'NETICU28sedon1_ST': '0', 'NETICU29sedoff_IT': '1', 'NETICU29sedoff_RS': '1', 'NETICU29sedoff_ST': '1', 'NETICU29sedon1_IT': '1', 'NETICU29sedon1_RS': '1', 'NETICU29sedon1_ST': '1', 'NETICU30sedoff_IT': '0', 'NETICU30sedoff_RS': '0', 'NETICU30sedoff_ST': '0', 'NETICU30sedon1_IT': '0', 'NETICU30sedon1_RS': '0', 'NETICU30sedon1_ST': '0', 'NETICU31sedoff_IT': '1', 'NETICU31sedoff_RS': '1', 'NETICU31sedoff_ST': '1', 'NETICU31sedon1_IT': '1', 'NETICU31sedon1_ST': '1', 'NETICU31sedon2_RS': '1', 'NETICU33sedoff_RS': '0', 'NETICU33sedon1_IT': '0', 'NETICU33sedon1_RS': '0', 'NETICU33sedon1_ST': '0', 'NETICU38sedon1_IT': '0', 'NETICU38sedon1_RS': '0', 'NETICU38sedon1_ST': '0', 'NETICU40sedoff_IT': '0', 'NETICU40sedoff_RS': '0', 'NETICU40sedoff_ST': '0', 'NETICU40sedon1_IT': '0', 'NETICU40sed
NETICU30sedoff_ST': 'OFF', 'NETICU30sedon1_IT': 'ON', 'NETICU30sedon1_RS': 'ON', 'NETICU30sedon1_ST': 'ON', 'NETICU31sedoff_IT': 'OFF', 'NETICU31sedoff_RS': 'OFF', 'NETICU31sedoff_ST': 'OFF', 'NETICU31sedon1_IT': 'ON', 'NETICU31sedon1_ST': 'ON', 'NETICU31sedon2_RS': 'ON', 'NETICU33sedoff_RS': 'OFF', 'NETICU33sedon1_IT': 'ON', 'NETICU33sedon1_RS': 'ON', 'NETICU33sedon1_ST': 'ON', 'NETICU38sedon1_IT': 'ON', 'NETICU38sedon1_RS': 'ON', 'NETICU38sedon1_ST': 'ON', 'NETICU40sedoff_IT': 'OFF', 'NETICU40sedoff_RS': 'OFF', 'NETICU40sedoff_ST': 'OFF', 'NETICU40sedon1_IT': 'ON', 'NETICU40sedon1_RS': 'ON', 'NETICU40sedon1_ST': 'ON', 'NETICU41sedoff_IT': 'OFF', 'NETICU41sedoff_RS': 'OFF', 'NETICU41sedoff_ST': 'OFF', 'NETICU41sedon1_IT': 'ON', 'NETICU41sedon1_RS': 'ON', 'NETICU41sedon1_ST': 'ON', 'NETICU41sedon2_IT': 'ON', 'NETICU41sedon2_RS': 'ON', 'NETICU41sedon2_ST': 'ON', 'NETICU46sedoff_RS': 'OFF', 'NETICU46sedon1_IT': 'ON', 'NETICU46sedon1_RS': 'ON', 'NETICU46sedon1_ST': 'ON'}
GCSdic={'CCTC03_IT': '3', 'CCTC03_RS': '3', 'CCTC03_ST': '3', 'CCTC03part2_IT': '3', 'CCTC03part2_RS': '3', 'CCTC03part2_ST': '3', 'CCTC04_IT': '3', 'CCTC04_RS': '3', 'CCTC04_RSredo': '3', 'CCTC04_ST': '3', 'CCTC05_IT': '3', 'CCTC05_RS': '3', 'CCTC05_ST': '3', 'CCTC07NETICUsedoff_IT': '7', 'CCTC07NETICUsedoff_RS': '7', 'CCTC07NETICUsedoff_ST': '7', 'CCTC07NETICUsedon1_IT': '4', 'CCTC07NETICUsedon1_RS': '4', 'CCTC07NETICUsedon1_ST': '4', 'CCTC07_IT': '5', 'CCTC07_RS': '5', 'CCTC07_ST': '5', 'HC01_IT': '15', 'HC01_ST': '15', 'HC02_IT': '15', 'HC02_ST': '15', 'HC03_IT': '15', 'HC03_ST': '15', 'HC04_IT': '15', 'HC04_ST': '15', 'HC05_IT1st': '15', 'HC05_IT2nd': '15', 'HC05_ST': '15', 'HC06_IT': '15', 'HC06_ST': '15', 'HC07_IT': '15', 'HC07_ST': '15', 'HC08_IT': '15', 'HC08_ST': '15', 'HC09_IT': '15', 'HC09_ST': '15', 'HC10_IT': '15', 'HC10_ST': '15', 'HC11_IT': '15', 'HC11_ST': '15', 'HC12_IT': '15', 'HC12_ST': '15', 'HC13_IT': '15', 'HC13_ST': '15', 'HC14_IT': '15', 'HC14_ST': '15', 'HC15_IT': '15', 'HC15_ST': '15', 'HC16_IT': '15', 'HC16_ST': '15', 'HC17_IT': '15', 'HC17_ST': '15', 'HC18_IT': '15', 'HC18_ST': '15', 'MSICU05_IT': '3', 'MSICU05_RS': '3', 'MSICU05_ST': '3', 'MSICU05part2_IT': '15', 'MSICU05part2_RS': '15', 'MSICU05part2_ST': '15', 'MSICU07_IT': '3', 'MSICU07_RS': '3', 'MSICU07_ST': '3', 'MSICU09_IT': '5', 'MSICU09_RS': '5', 'MSICU09_ST': '5', 'MSICU09part2_IT': '4', 'MSICU09part2_RS': '4', 'MSICU09part2_ST': '4', 'MSICU10_IT': '4', 'MSICU10_RS': '4', 'MSICU10_ST': '4', 'MSICU14_IT': '3', 'MSICU14_RS': '3', 'MSICU14_ST': '3', 'MSICU15_IT': '6', 'MSICU15_RS': '6', 'MSICU15_ST': '6', 'MSICU16_IT': '3', 'MSICU16_RS': '3', 'MSICU16_ST': '3', 'MSICU18_IT': '7', 'MSICU18_RS': '7', 'MSICU18_ST': '7', 'MSICU19_IT': '8', 'MSICU19_RS': '8', 'MSICU19_ST': '8', 'MSICU21_IT': '9', 'MSICU21_RS': '9', 'MSICU21_ST': '9', 'MSICU22_IT': '4', 'MSICU22_RS': '4', 'MSICU22_ST': '4', 'MSICU26_IT': '7', 'MSICU26_RS': '7', 'MSICU26_ST': '7', 'MSICU28_IT': '6', 'MSICU28_RS': '6', 'MSICU28_ST': '6', 'MSICU29_IT': '9', 'MSICU29_RS': '9', 'MSICU29_ST': '9', 'MSICU30_IT': '5', 'MSICU30_RS': '5', 'MSICU30_ST': '5', 'MSICU32_IT': '3', 'MSICU32_RS': '3', 'MSICU32_ST': '3', 'MSICU38_IT': '5', 'MSICU38_RS': '5', 'MSICU38_ST': '5', 'MSICU42_IT': '6', 'MSICU42_RS': '6', 'MSICU42_ST': '6', 'MSICU43_IT': '9', 'MSICU43_RS': '9', 'MSICU43_ST': '9', 'MSICU47_IT': '6', 'MSICU47_RS': '6', 'MSICU47_ST': '6', 'NETICU01sedoff_IT': '3', 'NETICU01sedoff_RS': '3', 'NETICU01sedoff_ST': '3', 'NETICU01sedon1_IT': '3', 'NETICU01sedon1_RS': '3', 'NETICU01sedon1_ST': '3', 'NETICU02sedoff_IT': '10', 'NETICU02sedoff_RS': '10', 'NETICU02sedoff_ST': '10', 'NETICU02sedon1_IT': '3', 'NETICU02sedon1_RS': '3', 'NETICU02sedon1_ST': '3', 'NETICU03sedoff_IT': '6', 'NETICU03sedoff_RS': '6', 'NETICU03sedoff_ST': '6', 'NETICU03sedon1_IT': '6', 'NETICU03sedon1_RS': '6', 'NETICU03sedon1_ST': '6', 'NETICU04sedoff_IT': '3', 'NETICU04sedoff_RS': '3', 'NETICU04sedoff_ST': '3', 'NETICU04sedon1_IT': '3', 'NETICU04sedon1_RS': '3', 'NETICU04sedon1_ST': '3', 'NETICU05sedoff_IT': '3', 'NETICU05sedoff_RS': '3', 'NETICU05sedoff_ST': '3', 'NETICU05sedon1_IT': '3', 'NETICU05sedon1_RS': '3', 'NETICU05sedon1_ST': '3', 'NETICU06sedoff_IT': '6', 'NETICU06sedoff_RS': '6', 'NETICU06sedoff_ST': '6', 'NETICU06sedon1_IT': '3', 'NETICU06sedon1_RS': '3', 'NETICU06sedon1_ST': '3', 'NETICU08sedoff_IT': '9', 'NETICU08sedoff_ST': '9', 'NETICU08sedon2_IT': '3', 'NETICU08sedon2_RS': '3', 'NETICU08sedon2_ST': '3', 'NETICU11sedoff_IT': '4', 'NETICU11sedoff_RS': '4', 'NETICU11sedoff_ST': '4', 'NETICU11sedon1_IT': '3', 'NETICU11sedon1_RS': '3', 'NETICU11sedon1_ST': '3', 'NETICU13sedoff_IT': '4', 'NETICU13sedoff_RS': '4', 'NETICU13sedoff_ST': '4', 'NETICU13sedon1_IT': '3', 'NETICU13sedon1_RS': '3', 'NETICU13sedon1_ST': '3', 'NETICU15sedoff_IT': '3', 'NETICU15sedoff_RS': '3', 'NETICU15sedoff_ST': '3', 'NETICU15sedon1_IT': '3', 'NETICU15sedon1_RS': '3', 'NETICU15sedon1_ST': '3', 'NETICU17sedoff_IT': '10', 'NETICU17sedoff_RS': '10', 'NETICU17sedoff_ST': '10', 'NETICU17sedon1_IT': '3', 'NETICU17sedon1_RS': '3', 'NETICU17sedon1_ST': '3', 'NETICU18sedoff_RS': '11', 'NETICU18sedon1_IT': '3', 'NETICU18sedon1_RS': '3', 'NETICU18sedon1_ST': '3', 'NETICU19sedoff_IT': '7', 'NETICU19sedoff_RS': '7', 'NETICU19sedoff_ST': '7', 'NETICU19sedon1_IT': '3', 'NETICU19sedon1_RS': '3', 'NETICU19sedon1_ST': '3', 'NETICU20sedoff_RS': '11', 'NETICU20sedon1_IT': '3', 'NETICU20sedon1_RS': '3', 'NETICU20sedon1_ST': '3', 'NETICU22sedoff_IT': '3', 'NETICU22sedoff_RS': '3', 'NETICU22sedoff_ST': '3', 'NETICU22sedon1_IT': '3', 'NETICU22sedon1_RS': '3', 'NETICU22sedon1_ST': '3', 'NETICU24sedoff_IT': '3', 'NETICU24sedoff_RS': '3', 'NETICU24sedoff_ST': '3', 'NETICU24sedon1_IT': '3', 'NETICU24sedon1_RS': '3', 'NETICU24sedon1_ST': '3', 'NETICU25sedoff_RS': '8', 'NETICU25sedon1_IT': '6', 'NETICU25sedon1_RS': '6', 'NETICU25sedon1_ST': '6', 'NETICU27sedoff_IT': '3', 'NETICU27sedoff_RS': '3', 'NETICU27sedoff_ST': '3', 'NETICU27sedon1_IT': '3', 'NETICU27sedon1_RS': '3', 'NETICU27sedon1_ST': '3', 'NETICU28sedoff_IT': '3', 'NETICU28sedoff_RS': '3', 'NETICU28sedoff_ST': '3', 'NETICU28sedon1_IT': '3', 'NETICU28sedon1_RS': '3', 'NETICU28sedon1_ST': '3', 'NETICU29sedoff_IT': '11', 'NETICU29sedoff_RS': '11', 'NETICU29sedoff_ST': '11', 'NETICU29sedon1_IT': '3', 'NETICU29sedon1_RS': '3', 'NETICU29sedon1_ST': '3', 'NETICU30sedoff_IT': '6', 'NETICU30sedoff_RS': '6', 'NETICU30sedoff_ST': '6', 'NETICU30sedon1_IT': '3', 'NETICU30sedon1_RS': '3', 'NETICU30sedon1_ST': '3', 'NETICU31sedoff_IT': '10', 'NETICU31sedoff_RS': '10', 'NETICU31sedoff_ST': '10', 'NETICU31sedon1_IT': '3', 'NETICU31sedon1_ST': '3', 'NETICU31sedon2_RS': '6', 'NETICU33sedoff_RS': '5', 'NETICU33sedon1_IT': '3', 'NETICU33sedon1_RS': '3', 'NETICU33sedon1_ST': '3', 'NETICU38sedon1_IT': '3', 'NETICU38sedon1_RS': '3', 'NETICU38sedon1_ST': '3', 'NETICU40sedoff_IT': '9', 'NETICU40sedoff_RS': '9', 'NETICU40sedoff_ST': '9', 'NETICU40sedon1_IT': '3', 'NETICU40sedon1_RS': '3', 'NETICU40sedon1_ST': '3', 'NETICU41sedoff_IT': '3', 'NETICU41sedoff_RS': '3', 'NETICU41sedoff_ST': '3', 'NETICU41sedon1_IT': '3', 'NETICU41sedon1_RS': '3', 'NETICU41sedon1_ST': '3', 'NETICU41sedon2_IT': '3', 'NETICU41sedon2_RS': '3', 'NETICU41sedon2_ST': '3', 'NETICU46sedoff_RS': '8', 'NETICU46sedon1_IT': '3', 'NETICU46sedon1_RS': '3', 'NETICU46sedon1_ST': '3'}
######################################################################################################################


for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        vars()[m+'_'+window]= pd.read_csv(f'./results/NewDataResults/save/{window}/{m}/{m}_{window}.csv')
        vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
        vars()[m+'_'+window].set_index('ID', inplace=True)
        #------------------------------------------------------------------------------------------###
        df = vars()[m+'_'+window].copy()#                                                          ###
        ssfnames = [f for f in df.index if 'HC05_IT1st' not in f]#                                 ###
        #print(f'\n{m}_{window}\n{len(df.index)}-{len(ssfnames)} = {len(df.index)-len(ssfnames)}') ###
        #---------------------------------------######################################################
        df = df.loc[ssfnames] #using ssfnames   ###
        odf = df.copy()#old datafrmae           ###
        odf = odf[odf.index.str.contains('HC')] ###
        ###########################################
        IDlist=[]
        chaa=[]
        for f in odf.index:
            a,b,c = f.split('_')
            if 'HC05_IT2nd' in f:
                ID = a+'_'+b[:-3]
            else:
                ID = a+'_'+b
            IDlist.append(ID)
            for el in Echan:
                if el == c:
                    chaa.append(el)
        odf.insert(0,'el',chaa)
        odf.insert(0, 'IDlist', IDlist)
        # did i need to rename colunmns to range(10,40) for sorting????or is it already sorted?
        columns=odf.columns.tolist()
        columns[2:] = [str(i) for i in range(10,40)]
        odf.columns = columns  
        values = [a+b for a in string.ascii_lowercase for b in string.ascii_lowercase]
        mappings = dict(zip(Echan, values))
        mappings2 = dict(zip(values, Echan))
        odf['sortby'] = odf['el'].map(mappings)
        odf.drop('el',inplace=True,axis=1)
        odf=odf.pivot(index='sortby',columns = 'IDlist',values=[str(i) for i in range(10,40)])
        odf = odf.swaplevel(i=-2, j=-1, axis=1)
        odf = odf.sort_index(axis=1)
        odf.reset_index(level='sortby', inplace=True)
        odf['el'] = odf['sortby'].map(mappings2)
        odf.set_index('el', append=False, inplace=True)
        with io.capture_output() as captured:
            odf.drop('sortby',inplace=True,axis=1)
        odf=odf.transpose()
        odf.reset_index(level=1, inplace=True) # Moving timpoints/index-level_1 from index to column to (1) rename them & (2) to create Task-List from index-level_0 for Task Column
        timekeys= [str(i) for i in range(10,40)]#    (1)
        timevalues = [str(i) for i in range(30)]
        mappings3 = dict(zip(timekeys,timevalues))
        odf['windows']=odf['level_1'].map(mappings3)
        Tlist=[]#                                    (2)
        for f in odf.index:
            a,b = f.split('_')
            Tlist.append(b)
        odf.insert(0, 'Task', Tlist)
        odf.set_index('windows', append=True, inplace=True)
        # odf = odf.add_suffix(f'_{m}')
        odf.drop('level_1',inplace=True,axis=1)
        
        # Final Dataframe ______________________________________________________________________ #
        vars()['ssHC_'+m+'_'+window]=odf.copy()
        #Individual Dataframes
        for H in HC:
            vars()[H+'df_'+m+'_'+window]=odf.loc[([f'{H}_IT',f'{H}_ST']),:]##EXAMPLES-->>>##odf.loc[(['HC01_IT','HC01_ST'],'0'),:] ##odf.xs(key=('0'), level='windows').loc[['HC01_IT', 'HC01_ST']] ##odf.xs(('HC01_ST'), axis=0, level='IDlist')
            vars()[H+'df_'+m+'_'+window].index = ['_'.join(i) for i in vars()[H+'df_'+m+'_'+window].index] #combine both levels of index into one (i.e., 'HC01_IT_0')

            
#####################################################################################################################    
##                                                                                                                 ##
##                    HC MACHINE LEARNING                                                                             ## 
#####################################################################################################################    
from sklearn.model_selection import StratifiedKFold
import random
random.seed(42)
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier(random_state=42)))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto',kernel='rbf',random_state=42))) 
models.append(('SVC', SVC(gamma='scale', kernel='poly',random_state=42))) 

measures=['LZc','svd1','approx','sample','detrended','katz','ll','mswpen','bubben','cwpen']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']

accuracy_dict = {m: {model[0]: [] for model in models} for m in measures} #[X]
accuracy_dict2 = {m: {model[0]: [] for model in models} for m in measures} #[X] <---main
for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        print (f'\n=========================================\nssHC_{m}_{window} {odf.shape}\n=========================================')#print (f'\n=========================================I\nssHC_{m}_{window} {odf.shape}        I\n=========================================I')
        df = vars()['ssHC_'+m+'_'+window].copy()
        allHC_LR_results = []
        #Individual Dataframes
        for H in HC:
            hdf = vars()[H+'df_'+m+'_'+window].copy()
            print (f'{H}df_{m}_{window} {hdf.shape}')# <------------------------')
            # Accuracy lists
            LR_results= []
            LDA_results= []
            KNN_results= []
            CART_results= []
            NB_results= []
            SVM_results= []
            SVC_results= []     
            X = hdf.drop(columns='Task') #data
            y = hdf['Task'] #labels
            # Create a StratifiedKFold object
            skf = StratifiedKFold(n_splits=5)#,shuffle=True, random_state=42)
            # Stratified K-Folds cross-validator
            for count,(train_index, test_index) in enumerate(skf.split(X, y)):
                #print (f'Split_{count+1}:\nTrain_index: {train_index}\nTest_index: {test_index}')
                X_train= X.iloc[train_index]
                X_test= X.iloc[test_index]
                y_train= y.iloc[train_index]
                y_test= y.iloc[test_index]
                count +=1
                # Machine Learning Algorithms
                for name, model in models:
                    model.fit(X_train, y_train)
                    predictions = model.predict(X_test)
                    score = accuracy_score(y_test,predictions)
                    vars()[name+'_results'].append(score)
                    #print ('  -',name,score.round(2))
            #print('_________________________________________________________________')
            #print(f'Model Accuracy Scores and Average across 5 folds:')
            avg_models = []
            stdev_models = []
            for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
                average = round(((sum(vars()[i+'_results']))/len(vars()[i+'_results'])),2)
                stdev = round(np.std(vars()[i+'_results']),2)
                avg_models.append(average)
                stdev_models.append(stdev)
                #print (f"  > {i}: avg={average} stdev={stdev} {i}_results={[r.round(2) for r in vars()[i+'_results']]}") #print (f"  {i}: avg={average} stdev={stdev}")
                accuracy_dict2[m][i].append(vars()[i + '_results'])#[X]
                accuracy_dict[m][i].extend(vars()[i + '_results'])#[X]
            #print('_________________________________________________________________')
            # After calculating the accuracy scores for each model, store them in a dictionary
            etcresults = {'LR': LR_results,'LDA': LDA_results,'KNN': KNN_results,'CART': CART_results,'NB': NB_results,'SVM': SVM_results,'SVC': SVC_results}

#####################################################################################################################    
##                                                                                                                 ##
##                    plotting accuracy scores                                                                     ## 
#####################################################################################################################    
#(1)
for m in measures:
    data_to_plot = {name: accuracy_dict2[m][name] for name, _ in models}
    for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
        vars()[i+m+'scores']=data_to_plot[i]
for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
    vars()[i+'_']=[]
    for m in measures:
        scores_m =vars()[i+m+'scores'].copy()
        vars()[i+'_'].append(scores_m)    
#(2)***
for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
    print (i)
    hi = vars()[i+'_'].copy()
    hidf=pd.DataFrame(hi)
    hidf=hidf.transpose()
    hidf.columns = measures
    hidf.index =HC
    #(3)
    #i have a 10 by 18 dataframe. in each cell there is a list of 5 number. I want these 5 values (for both columns) to be thier own columns with the original column as a multilevel column
    # for i in HC:
    #     print (f"'{i}_fold1',",end='')
    #     print (f"'{i}_fold2',",end='')
    #     print (f"'{i}_fold3',",end='')
    #     print (f"'{i}_fold4',",end='')
    #     print (f"'{i}_fold5',",end='')    
    dfindex=['HC01_fold1','HC01_fold2','HC01_fold3','HC01_fold4','HC01_fold5','HC02_fold1','HC02_fold2','HC02_fold3','HC02_fold4','HC02_fold5','HC03_fold1','HC03_fold2','HC03_fold3','HC03_fold4','HC03_fold5','HC04_fold1','HC04_fold2','HC04_fold3','HC04_fold4','HC04_fold5','HC05_fold1','HC05_fold2','HC05_fold3','HC05_fold4','HC05_fold5','HC06_fold1','HC06_fold2','HC06_fold3','HC06_fold4','HC06_fold5','HC07_fold1','HC07_fold2','HC07_fold3','HC07_fold4','HC07_fold5','HC08_fold1','HC08_fold2','HC08_fold3','HC08_fold4','HC08_fold5','HC09_fold1','HC09_fold2','HC09_fold3','HC09_fold4','HC09_fold5','HC10_fold1','HC10_fold2','HC10_fold3','HC10_fold4','HC10_fold5','HC11_fold1','HC11_fold2','HC11_fold3','HC11_fold4','HC11_fold5','HC12_fold1','HC12_fold2','HC12_fold3','HC12_fold4','HC12_fold5','HC13_fold1','HC13_fold2','HC13_fold3','HC13_fold4','HC13_fold5','HC14_fold1','HC14_fold2','HC14_fold3','HC14_fold4','HC14_fold5','HC15_fold1','HC15_fold2','HC15_fold3','HC15_fold4','HC15_fold5','HC16_fold1','HC16_fold2','HC16_fold3','HC16_fold4','HC16_fold5','HC17_fold1','HC17_fold2','HC17_fold3','HC17_fold4','HC17_fold5','HC18_fold1','HC18_fold2','HC18_fold3','HC18_fold4','HC18_fold5']
    fdf=pd.DataFrame(index=dfindex)
    for m in measures:
        Mlist=[]
        for p in HC:
            #print(p,': ',hidf.loc[p,m])
            Mlist.extend(hidf.loc[p,m])
        fdf.insert(loc=len(fdf.columns),column=f'{m}',value=Mlist)    
    vars()['df_'+i]=fdf.copy()
    #(5)
    df = vars()['df_'+i].copy()
    #df.reset_index(inplace=True)
    IDlist=[]
    Foldlist=[]
    for o in df.index:
        a,b = o.split('_')
        IDlist.append(a)
        Foldlist.append(b)
    df.insert(0,'Fold',Foldlist)
    df.insert(0,'IDlist',IDlist)
    #(6) stacked df
    newdf=df.reset_index()
    newdf.set_index(keys='index',
        drop= True,
        append= False,
        inplace=True)
    # newdf.drop(labels='index',axis=1,inplace=True)
    newdf.set_index(keys='IDlist',
        drop= True,
        append= True,
        inplace=True)
    newdf.set_index(keys='Fold',
        drop= True,
        append= True,
        inplace=True)
    # newdf.drop(labels='Fold',axis=1,inplace=True)
    stacked=newdf.stack()
    stackeddf=pd.DataFrame(stacked,columns=['Values'])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    stackeddf=stackeddf.sort_index(axis=0,level=3)
    stackeddf=stackeddf.reset_index(level=3)
    col=list(stackeddf.columns.values)
    col[0]='measures'
    stackeddf.columns = col
    stackeddf=stackeddf.reset_index()
    #(7) plot
    sns.catplot(x="IDlist", 
                y="Values", 
                hue="measures", 
                data=stackeddf,
                kind='point',
                height=6,  
                aspect=3)

# lineplot : Plot data using lines.
# stripplot : Plot a categorical scatter with jitter.
# swarmplot : Plot a categorical scatter with non-overlapping points.


#####################################################################################################################
### OLD LABELING ###
# EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30','CCTC03','CCTC04','CCTC05','MSICU05','MSICU07','MSICU09','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
# # for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
# #     for m in measures:
# #         print (f'\n{m}_{window}_reorg')
# #         df = vars()[m+'_'+window+'_reorg'].copy()
# window ='10secwindows'
# for m in measures:
#     df = vars()[m+'_'+window+'_reorg'].copy()
#     #----------------------------------------#
#     IDlist=[]
#     Tlist=[]
#     for f in df.index:
#         ID = ((f.split('_')[0]).split('part2')[0]).split('sed')[0]
#         IDlist.append(ID)
#         #RS/ST/IT
#         for Task in ['RS','ST','IT']:
#             if Task in f:
#                 T = Task
#                 Tlist.append(T)
#     # Add Labels
#     df.insert(0, 'Task', Tlist)
#     df.insert(0, 'participant_id', IDlist)
#     #----------------------------------------#
#     vars()[m+'_'+window+'_reorgwlabels'] = df
#     vars()['ssHC_'+m] = df[df.index.str.contains('HC')]#only HC

# #Print
# print (f'\n_____________________________________________________________________________{window}\n')
# print('IT vs ST')
# df2 = vars()[i+'svd1']
# print (f"   -(Participants:{len(df2['participant_id'].value_counts())}, Files:{df2.shape[0]})  {i}")
# print ('_____________________________________________________________________________')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_346746/1451667935.py in <module>
#      26 for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
#      27     for m in measures:
# ---> 28         vars()[m+'_'+window]= pd.read_csv(f'./results/NewDataResults/save/{window}/{m}/{m}_{window}.csv')
#      29         vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
#      30         vars()[m+'_'+window].set_index('ID', inplace=True)
#
# NameError: name 'pd' is not defined

# %%
# Plot with the 7 models on the x axis and acuracy on the y axis

# %% [markdown]
# ### Graphing: Comparing accuracy scores of the 7 models and 9 measures

# %%
## updated NEWDATA
#################

import statsmodels
from statsmodels import formula
from statsmodels.formula import tests
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.anova import AnovaRM
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import pingouin as pg
#888888888888888888888**************
# alldf=[]
# for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
#     df = vars()['df_'+i].copy()
#     #df.reset_index(inplace=True)
#     IDlist=[]
#     Foldlist=[]
#     for o in df.index:
#         a,b = o.split('_')
#         IDlist.append(a)
#         Foldlist.append(b)
#     df.insert(0,'Fold',Foldlist)
#     df.insert(0,'IDlist',IDlist)
#     df=df.reset_index()
#     df.set_index(keys='index',drop= True,append= False,inplace=True)
#     # df.drop(labels='index',axis=1,inplace=True)
#     df.set_index(keys='IDlist',drop= True,append= True,inplace=True)
#     df.set_index(keys='Fold',drop= True,append= True,inplace=True)
#     df=df.stack()
#     df=pd.DataFrame(df,columns=[i])
#     # df=df.swaplevel(i=-2, j=-1, axis=0)
#     df=df.sort_index(axis=0,level=3)
#     df=df.reset_index(level=3)
#     col=list(df.columns.values)
#     col[0]='measures'
#     df.columns = col
#     df.set_index('measures',append=True,inplace=True)
#     alldf.append(df)
# df = pd.concat(alldf, axis=1)
# stackeddf = df.stack()
# stackeddf= pd.DataFrame(stackeddf,columns=['values'])
# stackeddf=stackeddf.reset_index()
# col=list(stackeddf.columns.values)
# col[0],col[1],col[2],col[3],col[4]='index','ID','Fold','meas','algo'
# stackeddf.columns = col
# # display(stackeddf)
#####
alldf=[]
for i in ['SVC','LDA','KNN','LR','CART','NB','SVM']:#['LR','LDA','KNN','CART','NB','SVM','SVC']:
    df_grouped = vars()['df_'+i].groupby(np.arange(len(vars()['df_'+i]))//5).mean()# Calculate the average of every 5 rows
    df_grouped.index = HC
    df_grouped=df_grouped.stack()
    df_grouped=pd.DataFrame(df_grouped,columns=[i])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    df_grouped=df_grouped.sort_index(axis=0,level=1)
    alldf.append(df_grouped)
result = pd.concat(alldf, axis=1)
# display(result)
#1
stackresult = result.copy().stack()
stackresult= pd.DataFrame(stackresult,columns=['values'])
stackresult=stackresult.reset_index()
col=list(stackresult.columns.values)
col[0],col[1],col[2]='ID','meas','algo'
stackresult.columns = col
display(stackresult)
# #2
# avgmeasdf = pd.DataFrame(result.mean(axis=1),columns=['values'])
# avgmeasdf.reset_index(inplace=True, names=['ID','meas'])
# display(avgmeasdf)
# #3
# avgalgodf = stackresult.copy().pivot(columns='meas', index=['ID','algo'], values='values')
# avgalgodf = pd.DataFrame(avgalgodf.mean(axis=1),columns=['values'])
# avgalgodf.reset_index(inplace=True, names=['ID','algo'])
# display(avgalgodf)
################################################################################################################    
##                                                                                                            ##
##                                                Statistics                                                  ## 
################################################################################################################ 
# Descriptive statistics --------------------------------------#

# OLD Descriptive statistics (avg) --------------------------------------#
df = stackresult.copy()
# calculate the mean of the 'value' column for each category
means = stackresult.groupby('meas')['values'].mean()
meas=means.sort_values(ascending=False)
print(meas)
means2 = stackresult.groupby('algo')['values'].mean()
algos=means2.sort_values(ascending=False)
print(algos)
# df.columns = [col[0]+col[1] for col in df.columns]
df['group'] = df['meas'].astype(str) + '_' + df['algo'].astype(str)
mix = df.groupby('group')['values'].mean()
mix2=mix.sort_values(ascending=False)
print (mix2,'\n')

# Performing two-way ANOVA ------------------------------------------#
data = stackresult.copy()
model = ols('values ~ C(meas) + C(algo) + C(meas):C(algo)', data=data).fit()#,drop_cols='ID'
result = sm.stats.anova_lm(model, type=2) 
print('___ANOVA Table____________________________________________________________\n',result,'\n__________________________________________________________________________')
for r in range(3):
    print (f'{result.index[r]}: p = {result.iloc[r,4].round(3)}')
print ("\nTukey's test") # Perform Tukey's test
tukey = pairwise_tukeyhsd(endog=data['values'],groups=data['meas'],alpha=0.01)
tukey2 = pairwise_tukeyhsd(endog=data['values'],groups=data['algo'],alpha=0.01)
print (tukey)
print (tukey2)
################################################################################################################    
##                                                                                                            ##
##                                                Plots                                                       ## 
################################################################################################################ 

#Plot

# display(stackresult)
df=stackresult.copy()
# df.set_index(['ID', 'meas', 'algo'],inplace=True)
# DescriptiveStats = df.describe()
# display(DescriptiveStats)
# df_unstacked = df.unstack(level=['meas','algo'])
# display(df_unstacked)

#Plot
fig, ax = plt.subplots(figsize=(12, 6))
# df_unstacked.plot(kind='bar', ax=ax)
sns.barplot(data=df,ax=ax, x='algo', y='values', 
            hue='meas',
            order=['SVC','LDA','KNN','LR','CART','NB','SVM'],
            hue_order=['ll','cwpen','bubben','sample','approx','detrended','svd1','katz','LZc','mswpen'])
#             estimator='mean',
#             errorbar=('ci', 95),
#             n_boot=1000,
#             units=None,
#             seed=None,
#             orient=None,
#             color=None,
#             palette='Set2',
#             saturation=0.75,
#             fill=True,
#             hue_norm=None,
#             width=0.8,
#             dodge='auto',
#             gap=0,
#             log_scale=None,
#             native_scale=False,
#             formatter=None,
#             legend='auto',
#             capsize=0,
#             err_kws=None)
plt.title('HC Models and measures for individual particpant performance') #'Measures(9) x Algorithms(7)') # ax.set_title('Measures(9) x Algorithms(7)')
plt.ylabel("Accuracy")
plt.xlabel("Models")
plt.ylim(0.4, 1.0)
legend = plt.legend(loc='upper left',bbox_to_anchor=(1, 1))#,fontsize='x-small', labelspacing=0.05)
legend.set_title('Measures')
new_labels = ['LL','CWPEn','bubbEn','Sample','Approx','Detrended','SVD','Katz','LZc','MSWPEn']
for t, l in zip(legend.texts, new_labels): t.set_text(l)
plt.show()
# Out:
#         ID       meas  algo    values
# 0     HC01        LZc   SVC  1.000000
# 1     HC01        LZc   LDA  0.983333
# 2     HC01        LZc   KNN  0.950000
# 3     HC01        LZc    LR  0.966667
# 4     HC01        LZc  CART  0.950000
# 5     HC01        LZc    NB  0.933333
# 6     HC01        LZc   SVM  0.933333
# 7     HC02        LZc   SVC  0.883333
# 8     HC02        LZc   LDA  0.866667
# 9     HC02        LZc   KNN  0.883333
# 10    HC02        LZc    LR  0.900000
# 11    HC02        LZc  CART  0.816667
# 12    HC02        LZc    NB  0.866667
# 13    HC02        LZc   SVM  0.816667
# 14    HC03        LZc   SVC  0.883333
# 15    HC03        LZc   LDA  0.883333
# 16    HC03        LZc   KNN  0.866667
# 17    HC03        LZc    LR  0.933333
# 18    HC03        LZc  CART  0.833333
# 19    HC03        LZc    NB  0.666667
# 20    HC03        LZc   SVM  0.650000
# 21    HC04        LZc   SVC  0.833333
# 22    HC04        LZc   LDA  0.683333
# 23    HC04        LZc   KNN  0.733333
# 24    HC04        LZc    LR  0.833333
# 25    HC04        LZc  CART  0.716667
# 26    HC04        LZc    NB  0.650000
# 27    HC04        LZc   SVM  0.583333
# 28    HC05        LZc   SVC  0.866667
# 29    HC05        LZc   LDA  0.833333
# 30    HC05        LZc   KNN  0.750000
# 31    HC05        LZc    LR  0.766667
# 32    HC05        LZc  CART  0.850000
# 33    HC05        LZc    NB  0.800000
# 34    HC05        LZc   SVM  0.750000
# 35    HC06        LZc   SVC  0.816667
# 36    HC06        LZc   LDA  0.683333
# 37    HC06        LZc   KNN  0.683333
# 38    HC06        LZc    LR  0.800000
# 39    HC06        LZc  CART  0.700000
# 40    HC06        LZc    NB  0.700000
# 41    HC06        LZc   SVM  0.633333
# 42    HC07        LZc   SVC  0.700000
# 43    HC07        LZc   LDA  0.666667
# 44    HC07        LZc   KNN  0.733333
# 45    HC07        LZc    LR  0.650000
# 46    HC07        LZc  CART  0.800000
# 47    HC07        LZc    NB  0.716667
# 48    HC07        LZc   SVM  0.700000
# 49    HC08        LZc   SVC  0.616667
# 50    HC08        LZc   LDA  0.600000
# 51    HC08        LZc   KNN  0.666667
# 52    HC08        LZc    LR  0.566667
# 53    HC08        LZc  CART  0.683333
# 54    HC08        LZc    NB  0.616667
# 55    HC08        LZc   SVM  0.550000
# 56    HC09        LZc   SVC  0.966667
# 57    HC09        LZc   LDA  0.933333
# 58    HC09        LZc   KNN  0.900000
# 59    HC09        LZc    LR  0.966667
# 60    HC09        LZc  CART  0.866667
# 61    HC09        LZc    NB  0.916667
# 62    HC09        LZc   SVM  0.933333
# 63    HC10        LZc   SVC  0.916667
# 64    HC10        LZc   LDA  0.916667
# 65    HC10        LZc   KNN  0.833333
# 66    HC10        LZc    LR  0.916667
# 67    HC10        LZc  CART  0.916667
# 68    HC10        LZc    NB  0.850000
# 69    HC10        LZc   SVM  0.816667
# 70    HC11        LZc   SVC  0.683333
# 71    HC11        LZc   LDA  0.766667
# 72    HC11        LZc   KNN  0.700000
# 73    HC11        LZc    LR  0.766667
# 74    HC11        LZc  CART  0.766667
# 75    HC11        LZc    NB  0.600000
# 76    HC11        LZc   SVM  0.616667
# 77    HC12        LZc   SVC  0.933333
# 78    HC12        LZc   LDA  0.966667
# 79    HC12        LZc   KNN  0.916667
# 80    HC12        LZc    LR  0.783333
# 81    HC12        LZc  CART  0.750000
# 82    HC12        LZc    NB  0.683333
# 83    HC12        LZc   SVM  0.600000
# 84    HC13        LZc   SVC  0.983333
# 85    HC13        LZc   LDA  0.916667
# 86    HC13        LZc   KNN  0.933333
# 87    HC13        LZc    LR  0.966667
# 88    HC13        LZc  CART  0.816667
# 89    HC13        LZc    NB  0.800000
# 90    HC13        LZc   SVM  0.883333
# 91    HC14        LZc   SVC  0.850000
# 92    HC14        LZc   LDA  0.833333
# 93    HC14        LZc   KNN  0.866667
# 94    HC14        LZc    LR  0.850000
# 95    HC14        LZc  CART  0.733333
# 96    HC14        LZc    NB  0.716667
# 97    HC14        LZc   SVM  0.716667
# 98    HC15        LZc   SVC  0.700000
# 99    HC15        LZc   LDA  0.700000
# 100   HC15        LZc   KNN  0.800000
# 101   HC15        LZc    LR  0.700000
# 102   HC15        LZc  CART  0.683333
# 103   HC15        LZc    NB  0.616667
# 104   HC15        LZc   SVM  0.550000
# 105   HC16        LZc   SVC  0.633333
# 106   HC16        LZc   LDA  0.583333
# 107   HC16        LZc   KNN  0.700000
# 108   HC16        LZc    LR  0.683333
# 109   HC16        LZc  CART  0.650000
# 110   HC16        LZc    NB  0.666667
# 111   HC16        LZc   SVM  0.600000
# 112   HC17        LZc   SVC  0.766667
# 113   HC17        LZc   LDA  0.750000
# 114   HC17        LZc   KNN  0.666667
# 115   HC17        LZc    LR  0.850000
# 116   HC17        LZc  CART  0.666667
# 117   HC17        LZc    NB  0.616667
# 118   HC17        LZc   SVM  0.466667
# 119   HC18        LZc   SVC  0.750000
# 120   HC18        LZc   LDA  0.733333
# 121   HC18        LZc   KNN  0.600000
# 122   HC18        LZc    LR  0.700000
# 123   HC18        LZc  CART  0.600000
# 124   HC18        LZc    NB  0.566667
# 125   HC18        LZc   SVM  0.566667
# 126   HC01     approx   SVC  0.983333
# 127   HC01     approx   LDA  1.000000
# 128   HC01     approx   KNN  0.966667
# 129   HC01     approx    LR  0.966667
# 130   HC01     approx  CART  0.916667
# 131   HC01     approx    NB  0.950000
# 132   HC01     approx   SVM  0.966667
# 133   HC02     approx   SVC  0.950000
# 134   HC02     approx   LDA  0.783333
# 135   HC02     approx   KNN  0.916667
# 136   HC02     approx    LR  0.966667
# 137   HC02     approx  CART  0.766667
# 138   HC02     approx    NB  0.833333
# 139   HC02     approx   SVM  0.783333
# 140   HC03     approx   SVC  0.833333
# 141   HC03     approx   LDA  0.883333
# 142   HC03     approx   KNN  0.883333
# 143   HC03     approx    LR  0.933333
# 144   HC03     approx  CART  0.816667
# 145   HC03     approx    NB  0.666667
# 146   HC03     approx   SVM  0.716667
# 147   HC04     approx   SVC  0.900000
# 148   HC04     approx   LDA  0.800000
# 149   HC04     approx   KNN  0.866667
# 150   HC04     approx    LR  0.933333
# 151   HC04     approx  CART  0.716667
# 152   HC04     approx    NB  0.700000
# 153   HC04     approx   SVM  0.700000
# 154   HC05     approx   SVC  0.866667
# 155   HC05     approx   LDA  0.816667
# 156   HC05     approx   KNN  0.833333
# 157   HC05     approx    LR  0.850000
# 158   HC05     approx  CART  0.850000
# 159   HC05     approx    NB  0.800000
# 160   HC05     approx   SVM  0.750000
# 161   HC06     approx   SVC  0.650000
# 162   HC06     approx   LDA  0.783333
# 163   HC06     approx   KNN  0.750000
# 164   HC06     approx    LR  0.833333
# 165   HC06     approx  CART  0.566667
# 166   HC06     approx    NB  0.700000
# 167   HC06     approx   SVM  0.650000
# 168   HC07     approx   SVC  0.816667
# 169   HC07     approx   LDA  0.816667
# 170   HC07     approx   KNN  0.716667
# 171   HC07     approx    LR  0.750000
# 172   HC07     approx  CART  0.916667
# 173   HC07     approx    NB  0.750000
# 174   HC07     approx   SVM  0.800000
# 175   HC08     approx   SVC  0.733333
# 176   HC08     approx   LDA  0.816667
# 177   HC08     approx   KNN  0.666667
# 178   HC08     approx    LR  0.750000
# 179   HC08     approx  CART  0.750000
# 180   HC08     approx    NB  0.583333
# 181   HC08     approx   SVM  0.533333
# 182   HC09     approx   SVC  0.983333
# 183   HC09     approx   LDA  0.950000
# 184   HC09     approx   KNN  0.950000
# 185   HC09     approx    LR  1.000000
# 186   HC09     approx  CART  1.000000
# 187   HC09     approx    NB  0.933333
# 188   HC09     approx   SVM  0.883333
# 189   HC10     approx   SVC  0.850000
# 190   HC10     approx   LDA  0.933333
# 191   HC10     approx   KNN  0.883333
# 192   HC10     approx    LR  0.950000
# 193   HC10     approx  CART  0.866667
# 194   HC10     approx    NB  0.816667
# 195   HC10     approx   SVM  0.850000
# 196   HC11     approx   SVC  0.733333
# 197   HC11     approx   LDA  0.850000
# 198   HC11     approx   KNN  0.700000
# 199   HC11     approx    LR  0.800000
# 200   HC11     approx  CART  0.733333
# 201   HC11     approx    NB  0.600000
# 202   HC11     approx   SVM  0.600000
# 203   HC12     approx   SVC  0.983333
# 204   HC12     approx   LDA  0.966667
# 205   HC12     approx   KNN  0.900000
# 206   HC12     approx    LR  0.933333
# 207   HC12     approx  CART  0.933333
# 208   HC12     approx    NB  0.616667
# 209   HC12     approx   SVM  0.600000
# 210   HC13     approx   SVC  0.983333
# 211   HC13     approx   LDA  0.983333
# 212   HC13     approx   KNN  0.950000
# 213   HC13     approx    LR  0.966667
# 214   HC13     approx  CART  0.966667
# 215   HC13     approx    NB  0.850000
# 216   HC13     approx   SVM  0.883333
# 217   HC14     approx   SVC  0.866667
# 218   HC14     approx   LDA  0.850000
# 219   HC14     approx   KNN  0.916667
# 220   HC14     approx    LR  0.883333
# 221   HC14     approx  CART  0.816667
# 222   HC14     approx    NB  0.750000
# 223   HC14     approx   SVM  0.700000
# 224   HC15     approx   SVC  0.883333
# 225   HC15     approx   LDA  0.833333
# 226   HC15     approx   KNN  0.883333
# 227   HC15     approx    LR  0.916667
# 228   HC15     approx  CART  0.900000
# 229   HC15     approx    NB  0.716667
# 230   HC15     approx   SVM  0.600000
# 231   HC16     approx   SVC  0.800000
# 232   HC16     approx   LDA  0.666667
# 233   HC16     approx   KNN  0.750000
# 234   HC16     approx    LR  0.800000
# 235   HC16     approx  CART  0.716667
# 236   HC16     approx    NB  0.733333
# 237   HC16     approx   SVM  0.733333
# 238   HC17     approx   SVC  0.933333
# 239   HC17     approx   LDA  0.750000
# 240   HC17     approx   KNN  0.766667
# 241   HC17     approx    LR  0.916667
# 242   HC17     approx  CART  0.783333
# 243   HC17     approx    NB  0.700000
# 244   HC17     approx   SVM  0.566667
# 245   HC18     approx   SVC  0.783333
# 246   HC18     approx   LDA  0.816667
# 247   HC18     approx   KNN  0.650000
# 248   HC18     approx    LR  0.666667
# 249   HC18     approx  CART  0.566667
# 250   HC18     approx    NB  0.516667
# 251   HC18     approx   SVM  0.550000
# 252   HC01     bubben   SVC  0.983333
# 253   HC01     bubben   LDA  0.816667
# 254   HC01     bubben   KNN  0.966667
# 255   HC01     bubben    LR  0.816667
# 256   HC01     bubben  CART  0.950000
# 257   HC01     bubben    NB  0.983333
# 258   HC01     bubben   SVM  0.800000
# 259   HC02     bubben   SVC  0.900000
# 260   HC02     bubben   LDA  0.766667
# 261   HC02     bubben   KNN  0.833333
# 262   HC02     bubben    LR  0.883333
# 263   HC02     bubben  CART  0.800000
# 264   HC02     bubben    NB  0.816667
# 265   HC02     bubben   SVM  0.833333
# 266   HC03     bubben   SVC  1.000000
# 267   HC03     bubben   LDA  1.000000
# 268   HC03     bubben   KNN  1.000000
# 269   HC03     bubben    LR  1.000000
# 270   HC03     bubben  CART  0.883333
# 271   HC03     bubben    NB  1.000000
# 272   HC03     bubben   SVM  0.916667
# 273   HC04     bubben   SVC  0.983333
# 274   HC04     bubben   LDA  0.916667
# 275   HC04     bubben   KNN  0.900000
# 276   HC04     bubben    LR  0.916667
# 277   HC04     bubben  CART  0.750000
# 278   HC04     bubben    NB  0.950000
# 279   HC04     bubben   SVM  0.916667
# 280   HC05     bubben   SVC  1.000000
# 281   HC05     bubben   LDA  1.000000
# 282   HC05     bubben   KNN  0.983333
# 283   HC05     bubben    LR  0.933333
# 284   HC05     bubben  CART  0.866667
# 285   HC05     bubben    NB  0.966667
# 286   HC05     bubben   SVM  0.933333
# 287   HC06     bubben   SVC  0.933333
# 288   HC06     bubben   LDA  0.866667
# 289   HC06     bubben   KNN  0.933333
# 290   HC06     bubben    LR  0.916667
# 291   HC06     bubben  CART  0.916667
# 292   HC06     bubben    NB  0.916667
# 293   HC06     bubben   SVM  0.850000
# 294   HC07     bubben   SVC  0.666667
# 295   HC07     bubben   LDA  0.600000
# 296   HC07     bubben   KNN  0.616667
# 297   HC07     bubben    LR  0.650000
# 298   HC07     bubben  CART  0.466667
# 299   HC07     bubben    NB  0.616667
# 300   HC07     bubben   SVM  0.716667
# 301   HC08     bubben   SVC  0.466667
# 302   HC08     bubben   LDA  0.666667
# 303   HC08     bubben   KNN  0.583333
# 304   HC08     bubben    LR  0.633333
# 305   HC08     bubben  CART  0.483333
# 306   HC08     bubben    NB  0.566667
# 307   HC08     bubben   SVM  0.616667
# 308   HC09     bubben   SVC  1.000000
# 309   HC09     bubben   LDA  0.900000
# 310   HC09     bubben   KNN  0.983333
# 311   HC09     bubben    LR  0.900000
# 312   HC09     bubben  CART  0.783333
# 313   HC09     bubben    NB  0.933333
# 314   HC09     bubben   SVM  0.933333
# 315   HC10     bubben   SVC  0.900000
# 316   HC10     bubben   LDA  0.850000
# 317   HC10     bubben   KNN  0.950000
# 318   HC10     bubben    LR  0.916667
# 319   HC10     bubben  CART  0.933333
# 320   HC10     bubben    NB  0.916667
# 321   HC10     bubben   SVM  0.816667
# 322   HC11     bubben   SVC  0.883333
# 323   HC11     bubben   LDA  0.850000
# 324   HC11     bubben   KNN  0.800000
# 325   HC11     bubben    LR  0.800000
# 326   HC11     bubben  CART  0.766667
# 327   HC11     bubben    NB  0.800000
# 328   HC11     bubben   SVM  0.750000
# 329   HC12     bubben   SVC  0.966667
# 330   HC12     bubben   LDA  0.883333
# 331   HC12     bubben   KNN  0.933333
# 332   HC12     bubben    LR  0.783333
# 333   HC12     bubben  CART  0.766667
# 334   HC12     bubben    NB  0.783333
# 335   HC12     bubben   SVM  0.533333
# 336   HC13     bubben   SVC  0.933333
# 337   HC13     bubben   LDA  0.866667
# 338   HC13     bubben   KNN  0.866667
# 339   HC13     bubben    LR  0.716667
# 340   HC13     bubben  CART  0.800000
# 341   HC13     bubben    NB  0.666667
# 342   HC13     bubben   SVM  0.566667
# 343   HC14     bubben   SVC  0.950000
# 344   HC14     bubben   LDA  0.900000
# 345   HC14     bubben   KNN  0.883333
# 346   HC14     bubben    LR  0.883333
# 347   HC14     bubben  CART  0.850000
# 348   HC14     bubben    NB  0.850000
# 349   HC14     bubben   SVM  0.850000
# 350   HC15     bubben   SVC  0.950000
# 351   HC15     bubben   LDA  0.916667
# 352   HC15     bubben   KNN  0.833333
# 353   HC15     bubben    LR  0.833333
# 354   HC15     bubben  CART  0.733333
# 355   HC15     bubben    NB  0.883333
# 356   HC15     bubben   SVM  0.600000
# 357   HC16     bubben   SVC  0.916667
# 358   HC16     bubben   LDA  0.933333
# 359   HC16     bubben   KNN  0.833333
# 360   HC16     bubben    LR  0.850000
# 361   HC16     bubben  CART  0.766667
# 362   HC16     bubben    NB  0.733333
# 363   HC16     bubben   SVM  0.683333
# 364   HC17     bubben   SVC  0.983333
# 365   HC17     bubben   LDA  0.933333
# 366   HC17     bubben   KNN  0.900000
# 367   HC17     bubben    LR  0.750000
# 368   HC17     bubben  CART  0.900000
# 369   HC17     bubben    NB  0.850000
# 370   HC17     bubben   SVM  0.750000
# 371   HC18     bubben   SVC  0.866667
# 372   HC18     bubben   LDA  0.900000
# 373   HC18     bubben   KNN  0.816667
# 374   HC18     bubben    LR  0.833333
# 375   HC18     bubben  CART  0.716667
# 376   HC18     bubben    NB  0.716667
# 377   HC18     bubben   SVM  0.683333
# 449   HC11      cwpen   LDA  0.883333
# 450   HC11      cwpen   KNN  0.750000
# 451   HC11      cwpen    LR  0.783333
# 452   HC11      cwpen  CART  0.933333
# 453   HC11      cwpen    NB  0.850000
# 454   HC11      cwpen   SVM  0.700000
# 455   HC12      cwpen   SVC  0.966667
# 456   HC12      cwpen   LDA  0.950000
# 457   HC12      cwpen   KNN  0.966667
# 458   HC12      cwpen    LR  0.916667
# 459   HC12      cwpen  CART  0.966667
# 460   HC12      cwpen    NB  0.933333
# 461   HC12      cwpen   SVM  0.700000
# 462   HC13      cwpen   SVC  0.966667
# 463   HC13      cwpen   LDA  0.983333
# 464   HC13      cwpen   KNN  0.916667
# 465   HC13      cwpen    LR  0.900000
# 466   HC13      cwpen  CART  0.850000
# 467   HC13      cwpen    NB  0.900000
# 468   HC13      cwpen   SVM  0.700000
# 469   HC14      cwpen   SVC  0.966667
# 470   HC14      cwpen   LDA  0.916667
# 471   HC14      cwpen   KNN  0.900000
# 472   HC14      cwpen    LR  0.933333
# 473   HC14      cwpen  CART  0.866667
# 474   HC14      cwpen    NB  0.883333
# 475   HC14      cwpen   SVM  0.916667
# 476   HC15      cwpen   SVC  0.933333
# 477   HC15      cwpen   LDA  0.933333
# 478   HC15      cwpen   KNN  0.850000
# 479   HC15      cwpen    LR  0.816667
# 480   HC15      cwpen  CART  0.816667
# 481   HC15      cwpen    NB  0.633333
# 482   HC15      cwpen   SVM  0.566667
# 483   HC16      cwpen   SVC  0.966667
# 484   HC16      cwpen   LDA  0.916667
# 485   HC16      cwpen   KNN  0.883333
# 486   HC16      cwpen    LR  0.716667
# 487   HC16      cwpen  CART  0.716667
# 488   HC16      cwpen    NB  0.666667
# 489   HC16      cwpen   SVM  0.633333
# 490   HC17      cwpen   SVC  1.000000
# 491   HC17      cwpen   LDA  0.966667
# 492   HC17      cwpen   KNN  0.900000
# 493   HC17      cwpen    LR  0.833333
# 494   HC17      cwpen  CART  0.866667
# 495   HC17      cwpen    NB  0.950000
# 496   HC17      cwpen   SVM  0.600000
# 497   HC18      cwpen   SVC  0.833333
# 498   HC18      cwpen   LDA  0.966667
# 499   HC18      cwpen   KNN  0.833333
# 500   HC18      cwpen    LR  0.750000
# 501   HC18      cwpen  CART  0.683333
# 502   HC18      cwpen    NB  0.483333
# 503   HC18      cwpen   SVM  0.550000
# 504   HC01  detrended   SVC  0.966667
# 505   HC01  detrended   LDA  0.983333
# 506   HC01  detrended   KNN  0.966667
# 507   HC01  detrended    LR  0.966667
# 508   HC01  detrended  CART  0.966667
# 509   HC01  detrended    NB  0.950000
# 510   HC01  detrended   SVM  0.966667
# 511   HC02  detrended   SVC  0.933333
# 512   HC02  detrended   LDA  0.950000
# 513   HC02  detrended   KNN  0.883333
# 514   HC02  detrended    LR  0.933333
# 515   HC02  detrended  CART  0.933333
# 516   HC02  detrended    NB  0.800000
# 517   HC02  detrended   SVM  0.800000
# 518   HC03  detrended   SVC  0.983333
# 519   HC03  detrended   LDA  1.000000
# 520   HC03  detrended   KNN  0.916667
# 596   HC14  detrended   LDA  0.850000
# 597   HC14  detrended   KNN  0.883333
# 598   HC14  detrended    LR  0.883333
# 599   HC14  detrended  CART  0.866667
# 600   HC14  detrended    NB  0.916667
# 601   HC14  detrended   SVM  0.666667
# 602   HC15  detrended   SVC  0.966667
# 603   HC15  detrended   LDA  0.866667
# 604   HC15  detrended   KNN  0.750000
# 605   HC15  detrended    LR  0.816667
# 606   HC15  detrended  CART  0.833333
# 607   HC15  detrended    NB  0.666667
# 608   HC15  detrended   SVM  0.600000
# 609   HC16  detrended   SVC  0.883333
# 610   HC16  detrended   LDA  0.816667
# 611   HC16  detrended   KNN  0.766667
# 612   HC16  detrended    LR  0.816667
# 613   HC16  detrended  CART  0.700000
# 614   HC16  detrended    NB  0.716667
# 615   HC16  detrended   SVM  0.750000
# 616   HC17  detrended   SVC  0.900000
# 617   HC17  detrended   LDA  0.900000
# 618   HC17  detrended   KNN  0.800000
# 619   HC17  detrended    LR  0.883333
# 620   HC17  detrended  CART  0.800000
# 621   HC17  detrended    NB  0.566667
# 622   HC17  detrended   SVM  0.600000
# 623   HC18  detrended   SVC  0.816667
# 624   HC18  detrended   LDA  0.783333
# 625   HC18  detrended   KNN  0.650000
# 626   HC18  detrended    LR  0.683333
# 627   HC18  detrended  CART  0.700000
# 628   HC18  detrended    NB  0.566667
# 629   HC18  detrended   SVM  0.650000
# 630   HC01       katz   SVC  0.933333
# 631   HC01       katz   LDA  0.950000
# 632   HC01       katz   KNN  0.966667
# 633   HC01       katz    LR  0.950000
# 634   HC01       katz  CART  0.883333
# 635   HC01       katz    NB  0.916667
# 636   HC01       katz   SVM  0.966667
# 637   HC02       katz   SVC  0.883333
# 638   HC02       katz   LDA  0.950000
# 639   HC02       katz   KNN  0.833333
# 640   HC02       katz    LR  0.950000
# 641   HC02       katz  CART  0.700000
# 642   HC02       katz    NB  0.783333
# 643   HC02       katz   SVM  0.850000
# 644   HC03       katz   SVC  0.950000
# 645   HC03       katz   LDA  0.933333
# 646   HC03       katz   KNN  0.866667
# 647   HC03       katz    LR  1.000000
# 648   HC03       katz  CART  0.950000
# 649   HC03       katz    NB  0.766667
# 650   HC03       katz   SVM  0.883333
# 651   HC04       katz   SVC  0.750000
# 652   HC04       katz   LDA  0.733333
# 653   HC04       katz   KNN  0.800000
# 654   HC04       katz    LR  0.800000
# 655   HC04       katz  CART  0.516667
# 656   HC04       katz    NB  0.783333
# 657   HC04       katz   SVM  0.750000
# 658   HC05       katz   SVC  0.833333
# 659   HC05       katz   LDA  0.933333
# 660   HC05       katz   KNN  0.733333
# 661   HC05       katz    LR  0.866667
# 662   HC05       katz  CART  0.716667
# 663   HC05       katz    NB  0.800000
# 664   HC05       katz   SVM  0.783333
# 665   HC06       katz   SVC  0.666667
# 666   HC06       katz   LDA  0.650000
# 667   HC06       katz   KNN  0.700000
# 668   HC06       katz    LR  0.750000
# 669   HC06       katz  CART  0.750000
# 670   HC06       katz    NB  0.750000
# 671   HC06       katz   SVM  0.700000
# 672   HC07       katz   SVC  0.633333
# 673   HC07       katz   LDA  0.550000
# 674   HC07       katz   KNN  0.633333
# 675   HC07       katz    LR  0.583333
# 676   HC07       katz  CART  0.633333
# 677   HC07       katz    NB  0.683333
# 678   HC07       katz   SVM  0.566667
# 679   HC08       katz   SVC  0.683333
# 680   HC08       katz   LDA  0.766667
# 681   HC08       katz   KNN  0.583333
# 682   HC08       katz    LR  0.700000
# 683   HC08       katz  CART  0.533333
# 684   HC08       katz    NB  0.600000
# 685   HC08       katz   SVM  0.550000
# 686   HC09       katz   SVC  0.983333
# 687   HC09       katz   LDA  0.966667
# 688   HC09       katz   KNN  0.900000
# 689   HC09       katz    LR  1.000000
# 690   HC09       katz  CART  0.883333
# 691   HC09       katz    NB  0.866667
# 692   HC09       katz   SVM  0.833333
# 693   HC10       katz   SVC  0.983333
# 694   HC10       katz   LDA  0.916667
# 695   HC10       katz   KNN  0.916667
# 696   HC10       katz    LR  0.966667
# 697   HC10       katz  CART  0.850000
# 698   HC10       katz    NB  0.816667
# 699   HC10       katz   SVM  0.866667
# 700   HC11       katz   SVC  0.766667
# 701   HC11       katz   LDA  0.766667
# 702   HC11       katz   KNN  0.683333
# 703   HC11       katz    LR  0.750000
# 704   HC11       katz  CART  0.700000
# 705   HC11       katz    NB  0.666667
# 706   HC11       katz   SVM  0.633333
# 707   HC12       katz   SVC  0.950000
# 708   HC12       katz   LDA  0.900000
# 709   HC12       katz   KNN  0.816667
# 710   HC12       katz    LR  0.916667
# 711   HC12       katz  CART  0.766667
# 712   HC12       katz    NB  0.650000
# 713   HC12       katz   SVM  0.616667
# 714   HC13       katz   SVC  0.933333
# 715   HC13       katz   LDA  0.866667
# 716   HC13       katz   KNN  0.900000
# 717   HC13       katz    LR  0.966667
# 718   HC13       katz  CART  0.800000
# 719   HC13       katz    NB  0.800000
# 720   HC13       katz   SVM  0.783333
# 721   HC14       katz   SVC  0.800000
# 722   HC14       katz   LDA  0.783333
# 723   HC14       katz   KNN  0.833333
# 724   HC14       katz    LR  0.850000
# 725   HC14       katz  CART  0.633333
# 726   HC14       katz    NB  0.816667
# 727   HC14       katz   SVM  0.716667
# 728   HC15       katz   SVC  0.750000
# 729   HC15       katz   LDA  0.666667
# 730   HC15       katz   KNN  0.700000
# 731   HC15       katz    LR  0.733333
# 732   HC15       katz  CART  0.800000
# 733   HC15       katz    NB  0.666667
# 734   HC15       katz   SVM  0.633333
# 735   HC16       katz   SVC  0.766667
# 736   HC16       katz   LDA  0.700000
# 737   HC16       katz   KNN  0.833333
# 738   HC16       katz    LR  0.783333
# 739   HC16       katz  CART  0.666667
# 740   HC16       katz    NB  0.750000
# 741   HC16       katz   SVM  0.716667
# 742   HC17       katz   SVC  0.750000
# 743   HC17       katz   LDA  0.733333
# 744   HC17       katz   KNN  0.750000
# 745   HC17       katz    LR  0.800000
# 746   HC17       katz  CART  0.650000
# 747   HC17       katz    NB  0.716667
# 748   HC17       katz   SVM  0.650000
# 749   HC18       katz   SVC  0.716667
# 750   HC18       katz   LDA  0.633333
# 751   HC18       katz   KNN  0.650000
# 752   HC18       katz    LR  0.566667
# 753   HC18       katz  CART  0.683333
# 754   HC18       katz    NB  0.583333
# 755   HC18       katz   SVM  0.550000
# 756   HC01         ll   SVC  1.000000
# 757   HC01         ll   LDA  1.000000
# 758   HC01         ll   KNN  1.000000
# 759   HC01         ll    LR  0.900000
# 760   HC01         ll  CART  1.000000
# 761   HC01         ll    NB  1.000000
# 762   HC01         ll   SVM  0.933333
# 763   HC02         ll   SVC  0.966667
# 764   HC02         ll   LDA  0.966667
# 765   HC02         ll   KNN  1.000000
# 766   HC02         ll    LR  0.666667
# 767   HC02         ll  CART  0.950000
# 768   HC02         ll    NB  0.816667
# 769   HC02         ll   SVM  0.583333
# 770   HC03         ll   SVC  1.000000
# 771   HC03         ll   LDA  1.000000
# 772   HC03         ll   KNN  1.000000
# 773   HC03         ll    LR  0.983333
# 774   HC03         ll  CART  1.000000
# 775   HC03         ll    NB  1.000000
# 776   HC03         ll   SVM  1.000000
# 777   HC04         ll   SVC  0.966667
# 778   HC04         ll   LDA  0.966667
# 779   HC04         ll   KNN  0.950000
# 780   HC04         ll    LR  0.700000
# 781   HC04         ll  CART  0.966667
# 782   HC04         ll    NB  0.966667
# 783   HC04         ll   SVM  0.733333
# 784   HC05         ll   SVC  1.000000
# 785   HC05         ll   LDA  1.000000
# 786   HC05         ll   KNN  0.833333
# 787   HC05         ll    LR  0.716667
# 788   HC05         ll  CART  0.916667
# 789   HC05         ll    NB  0.883333
# 790   HC05         ll   SVM  0.716667
# 791   HC06         ll   SVC  0.950000
# 792   HC06         ll   LDA  0.966667
# 793   HC06         ll   KNN  0.950000
# 794   HC06         ll    LR  0.950000
# 795   HC06         ll  CART  0.933333
# 796   HC06         ll    NB  0.900000
# 797   HC06         ll   SVM  0.950000
# 798   HC07         ll   SVC  0.716667
# 799   HC07         ll   LDA  0.950000
# 800   HC07         ll   KNN  0.766667
# 801   HC07         ll    LR  0.466667
# 802   HC07         ll  CART  0.833333
# 803   HC07         ll    NB  0.783333
# 804   HC07         ll   SVM  0.616667
# 805   HC08         ll   SVC  0.850000
# 806   HC08         ll   LDA  0.933333
# 807   HC08         ll   KNN  0.766667
# 808   HC08         ll    LR  0.600000
# 809   HC08         ll  CART  0.800000
# 810   HC08         ll    NB  0.700000
# 811   HC08         ll   SVM  0.500000
# 812   HC09         ll   SVC  1.000000
# 813   HC09         ll   LDA  1.000000
# 814   HC09         ll   KNN  1.000000
# 815   HC09         ll    LR  0.650000
# 816   HC09         ll  CART  1.000000
# 817   HC09         ll    NB  1.000000
# 818   HC09         ll   SVM  1.000000
# 819   HC10         ll   SVC  0.933333
# 820   HC10         ll   LDA  0.950000
# 821   HC10         ll   KNN  0.983333
# 822   HC10         ll    LR  0.750000
# 823   HC10         ll  CART  0.933333
# 824   HC10         ll    NB  0.950000
# 825   HC10         ll   SVM  0.966667
# 826   HC11         ll   SVC  0.900000
# 827   HC11         ll   LDA  0.900000
# 828   HC11         ll   KNN  0.666667
# 829   HC11         ll    LR  0.500000
# 830   HC11         ll  CART  0.733333
# 831   HC11         ll    NB  0.733333
# 832   HC11         ll   SVM  0.716667
# 833   HC12         ll   SVC  1.000000
# 834   HC12         ll   LDA  1.000000
# 835   HC12         ll   KNN  1.000000
# 836   HC12         ll    LR  0.750000
# 837   HC12         ll  CART  0.950000
# 838   HC12         ll    NB  1.000000
# 839   HC12         ll   SVM  0.983333
# 840   HC13         ll   SVC  1.000000
# 841   HC13         ll   LDA  1.000000
# 842   HC13         ll   KNN  0.983333
# 843   HC13         ll    LR  0.950000
# 844   HC13         ll  CART  0.950000
# 845   HC13         ll    NB  0.983333
# 846   HC13         ll   SVM  0.850000
# 847   HC14         ll   SVC  0.883333
# 848   HC14         ll   LDA  0.916667
# 849   HC14         ll   KNN  0.916667
# 850   HC14         ll    LR  0.733333
# 851   HC14         ll  CART  0.900000
# 852   HC14         ll    NB  0.916667
# 853   HC14         ll   SVM  0.900000
# 854   HC15         ll   SVC  0.966667
# 855   HC15         ll   LDA  1.000000
# 856   HC15         ll   KNN  0.966667
# 857   HC15         ll    LR  0.500000
# 858   HC15         ll  CART  1.000000
# 859   HC15         ll    NB  0.933333
# 860   HC15         ll   SVM  0.783333
# 861   HC16         ll   SVC  0.950000
# 862   HC16         ll   LDA  0.900000
# 863   HC16         ll   KNN  0.866667
# 864   HC16         ll    LR  0.500000
# 865   HC16         ll  CART  0.850000
# 866   HC16         ll    NB  0.666667
# 867   HC16         ll   SVM  0.500000
# 868   HC17         ll   SVC  0.983333
# 869   HC17         ll   LDA  0.983333
# 870   HC17         ll   KNN  0.950000
# 871   HC17         ll    LR  0.500000
# 872   HC17         ll  CART  0.950000
# 873   HC17         ll    NB  0.983333
# 874   HC17         ll   SVM  0.750000
# 875   HC18         ll   SVC  1.000000
# 876   HC18         ll   LDA  0.933333
# 877   HC18         ll   KNN  0.883333
# 878   HC18         ll    LR  0.500000
# 879   HC18         ll  CART  0.983333
# 880   HC18         ll    NB  0.783333
# 881   HC18         ll   SVM  0.800000
# 882   HC01     mswpen   SVC  0.933333
# 883   HC01     mswpen   LDA  0.933333
# 884   HC01     mswpen   KNN  0.833333
# 885   HC01     mswpen    LR  0.950000
# 886   HC01     mswpen  CART  0.700000
# 887   HC01     mswpen    NB  0.816667
# 888   HC01     mswpen   SVM  0.616667
# 889   HC02     mswpen   SVC  0.916667
# 890   HC02     mswpen   LDA  0.733333
# 891   HC02     mswpen   KNN  0.666667
# 892   HC02     mswpen    LR  0.750000
# 893   HC02     mswpen  CART  0.700000
# 894   HC02     mswpen    NB  0.716667
# 895   HC02     mswpen   SVM  0.566667
# 896   HC03     mswpen   SVC  0.533333
# 897   HC03     mswpen   LDA  0.633333
# 898   HC03     mswpen   KNN  0.583333
# 899   HC03     mswpen    LR  0.550000
# 900   HC03     mswpen  CART  0.516667
# 901   HC03     mswpen    NB  0.600000
# 902   HC03     mswpen   SVM  0.600000
# 903   HC04     mswpen   SVC  0.683333
# 904   HC04     mswpen   LDA  0.650000
# 905   HC04     mswpen   KNN  0.650000
# 906   HC04     mswpen    LR  0.600000
# 907   HC04     mswpen  CART  0.616667
# 908   HC04     mswpen    NB  0.650000
# 909   HC04     mswpen   SVM  0.666667
# 910   HC05     mswpen   SVC  0.850000
# 911   HC05     mswpen   LDA  0.916667
# 912   HC05     mswpen   KNN  0.800000
# 913   HC05     mswpen    LR  0.800000
# 914   HC05     mswpen  CART  0.950000
# 915   HC05     mswpen    NB  0.816667
# 916   HC05     mswpen   SVM  0.750000
# 917   HC06     mswpen   SVC  0.516667
# 918   HC06     mswpen   LDA  0.566667
# 919   HC06     mswpen   KNN  0.516667
# 920   HC06     mswpen    LR  0.533333
# 921   HC06     mswpen  CART  0.500000
# 922   HC06     mswpen    NB  0.350000
# 923   HC06     mswpen   SVM  0.416667
# 924   HC07     mswpen   SVC  0.566667
# 925   HC07     mswpen   LDA  0.566667
# 926   HC07     mswpen   KNN  0.616667
# 927   HC07     mswpen    LR  0.650000
# 928   HC07     mswpen  CART  0.483333
# 929   HC07     mswpen    NB  0.683333
# 930   HC07     mswpen   SVM  0.550000
# 931   HC08     mswpen   SVC  0.533333
# 932   HC08     mswpen   LDA  0.716667
# 933   HC08     mswpen   KNN  0.566667
# 934   HC08     mswpen    LR  0.600000
# 935   HC08     mswpen  CART  0.533333
# 936   HC08     mswpen    NB  0.466667
# 937   HC08     mswpen   SVM  0.450000
# 938   HC09     mswpen   SVC  0.550000
# 939   HC09     mswpen   LDA  0.550000
# 940   HC09     mswpen   KNN  0.683333
# 941   HC09     mswpen    LR  0.583333
# 942   HC09     mswpen  CART  0.633333
# 943   HC09     mswpen    NB  0.600000
# 944   HC09     mswpen   SVM  0.633333
# 945   HC10     mswpen   SVC  0.766667
# 946   HC10     mswpen   LDA  0.800000
# 947   HC10     mswpen   KNN  0.783333
# 948   HC10     mswpen    LR  0.833333
# 949   HC10     mswpen  CART  0.600000
# 950   HC10     mswpen    NB  0.716667
# 951   HC10     mswpen   SVM  0.666667
# 952   HC11     mswpen   SVC  0.666667
# 953   HC11     mswpen   LDA  0.733333
# 954   HC11     mswpen   KNN  0.666667
# 955   HC11     mswpen    LR  0.766667
# 956   HC11     mswpen  CART  0.683333
# 957   HC11     mswpen    NB  0.616667
# 958   HC11     mswpen   SVM  0.600000
# 959   HC12     mswpen   SVC  0.550000
# 960   HC12     mswpen   LDA  0.566667
# 961   HC12     mswpen   KNN  0.766667
# 962   HC12     mswpen    LR  0.616667
# 963   HC12     mswpen  CART  0.666667
# 964   HC12     mswpen    NB  0.600000
# 965   HC12     mswpen   SVM  0.600000
# 966   HC13     mswpen   SVC  0.683333
# 967   HC13     mswpen   LDA  0.633333
# 968   HC13     mswpen   KNN  0.683333
# 969   HC13     mswpen    LR  0.700000
# 970   HC13     mswpen  CART  0.666667
# 971   HC13     mswpen    NB  0.700000
# 972   HC13     mswpen   SVM  0.516667
# 973   HC14     mswpen   SVC  0.783333
# 974   HC14     mswpen   LDA  0.633333
# 975   HC14     mswpen   KNN  0.783333
# 976   HC14     mswpen    LR  0.733333
# 977   HC14     mswpen  CART  0.600000
# 978   HC14     mswpen    NB  0.666667
# 979   HC14     mswpen   SVM  0.700000
# 980   HC15     mswpen   SVC  0.716667
# 981   HC15     mswpen   LDA  0.533333
# 982   HC15     mswpen   KNN  0.683333
# 983   HC15     mswpen    LR  0.633333
# 984   HC15     mswpen  CART  0.566667
# 985   HC15     mswpen    NB  0.616667
# 986   HC15     mswpen   SVM  0.583333
# 987   HC16     mswpen   SVC  0.816667
# 988   HC16     mswpen   LDA  0.666667
# 989   HC16     mswpen   KNN  0.566667
# 990   HC16     mswpen    LR  0.816667
# 991   HC16     mswpen  CART  0.633333
# 992   HC16     mswpen    NB  0.500000
# 993   HC16     mswpen   SVM  0.550000
# 994   HC17     mswpen   SVC  0.683333
# 995   HC17     mswpen   LDA  0.600000
# 996   HC17     mswpen   KNN  0.650000
# 997   HC17     mswpen    LR  0.700000
# 998   HC17     mswpen  CART  0.566667
# 999   HC17     mswpen    NB  0.600000
# 1000  HC17     mswpen   SVM  0.583333
# 1001  HC18     mswpen   SVC  0.633333
# 1002  HC18     mswpen   LDA  0.500000
# 1003  HC18     mswpen   KNN  0.533333
# 1004  HC18     mswpen    LR  0.600000
# 1005  HC18     mswpen  CART  0.550000
# 1006  HC18     mswpen    NB  0.483333
# 1007  HC18     mswpen   SVM  0.566667
# 1008  HC01     sample   SVC  0.950000
# 1009  HC01     sample   LDA  1.000000
# 1010  HC01     sample   KNN  0.966667
# 1011  HC01     sample    LR  0.966667
# 1012  HC01     sample  CART  0.900000
# 1013  HC01     sample    NB  0.950000
# 1014  HC01     sample   SVM  0.966667
# 1015  HC02     sample   SVC  0.933333
# 1016  HC02     sample   LDA  0.833333
# 1017  HC02     sample   KNN  0.916667
# 1018  HC02     sample    LR  0.950000
# 1019  HC02     sample  CART  0.766667
# 1020  HC02     sample    NB  0.833333
# 1021  HC02     sample   SVM  0.816667
# 1022  HC03     sample   SVC  0.833333
# 1023  HC03     sample   LDA  0.866667
# 1024  HC03     sample   KNN  0.900000
# 1025  HC03     sample    LR  0.933333
# 1026  HC03     sample  CART  0.833333
# 1027  HC03     sample    NB  0.666667
# 1028  HC03     sample   SVM  0.783333
# 1029  HC04     sample   SVC  0.883333
# 1030  HC04     sample   LDA  0.800000
# 1031  HC04     sample   KNN  0.816667
# 1032  HC04     sample    LR  0.916667
# 1033  HC04     sample  CART  0.766667
# 1034  HC04     sample    NB  0.666667
# 1035  HC04     sample   SVM  0.700000
# 1036  HC05     sample   SVC  0.883333
# 1037  HC05     sample   LDA  0.766667
# 1038  HC05     sample   KNN  0.816667
# 1039  HC05     sample    LR  0.850000
# 1040  HC05     sample  CART  0.883333
# 1041  HC05     sample    NB  0.800000
# 1042  HC05     sample   SVM  0.800000
# 1043  HC06     sample   SVC  0.683333
# 1044  HC06     sample   LDA  0.766667
# 1045  HC06     sample   KNN  0.766667
# 1046  HC06     sample    LR  0.833333
# 1047  HC06     sample  CART  0.650000
# 1048  HC06     sample    NB  0.700000
# 1049  HC06     sample   SVM  0.683333
# 1050  HC07     sample   SVC  0.750000
# 1051  HC07     sample   LDA  0.750000
# 1052  HC07     sample   KNN  0.666667
# 1053  HC07     sample    LR  0.750000
# 1054  HC07     sample  CART  0.883333
# 1055  HC07     sample    NB  0.750000
# 1056  HC07     sample   SVM  0.783333
# 1057  HC08     sample   SVC  0.750000
# 1058  HC08     sample   LDA  0.816667
# 1059  HC08     sample   KNN  0.633333
# 1060  HC08     sample    LR  0.766667
# 1061  HC08     sample  CART  0.800000
# 1062  HC08     sample    NB  0.583333
# 1063  HC08     sample   SVM  0.583333
# 1064  HC09     sample   SVC  1.000000
# 1065  HC09     sample   LDA  0.983333
# 1066  HC09     sample   KNN  0.966667
# 1067  HC09     sample    LR  1.000000
# 1068  HC09     sample  CART  0.966667
# 1069  HC09     sample    NB  0.950000
# 1070  HC09     sample   SVM  0.866667
# 1071  HC10     sample   SVC  0.883333
# 1072  HC10     sample   LDA  0.916667
# 1073  HC10     sample   KNN  0.866667
# 1074  HC10     sample    LR  0.950000
# 1075  HC10     sample  CART  0.883333
# 1076  HC10     sample    NB  0.833333
# 1077  HC10     sample   SVM  0.866667
# 1078  HC11     sample   SVC  0.750000
# 1079  HC11     sample   LDA  0.750000
# 1080  HC11     sample   KNN  0.716667
# 1081  HC11     sample    LR  0.816667
# 1082  HC11     sample  CART  0.783333
# 1083  HC11     sample    NB  0.616667
# 1084  HC11     sample   SVM  0.616667
# 1085  HC12     sample   SVC  0.983333
# 1086  HC12     sample   LDA  0.966667
# 1087  HC12     sample   KNN  0.900000
# 1088  HC12     sample    LR  0.933333
# 1089  HC12     sample  CART  0.900000
# 1090  HC12     sample    NB  0.616667
# 1091  HC12     sample   SVM  0.600000
# 1092  HC13     sample   SVC  0.983333
# 1093  HC13     sample   LDA  1.000000
# 1094  HC13     sample   KNN  0.933333
# 1095  HC13     sample    LR  0.966667
# 1096  HC13     sample  CART  0.950000
# 1097  HC13     sample    NB  0.833333
# 1098  HC13     sample   SVM  0.866667
# 1099  HC14     sample   SVC  0.866667
# 1100  HC14     sample   LDA  0.850000
# 1101  HC14     sample   KNN  0.916667
# 1102  HC14     sample    LR  0.883333
# 1103  HC14     sample  CART  0.816667
# 1104  HC14     sample    NB  0.800000
# 1105  HC14     sample   SVM  0.700000
# 1106  HC15     sample   SVC  0.866667
# 1107  HC15     sample   LDA  0.833333
# 1108  HC15     sample   KNN  0.916667
# 1109  HC15     sample    LR  0.916667
# 1110  HC15     sample  CART  0.933333
# 1111  HC15     sample    NB  0.700000
# 1112  HC15     sample   SVM  0.666667
# 1113  HC16     sample   SVC  0.766667
# 1114  HC16     sample   LDA  0.716667
# 1115  HC16     sample   KNN  0.766667
# 1116  HC16     sample    LR  0.816667
# 1117  HC16     sample  CART  0.666667
# 1118  HC16     sample    NB  0.750000
# 1119  HC16     sample   SVM  0.716667
# 1120  HC17     sample   SVC  0.916667
# 1121  HC17     sample   LDA  0.833333
# 1122  HC17     sample   KNN  0.783333
# 1123  HC17     sample    LR  0.916667
# 1124  HC17     sample  CART  0.800000
# 1125  HC17     sample    NB  0.683333
# 1126  HC17     sample   SVM  0.633333
# 1127  HC18     sample   SVC  0.783333
# 1128  HC18     sample   LDA  0.833333
# 1129  HC18     sample   KNN  0.683333
# 1130  HC18     sample    LR  0.700000
# 1131  HC18     sample  CART  0.716667
# 1132  HC18     sample    NB  0.516667
# 1133  HC18     sample   SVM  0.566667
# 1134  HC01       svd1   SVC  0.983333
# 1135  HC01       svd1   LDA  1.000000
# 1136  HC01       svd1   KNN  0.966667
# 1137  HC01       svd1    LR  0.966667
# 1138  HC01       svd1  CART  0.916667
# 1139  HC01       svd1    NB  0.933333
# 1140  HC01       svd1   SVM  0.950000
# 1141  HC02       svd1   SVC  0.950000
# 1142  HC02       svd1   LDA  0.833333
# 1143  HC02       svd1   KNN  0.850000
# 1144  HC02       svd1    LR  0.933333
# 1145  HC02       svd1  CART  0.783333
# 1146  HC02       svd1    NB  0.766667
# 1147  HC02       svd1   SVM  0.766667
# 1148  HC03       svd1   SVC  0.866667
# 1149  HC03       svd1   LDA  0.766667
# 1150  HC03       svd1   KNN  0.866667
# 1151  HC03       svd1    LR  0.933333
# 1152  HC03       svd1  CART  0.850000
# 1153  HC03       svd1    NB  0.683333
# 1154  HC03       svd1   SVM  0.683333
# 1155  HC04       svd1   SVC  0.816667
# 1156  HC04       svd1   LDA  0.750000
# 1157  HC04       svd1   KNN  0.800000
# 1158  HC04       svd1    LR  0.800000
# 1159  HC04       svd1  CART  0.716667
# 1160  HC04       svd1    NB  0.666667
# 1161  HC04       svd1   SVM  0.666667
# 1162  HC05       svd1   SVC  0.900000
# 1163  HC05       svd1   LDA  0.833333
# 1164  HC05       svd1   KNN  0.800000
# 1165  HC05       svd1    LR  0.816667
# 1166  HC05       svd1  CART  0.883333
# 1167  HC05       svd1    NB  0.800000
# 1168  HC05       svd1   SVM  0.766667
# 1169  HC06       svd1   SVC  0.650000
# 1170  HC06       svd1   LDA  0.683333
# 1171  HC06       svd1   KNN  0.683333
# 1172  HC06       svd1    LR  0.783333
# 1173  HC06       svd1  CART  0.650000
# 1174  HC06       svd1    NB  0.633333
# 1175  HC06       svd1   SVM  0.616667
# 1176  HC07       svd1   SVC  0.800000
# 1177  HC07       svd1   LDA  0.766667
# 1178  HC07       svd1   KNN  0.683333
# 1179  HC07       svd1    LR  0.800000
# 1180  HC07       svd1  CART  0.700000
# 1181  HC07       svd1    NB  0.733333
# 1182  HC07       svd1   SVM  0.766667
# 1183  HC08       svd1   SVC  0.700000
# 1184  HC08       svd1   LDA  0.700000
# 1185  HC08       svd1   KNN  0.650000
# 1186  HC08       svd1    LR  0.566667
# 1187  HC08       svd1  CART  0.850000
# 1188  HC08       svd1    NB  0.550000
# 1189  HC08       svd1   SVM  0.550000
# 1190  HC09       svd1   SVC  0.950000
# 1191  HC09       svd1   LDA  0.983333
# 1192  HC09       svd1   KNN  0.933333
# 1193  HC09       svd1    LR  0.950000
# 1194  HC09       svd1  CART  0.966667
# 1195  HC09       svd1    NB  0.883333
# 1196  HC09       svd1   SVM  0.916667
# 1197  HC10       svd1   SVC  0.866667
# 1198  HC10       svd1   LDA  0.900000
# 1199  HC10       svd1   KNN  0.916667
# 1200  HC10       svd1    LR  0.916667
# 1201  HC10       svd1  CART  0.783333
# 1202  HC10       svd1    NB  0.816667
# 1203  HC10       svd1   SVM  0.866667
# 1204  HC11       svd1   SVC  0.716667
# 1205  HC11       svd1   LDA  0.716667
# 1206  HC11       svd1   KNN  0.616667
# 1207  HC11       svd1    LR  0.716667
# 1208  HC11       svd1  CART  0.566667
# 1209  HC11       svd1    NB  0.633333
# 1210  HC11       svd1   SVM  0.633333
# 1211  HC12       svd1   SVC  0.983333
# 1212  HC12       svd1   LDA  0.966667
# 1213  HC12       svd1   KNN  0.950000
# 1214  HC12       svd1    LR  0.900000
# 1215  HC12       svd1  CART  0.916667
# 1216  HC12       svd1    NB  0.616667
# 1217  HC12       svd1   SVM  0.616667
# 1218  HC13       svd1   SVC  0.983333
# 1219  HC13       svd1   LDA  0.966667
# 1220  HC13       svd1   KNN  0.966667
# 1221  HC13       svd1    LR  0.966667
# 1222  HC13       svd1  CART  0.916667
# 1223  HC13       svd1    NB  0.900000
# 1224  HC13       svd1   SVM  0.933333
# 1225  HC14       svd1   SVC  0.800000
# 1226  HC14       svd1   LDA  0.900000
# 1227  HC14       svd1   KNN  0.883333
# 1228  HC14       svd1    LR  0.883333
# 1229  HC14       svd1  CART  0.816667
# 1230  HC14       svd1    NB  0.800000
# 1231  HC14       svd1   SVM  0.700000
# 1232  HC15       svd1   SVC  0.833333
# 1233  HC15       svd1   LDA  0.733333
# 1234  HC15       svd1   KNN  0.750000
# 1235  HC15       svd1    LR  0.750000
# 1236  HC15       svd1  CART  0.650000
# 1237  HC15       svd1    NB  0.583333
# 1238  HC15       svd1   SVM  0.550000
# 1239  HC16       svd1   SVC  0.833333
# 1240  HC16       svd1   LDA  0.800000
# 1241  HC16       svd1   KNN  0.783333
# 1242  HC16       svd1    LR  0.850000
# 1243  HC16       svd1  CART  0.733333
# 1244  HC16       svd1    NB  0.783333
# 1245  HC16       svd1   SVM  0.750000
# 1246  HC17       svd1   SVC  0.933333
# 1247  HC17       svd1   LDA  0.816667
# 1248  HC17       svd1   KNN  0.700000
# 1249  HC17       svd1    LR  0.883333
# 1250  HC17       svd1  CART  0.800000
# 1251  HC17       svd1    NB  0.716667
# 1252  HC17       svd1   SVM  0.533333
# 1253  HC18       svd1   SVC  0.733333
# 1254  HC18       svd1   LDA  0.750000
# 1255  HC18       svd1   KNN  0.633333
# 1256  HC18       svd1    LR  0.633333
# 1257  HC18       svd1  CART  0.666667
# 1258  HC18       svd1    NB  0.550000
# 1259  HC18       svd1   SVM  0.550000
# meas
# ll           0.874339
# cwpen        0.864021
# bubben       0.835847
# sample       0.816799
# approx       0.811640
# detrended    0.809656
# svd1         0.791138
# katz         0.775794
# LZc          0.769974
# mswpen       0.648810
# Name: values, dtype: float64
# algo
# SVC     0.860093
# LDA     0.840741
# KNN     0.818148
# LR      0.815185
# CART    0.791204
# NB      0.755741
# SVM     0.717500
# Name: values, dtype: float64
# group
# ll_LDA            0.964815
# ll_SVC            0.948148
# cwpen_SVC         0.931481
# cwpen_LDA         0.931481
# ll_CART           0.925000
# detrended_SVC     0.916667
# ll_KNN            0.915741
# bubben_SVC        0.904630
# ll_NB             0.888889
# cwpen_KNN         0.885185
# sample_LR         0.881481
# approx_LR         0.878704
# bubben_KNN        0.867593
# bubben_LDA        0.864815
# detrended_LDA     0.863889
# approx_SVC        0.862963
# sample_SVC        0.859259
# cwpen_CART        0.855556
# detrended_LR      0.853704
# cwpen_LR          0.852778
# svd1_SVC          0.850000
# approx_LDA        0.850000
# sample_LDA        0.849074
# svd1_LR           0.836111
# bubben_LR         0.834259
# approx_KNN        0.830556
# cwpen_NB          0.830556
# bubben_NB         0.830556
# katz_LR           0.829630
# sample_KNN        0.829630
# sample_CART       0.827778
# svd1_LDA          0.825926
# LZc_SVC           0.821296
# katz_SVC          0.818519
# detrended_KNN     0.811111
# LZc_LR            0.811111
# approx_CART       0.810185
# detrended_CART    0.805556
# svd1_KNN          0.801852
# katz_LDA          0.800000
# LZc_LDA           0.794444
# ll_SVM            0.793519
# LZc_KNN           0.787963
# svd1_CART         0.787037
# bubben_CART       0.785185
# katz_KNN          0.783333
# LZc_CART          0.766667
# bubben_SVM        0.763889
# cwpen_SVM         0.761111
# katz_NB           0.745370
# sample_NB         0.736111
# approx_NB         0.734259
# sample_SVM        0.734259
# katz_CART         0.728704
# katz_SVM          0.725000
# svd1_NB           0.725000
# detrended_NB      0.723148
# LZc_NB            0.721296
# approx_SVM        0.714815
# svd1_SVM          0.712037
# detrended_SVM     0.693519
# mswpen_LR         0.689815
# mswpen_SVC        0.687963
# LZc_SVM           0.687037
# ll_LR             0.684259
# mswpen_KNN        0.668519
# mswpen_LDA        0.662963
# mswpen_NB         0.622222
# mswpen_CART       0.620370
# mswpen_SVM        0.589815
# Name: values, dtype: float64
#
# ___ANOVA Table____________________________________________________________
#                       df     sum_sq   mean_sq          F        PR(>F)
# C(meas)             9.0   4.516483  0.501831  39.369136  1.183566e-61
# C(algo)             6.0   2.641159  0.440193  34.533556  1.324855e-38
# C(meas):C(algo)    54.0   1.512201  0.028004   2.196918  2.294199e-06
# Residual         1190.0  15.168719  0.012747        NaN           NaN
# __________________________________________________________________________
# C(meas): p = 0.0
# C(algo): p = 0.0
# C(meas):C(algo): p = 0.0
#
# Tukey's test
#    Multiple Comparison of Means - Tukey HSD, FWER=0.01
# ==========================================================
#   group1    group2  meandiff p-adj   lower   upper  reject
# ----------------------------------------------------------
#       LZc    approx   0.0417 0.1914 -0.0156  0.0989  False
#       LZc    bubben   0.0659 0.0012  0.0086  0.1231   True
#       LZc     cwpen    0.094    0.0  0.0368  0.1513   True
#       LZc detrended   0.0397 0.2516 -0.0176  0.0969  False
#       LZc      katz   0.0058    1.0 -0.0514  0.0631  False
#       LZc        ll   0.1044    0.0  0.0471  0.1616   True
#       LZc    mswpen  -0.1212    0.0 -0.1784 -0.0639   True
#       LZc    sample   0.0468 0.0838 -0.0104  0.1041  False
#       LZc      svd1   0.0212 0.9413 -0.0361  0.0784  False
#    approx    bubben   0.0242 0.8735 -0.0331  0.0815  False
#    approx     cwpen   0.0524  0.029 -0.0049  0.1096  False
#    approx detrended   -0.002    1.0 -0.0592  0.0553  False
#    approx      katz  -0.0358 0.3972 -0.0931  0.0214  False
#    approx        ll   0.0627 0.0027  0.0054    0.12   True
#    approx    mswpen  -0.1628    0.0 -0.2201 -0.1056   True
#    approx    sample   0.0052    1.0 -0.0521  0.0624  False
#    approx      svd1  -0.0205 0.9517 -0.0778  0.0368  False
#    bubben     cwpen   0.0282 0.7362 -0.0291  0.0854  False
#    bubben detrended  -0.0262 0.8112 -0.0835  0.0311  False
#    bubben      katz  -0.0601 0.0052 -0.1173 -0.0028   True
#    bubben        ll   0.0385 0.2929 -0.0188  0.0958  False
#    bubben    mswpen   -0.187    0.0 -0.2443 -0.1298   True
#    bubben    sample   -0.019 0.9699 -0.0763  0.0382  False
#    bubben      svd1  -0.0447 0.1199  -0.102  0.0126  False
#     cwpen detrended  -0.0544 0.0191 -0.1116  0.0029  False
#     cwpen      katz  -0.0882    0.0 -0.1455  -0.031   True
#     cwpen        ll   0.0103 0.9997 -0.0469  0.0676  False
#     cwpen    mswpen  -0.2152    0.0 -0.2725 -0.1579   True
#     cwpen    sample  -0.0472 0.0782 -0.1045    0.01  False
#     cwpen      svd1  -0.0729 0.0002 -0.1301 -0.0156   True
# detrended      katz  -0.0339  0.484 -0.0911  0.0234  False
# detrended        ll   0.0647 0.0016  0.0074  0.1219   True
# detrended    mswpen  -0.1608    0.0 -0.2181 -0.1036   True
# detrended    sample   0.0071    1.0 -0.0501  0.0644  False
# detrended      svd1  -0.0185  0.975 -0.0758  0.0387  False
#      katz        ll   0.0985    0.0  0.0413  0.1558   True
#      katz    mswpen   -0.127    0.0 -0.1842 -0.0697   True
#      katz    sample    0.041 0.2102 -0.0163  0.0983  False
#      katz      svd1   0.0153 0.9934 -0.0419  0.0726  False
#        ll    mswpen  -0.2255    0.0 -0.2828 -0.1683   True
#        ll    sample  -0.0575 0.0094 -0.1148 -0.0003   True
#        ll      svd1  -0.0832    0.0 -0.1405 -0.0259   True
#    mswpen    sample    0.168    0.0  0.1107  0.2253   True
#    mswpen      svd1   0.1423    0.0  0.0851  0.1996   True
#    sample      svd1  -0.0257 0.8292 -0.0829  0.0316  False
# ----------------------------------------------------------
# Multiple Comparison of Means - Tukey HSD, FWER=0.01
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   CART    KNN   0.0269 0.4375 -0.0205  0.0744  False
#   CART    LDA   0.0495 0.0058  0.0021   0.097   True
#   CART     LR    0.024 0.5829 -0.0235  0.0714  False
#   CART     NB  -0.0355 0.1309 -0.0829   0.012  False
#   CART    SVC   0.0689    0.0  0.0214  0.1163   True
#   CART    SVM  -0.0737    0.0 -0.1211 -0.0263   True
#    KNN    LDA   0.0226 0.6511 -0.0249    0.07  False
#    KNN     LR   -0.003    1.0 -0.0504  0.0445  False
#    KNN     NB  -0.0624 0.0001 -0.1099  -0.015   True
#    KNN    SVC   0.0419 0.0366 -0.0055  0.0894  False
#    KNN    SVM  -0.1006    0.0 -0.1481 -0.0532   True
#    LDA     LR  -0.0256 0.5048  -0.073  0.0219  False
#    LDA     NB   -0.085    0.0 -0.1324 -0.0376   True
#    LDA    SVC   0.0194 0.7958 -0.0281  0.0668  False
#    LDA    SVM  -0.1232    0.0 -0.1707 -0.0758   True
#     LR     NB  -0.0594 0.0003 -0.1069  -0.012   True
#     LR    SVC   0.0449 0.0186 -0.0025  0.0924  False
#     LR    SVM  -0.0977    0.0 -0.1451 -0.0502   True
#     NB    SVC   0.1044    0.0  0.0569  0.1518   True
#     NB    SVM  -0.0382 0.0786 -0.0857  0.0092  False
#    SVC    SVM  -0.1426    0.0   -0.19 -0.0951   True
# ----------------------------------------------------
# qt.xkb.compose: failed to create compose table

# %%
## updated NEWDATA
#################

print('\n\n\n\n\n#############################################################\nssHC_ssP - Statistics\n#############################################################')
df = stackresult.copy()
data = stackresult.copy()
stackeddf = stackresult.copy()
#******************************************************************#
# Table 1 - Descriptive statistics
#******************************************************************#
meandf = stackeddf.copy()
means = stackeddf.groupby('meas')['values'].mean()# calculate the mean of the 'value' column for each category
meas=means.sort_values(ascending=False)
means2 = stackeddf.groupby('algo')['values'].mean()
algos=means2.sort_values(ascending=False)
# meandf.columns = [col[0]+col[1] for col in meandf.columns]
meandf['group'] = meandf['meas'].astype(str) + '_' + meandf['algo'].astype(str)
mix = meandf.groupby('group')['values'].mean()
mix2=mix.sort_values(ascending=False)
# print(meas)
# print(algos)
# print (mix2,'\n')
# desc_stats = df.groupby(['meas', 'algo'])['values'].describe()
# display(desc_stats)
import scipy.stats as stats #wont workw/out imports
grouped = df.groupby(['meas', 'algo'])
stats_df = pd.DataFrame()
stats_df['Sample Size'] = grouped['values'].count()
stats_df['Mean (M)'] = grouped['values'].mean()
stats_df['Standard Deviation (SD)'] = grouped['values'].std()
stats_df['Standard Error of the Mean (SEM)'] = grouped['values'].sem()
stats_df['Skewness'] = grouped['values'].apply(lambda x: stats.skew(x))
stats_df['Kurtosis'] = grouped['values'].apply(lambda x: stats.kurtosis(x))
display(stats_df)
# stats_df['Mean (M)'].idxmax()



# pgrm = pg.rm_anova(dv='values', within=['meas', 'algo'], subject='ID', data=data)
# pgrm.round(3)
# Out:
# #############################################################
# ssHC_ssP - Statistics
# #############################################################
#                 Sample Size  Mean (M)  Standard Deviation (SD)  \
# meas      algo
# approx    CART           18  0.810185                 0.123556
#           KNN            18  0.830556                 0.103729
#           LDA            18  0.850000                 0.088006
#           LR             18  0.878704                 0.093376
#           NB             18  0.734259                 0.116663
#           SVC            18  0.862963                 0.098445
#           SVM            18  0.714815                 0.127941
# bubben    CART           18  0.785185                 0.133442
#           KNN            18  0.867593                 0.115395
#           LDA            18  0.864815                 0.102084
#           LR             18  0.834259                 0.098928
#           NB             18  0.830556                 0.128751
#           SVC            18  0.904630                 0.134165
#           SVM            18  0.763889                 0.129258
# cwpen     CART           18  0.855556                 0.095144
#           KNN            18  0.885185                 0.091625
#           LDA            18  0.931481                 0.058547
#           LR             18  0.852778                 0.113795
#           NB             18  0.830556                 0.158861
#           SVC            18  0.931481                 0.073629
#           SVM            18  0.761111                 0.156869
# detrended CART           18  0.805556                 0.105099
#           KNN            18  0.811111                 0.116035
#           LDA            18  0.863889                 0.096041
#           LR             18  0.853704                 0.108398
#           NB             18  0.723148                 0.121017
#           SVC            18  0.916667                 0.064423
#           SVM            18  0.693519                 0.109087
# katz      CART           18  0.728704                 0.118516
#           KNN            18  0.783333                 0.109066
#           LDA            18  0.800000                 0.130234
#           LR             18  0.829630                 0.134256
#           NB             18  0.745370                 0.089808
#           SVC            18  0.818519                 0.115171
#           SVM            18  0.725000                 0.123570
# ll        CART           18  0.925000                 0.075678
#           KNN            18  0.915741                 0.099257
#           LDA            18  0.964815                 0.036105
#           LR             18  0.684259                 0.174096
#           NB             18  0.888889                 0.112894
#           SVC            18  0.948148                 0.073184
#           SVM            18  0.793519                 0.167170
# mswpen    CART           18  0.620370                 0.106574
#           KNN            18  0.668519                 0.095124
#           LDA            18  0.662963                 0.123611
#           LR             18  0.689815                 0.113203
#           NB             18  0.622222                 0.118955
#           SVC            18  0.687963                 0.133921
#           SVM            18  0.589815                 0.081075
# sample    CART           18  0.827778                 0.092708
#           KNN            18  0.829630                 0.106267
#           LDA            18  0.849074                 0.089930
#           LR             18  0.881481                 0.084770
#           NB             18  0.736111                 0.119674
#           SVC            18  0.859259                 0.094319
#           SVM            18  0.734259                 0.115112
# svd1      CART           18  0.787037                 0.112975
#           KNN            18  0.801852                 0.120577
#           LDA            18  0.825926                 0.103410
#           LR             18  0.836111                 0.114368
#           NB             18  0.725000                 0.118577
#           SVC            18  0.850000                 0.104005
#           SVM            18  0.712037                 0.137176
#
#                 Standard Error of the Mean (SEM)  Skewness  Kurtosis
# meas      algo
# approx    CART                          0.029122 -0.493235 -0.407372
#           KNN                           0.024449 -0.394103 -1.250288
#           LDA                           0.020743  0.081402 -0.469156
#           LR                            0.022009 -0.751003 -0.456499
#           NB                            0.027498  0.117571 -0.518760
#           SVC                           0.023204 -0.434820 -0.608279
#           SVM                           0.030156  0.302933 -0.933502
# bubben    CART                          0.031453 -1.198806  1.021410
#           KNN                           0.027199 -1.250088  0.995061
#           LDA                           0.024062 -1.218372  1.180186
#           LR                            0.023317 -0.565224 -0.365044
#           NB                            0.030347 -0.564800 -0.716931
#           SVC                           0.031623 -2.331099  4.763869
#           SVM                           0.030466 -0.280498 -1.103435
# cwpen     CART                          0.022426 -0.258557 -0.950019
#           KNN                           0.021596 -1.215812  1.311746
#           LDA                           0.013800 -0.910495  0.288858
#           LR                            0.026822 -1.024118  0.752238
#           NB                            0.037444 -0.946024 -0.329259
#           SVC                           0.017354 -1.612867  2.073513
#           SVM                           0.036974 -0.091420 -1.362116
# detrended CART                          0.024772 -0.271964 -1.009051
#           KNN                           0.027350 -0.473054 -0.651593
#           LDA                           0.022637 -0.646157  0.484602
#           LR                            0.025550 -0.566659 -0.793294
#           NB                            0.028524  0.287181 -0.692509
#           SVC                           0.015185 -0.345859 -1.171430
#           SVM                           0.025712  1.101735  0.638931
# katz      CART                          0.027934  0.044059 -0.627634
#           KNN                           0.025707 -0.156811 -1.014506
#           LDA                           0.030696 -0.237490 -1.189214
#           LR                            0.031644 -0.453054 -0.740523
#           NB                            0.021168 -0.121194 -0.642599
#           SVC                           0.027146  0.086101 -1.347256
#           SVM                           0.029126  0.212523 -0.953049
# ll        CART                          0.017837 -1.142459  0.492172
#           KNN                           0.023395 -1.171615  0.332971
#           LDA                           0.008510 -0.532190 -1.036212
#           LR                            0.041035  0.376510 -1.085250
#           NB                            0.026609 -0.682560 -0.930809
#           SVC                           0.017250 -1.960866  3.599782
#           SVM                           0.039402 -0.375898 -1.021027
# mswpen    CART                          0.025120  1.525690  3.126067
#           KNN                           0.022421  0.131977 -1.008312
#           LDA                           0.029135  0.915374  0.020753
#           LR                            0.026682  0.589341 -0.416551
#           NB                            0.028038 -0.405987  0.031714
#           SVC                           0.031565  0.374741 -0.986063
#           SVM                           0.019110 -0.227887  0.164005
# sample    CART                          0.021851 -0.365521 -0.756842
#           KNN                           0.025047 -0.407498 -1.099584
#           LDA                           0.021197  0.472956 -0.929481
#           LR                            0.019980 -0.645598 -0.630114
#           NB                            0.028207  0.155431 -0.626722
#           SVC                           0.022231 -0.188523 -1.057145
#           SVM                           0.027132  0.271872 -0.916326
# svd1      CART                          0.026628 -0.210072 -0.946702
#           KNN                           0.028420 -0.077786 -1.373203
#           LDA                           0.024374  0.397394 -1.175634
#           LR                            0.026957 -0.879176 -0.004595
#           NB                            0.027949  0.131101 -1.055917
#           SVC                           0.024514 -0.312354 -0.964340
#           SVM                           0.032333  0.382470 -1.020172

# %%
# NEW-COMPLETE

#Plot
fig, ax = plt.subplots(figsize=(10, 6))
# df_unstacked.plot(kind='bar', ax=ax)
sns.boxplot(data=df,ax=ax, x='algo', y='values', hue='meas')
plt.title('HC Models and measures individual particpant performance') #'Measures(9) x Algorithms(7)') # ax.set_title('Measures(9) x Algorithms(7)')
plt.ylabel("Accuracy")
plt.xlabel("Models")
plt.ylim(0.4, 1.0)
legend = plt.legend(loc='upper left',bbox_to_anchor=(1, 1))#,fontsize='x-small', labelspacing=0.05)
legend.set_title('Measures')
new_labels = ['Approx','bubbEn','CWPEn','Detrended','Katz','LL','MSWPEn','Sample','SVD','LZc']
for t, l in zip(legend.texts, new_labels): t.set_text(l)
plt.show()

# %% [markdown]
# ## using less features (HC)

# %%
# NEW-COMPLETE

# %% [markdown]
# ## Top performing featues are:
# - Model Algorithm
#     - SVC (Support Vector Classification)
#     - LDA (Linear Discriminant Analysis)
#
# - Complexity
#     - LL (Fractal Line Length index)
#     - CWPEn (Conditional Weighted Permutation Entropy)

# %% [markdown]
# # PART 2: Patients (w/ top measures and models)

# %%
#(1)
## updated NEWDATA
#################










#MAX's way (5) - PT (IT vs ST)                        ( MAIN )
#####################################################################################################################    
##                                                                                                                 ##
##                 LOADING DATAFRAME & RESHAPING IT    +  NEW DICTIONARIES                                         ## 
ICU27sedoff_ST': 'OFF', 'NETICU27sedon1_IT': 'ON', 'NETICU27sedon1_RS': 'ON', 'NETICU27sedon1_ST': 'ON', 'NETICU28sedoff_IT': 'OFF', 'NETICU28sedoff_RS': 'OFF', 'NETICU28sedoff_ST': 'OFF', 'NETICU28sedon1_IT': 'ON', 'NETICU28sedon1_RS': 'ON', 'NETICU28sedon1_ST': 'ON', 'NETICU29sedoff_IT': 'OFF', 'NETICU29sedoff_RS': 'OFF', 'NETICU29sedoff_ST': 'OFF', 'NETICU29sedon1_IT': 'ON', 'NETICU29sedon1_RS': 'ON', 'NETICU29sedon1_ST': 'ON', 'NETICU30sedoff_IT': 'OFF', 'NETICU30sedoff_RS': 'OFF', 'NETICU30sedoff_ST': 'OFF', 'NETICU30sedon1_IT': 'ON', 'NETICU30sedon1_RS': 'ON', 'NETICU30sedon1_ST': 'ON', 'NETICU31sedoff_IT': 'OFF', 'NETICU31sedoff_RS': 'OFF', 'NETICU31sedoff_ST': 'OFF', 'NETICU31sedon1_IT': 'ON', 'NETICU31sedon1_ST': 'ON', 'NETICU31sedon2_RS': 'ON', 'NETICU33sedoff_RS': 'OFF', 'NETICU33sedon1_IT': 'ON', 'NETICU33sedon1_RS': 'ON', 'NETICU33sedon1_ST': 'ON', 'NETICU38sedon1_IT': 'ON', 'NETICU38sedon1_RS': 'ON', 'NETICU38sedon1_ST': 'ON', 'NETICU40sedoff_IT': 'OFF', 'NETICU40sedoff_RS': 'OFF', 'NETICU40sedoff_ST': 'OFF', 'NETICU40sedon1_IT': 'ON', 'NETICU40sedon1_RS': 'ON', 'NETICU40sedon1_ST': 'ON', 'NETICU41sedoff_IT': 'OFF', 'NETICU41sedoff_RS': 'OFF', 'NETICU41sedoff_ST': 'OFF', 'NETICU41sedon1_IT': 'ON', 'NETICU41sedon1_RS': 'ON', 'NETICU41sedon1_ST': 'ON', 'NETICU41sedon2_IT': 'ON', 'NETICU41sedon2_RS': 'ON', 'NETICU41sedon2_ST': 'ON', 'NETICU46sedoff_RS': 'OFF', 'NETICU46sedon1_IT': 'ON', 'NETICU46sedon1_RS': 'ON', 'NETICU46sedon1_ST': 'ON'}
GCSdic={'CCTC03_IT': '3', 'CCTC03_RS': '3', 'CCTC03_ST': '3', 'CCTC03part2_IT': '3', 'CCTC03part2_RS': '3', 'CCTC03part2_ST': '3', 'CCTC04_IT': '3', 'CCTC04_RS': '3', 'CCTC04_RSredo': '3', 'CCTC04_ST': '3', 'CCTC05_IT': '3', 'CCTC05_RS': '3', 'CCTC05_ST': '3', 'CCTC07NETICUsedoff_IT': '7', 'CCTC07NETICUsedoff_RS': '7', 'CCTC07NETICUsedoff_ST': '7', 'CCTC07NETICUsedon1_IT': '4', 'CCTC07NETICUsedon1_RS': '4', 'CCTC07NETICUsedon1_ST': '4', 'CCTC07_IT': '5', 'CCTC07_RS': '5', 'CCTC07_ST': '5', 'HC01_IT': '15', 'HC01_ST': '15', 'HC02_IT': '15', 'HC02_ST': '15', 'HC03_IT': '15', 'HC03_ST':
ICU03sedoff_IT': '6', 'NETICU03sedoff_RS': '6', 'NETICU03sedoff_ST': '6', 'NETICU03sedon1_IT': '6', 'NETICU03sedon1_RS': '6', 'NETICU03sedon1_ST': '6', 'NETICU04sedoff_IT': '3', 'NETICU04sedoff_RS': '3', 'NETICU04sedoff_ST': '3', 'NETICU04sedon1_IT': '3', 'NETICU04sedon1_RS': '3', 'NETICU04sedon1_ST': '3', 'NETICU05sedoff_IT': '3', 'NETICU05sedoff_RS': '3', 'NETICU05sedoff_ST': '3', 'NETICU05sedon1_IT': '3', 'NETICU05sedon1_RS': '3', 'NETICU05sedon1_ST': '3', 'NETICU06sedoff_IT': '6', 'NETICU06sedoff_RS': '6', 'NETICU06sedoff_ST': '6', 'NETICU06sedon1_IT': '3', 'NETICU06sedon1_RS': '3', 'NETICU06sedon1_ST': '3', 'NETICU08sedoff_IT': '9', 'NETICU08sedoff_ST': '9', 'NETICU08sedon2_IT': '3', 'NETICU08sedon2_RS': '3', 'NETICU08sedon2_ST': '3', 'NETICU11sedoff_IT': '4', 'NETICU11sedoff_RS': '4', 'NETICU11sedoff_ST': '4', 'NETICU11sedon1_IT': '3', 'NETICU11sedon1_RS': '3', 'NETICU11sedon1_ST': '3', 'NETICU13sedoff_IT': '4', 'NETICU13sedoff_RS': '4', 'NETICU13sedoff_ST': '4', 'NETICU13sedon1_IT': '3', 'NETICU13sedon1_RS': '3', 'NETICU13sedon1_ST': '3', 'NETICU15sedoff_IT': '3', 'NETICU15sedoff_RS': '3', 'NETICU15sedoff_ST': '3', 'NETICU15sedon1_IT': '3', 'NETICU15sedon1_RS': '3', 'NETICU15sedon1_ST': '3', 'NETICU17sedoff_IT': '10', 'NETICU17sedoff_RS': '10', 'NETICU17sedoff_ST': '10', 'NETICU17sedon1_IT': '3', 'NETICU17sedon1_RS': '3', 'NETICU17sedon1_ST': '3', 'NETICU18sedoff_RS': '11', 'NETICU18sedon1_IT': '3', 'NETICU18sedon1_RS': '3', 'NETICU18sedon1_ST': '3', 'NETICU19sedoff_IT': '7', 'NETICU19sedoff_RS': '7', 'NETICU19sedoff_ST': '7', 'NETICU19sedon1_IT': '3', 'NETICU19sedon1_RS': '3', 'NETICU19sedon1_ST': '3', 'NETICU20sedoff_RS': '11', 'NETICU20sedon1_IT': '3', 'NETICU20sedon1_RS': '3', 'NETICU20sedon1_ST': '3', 'NETICU22sedoff_IT': '3', 'NETICU22sedoff_RS': '3', 'NETICU22sedoff_ST': '3', 'NETICU22sedon1_IT': '3', 'NETICU22sedon1_RS': '3', 'NETICU22sedon1_ST': '3', 'NETICU24sedoff_IT': '3', 'NETICU24sedoff_RS': '3', 'NETICU24sedoff_ST': '3', 'NETICU24sedon1_IT': '3', 'NETICU24sedon1_RS': '3', 'NETICU24sedon1_ST': '3', 'NETICU25sedoff_RS': '8', 'NETICU25sedon1_IT': '6', 'NETICU25sedon1_RS': '6', 'NETICU25sedon1_ST': '6', 'NETICU27sedoff_IT': '3', 'NETICU27sedoff_RS': '3', 'NETICU27sedoff_ST': '3', 'NETICU27sedon1_IT': '3', 'NETICU27sedon1_RS': '3', 'NETICU27sedon1_ST': '3', 'NETICU28sedoff_IT': '3', 'NETICU28sedoff_RS': '3', 'NETICU28sedoff_ST': '3', 'NETICU28sedon1_IT': '3', 'NETICU28sedon1_RS': '3', 'NETICU28sedon1_ST': '3', 'NETICU29sedoff_IT': '11', 'NETICU29sedoff_RS': '11', 'NETICU29sedoff_ST': '11', 'NETICU29sedon1_IT': '3', 'NETICU29sedon1_RS': '3', 'NETICU29sedon1_ST': '3', 'NETICU30sedoff_IT': '6', 'NETICU30sedoff_RS': '6', 'NETICU30sedoff_ST': '6', 'NETICU30sedon1_IT': '3', 'NETICU30sedon1_RS': '3', 'NETICU30sedon1_ST': '3', 'NETICU31sedoff_IT': '10', 'NETICU31sedoff_RS': '10', 'NETICU31sedoff_ST': '10', 'NETICU31sedon1_IT': '3', 'NETICU31sedon1_ST': '3', 'NETICU31sedon2_RS': '6', 'NETICU33sedoff_RS': '5', 'NETICU33sedon1_IT': '3', 'NETICU33sedon1_RS': '3', 'NETICU33sedon1_ST': '3', 'NETICU38sedon1_IT': '3', 'NETICU38sedon1_RS': '3', 'NETICU38sedon1_ST': '3', 'NETICU40sedoff_IT': '9', 'NETICU40sedoff_RS': '9', 'NETICU40sedoff_ST': '9', 'NETICU40sedon1_IT': '3', 'NETICU40sedon1_RS': '3', 'NETICU40sedon1_ST': '3', 'NETICU41sedoff_IT': '3', 'NETICU41sedoff_RS': '3', 'NETICU41sedoff_ST': '3', 'NETICU41sedon1_IT': '3', 'NETICU41sedon1_RS': '3', 'NETICU41sedon1_ST': '3', 'NETICU41sedon2_IT': '3', 'NETICU41sedon2_RS': '3', 'NETICU41sedon2_ST': '3', 'NETICU46sedoff_RS': '8', 'NETICU46sedon1_IT': '3', 'NETICU46sedon1_RS': '3', 'NETICU46sedon1_ST': '3'}
######################################################################################################################
for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        vars()[m+'_'+window]= pd.read_csv(f'./results/NewDataResults/save/{window}/{m}/{m}_{window}.csv')
        vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
        vars()[m+'_'+window].set_index('ID', inplace=True)
        #------------------------------------------------------------------------------------------###
        df = vars()[m+'_'+window].copy()#                                                          ###
        ssfnames = [f for f in df.index if 'HC05_IT1st' not in f]#                                 ###
        #print(f'\n{m}_{window}\n{len(df.index)}-{len(ssfnames)} = {len(df.index)-len(ssfnames)}') ###
        #---------------------------------------######################################################
        df = df.loc[ssfnames] #using ssfnames   ###
        odf = df.copy()#old dataframe           ###
        #odf = odf[odf.index.str.contains('HC')]###
        ###########################################
        IDlist=[]
        chaa=[]
        for f in odf.index:
            a,b,c = f.split('_')
            if 'HC05_IT2nd' in f:
                ID = a+'_'+b[:-3]
            else:
                ID = a+'_'+b
            IDlist.append(ID)
            for el in Echan:
                if el == c:
                    chaa.append(el)
        odf.insert(0,'el',chaa)
        odf.insert(0, 'IDlist', IDlist)
        # did i need to rename colunmns to range(10,40) for sorting????or is it already sorted?
        columns=odf.columns.tolist()
        columns[2:] = [str(i) for i in range(10,40)]
        odf.columns = columns  
        values = [a+b for a in string.ascii_lowercase for b in string.ascii_lowercase]
        mappings = dict(zip(Echan, values))
        mappings2 = dict(zip(values, Echan))
        odf['sortby'] = odf['el'].map(mappings)
        odf.drop('el',inplace=True,axis=1)
        odf=odf.pivot(index='sortby',columns = 'IDlist',values=[str(i) for i in range(10,40)])
        odf = odf.swaplevel(i=-2, j=-1, axis=1)
        odf = odf.sort_index(axis=1)
        odf.reset_index(level='sortby', inplace=True)
        odf['el'] = odf['sortby'].map(mappings2)
        odf.set_index('el', append=False, inplace=True)
        with io.capture_output() as captured:
            odf.drop('sortby',inplace=True,axis=1)
        odf=odf.transpose()
        odf.reset_index(level=1, inplace=True) # Moving timpoints/index-level_1 from index to column to (1) rename them & (2) to create Task-List from index-level_0 for Task Column
        timekeys= [str(i) for i in range(10,40)]#    (1)
        timevalues = [str(i) for i in range(30)]
        mappings3 = dict(zip(timekeys,timevalues))
        odf['windows']=odf['level_1'].map(mappings3)
        Tlist=[]#                                    (2)
        for f in odf.index:
            for Task in ['RS','ST','IT']:
                if Task in f:
                    T = Task
                    Tlist.append(T)
        odf.insert(0, 'Task', Tlist)
        odf.set_index('windows', append=True, inplace=True)
        # odf = odf.add_suffix(f'_{m}')
        odf.drop('level_1',inplace=True,axis=1)
        odf = odf[(odf['Task']=='IT') | (odf['Task']=='ST')]
        odf = odf[~odf.index.get_level_values('IDlist').str.contains('HC')]
        
    # DATAFRAMES______________________________________________________________________________#
    
    # (1) Final Dataframe = vars()['PT_'+m+'_'+window] = PT_ll_10secwindows  =  odf
        vars()['PT_'+m+'_'+window]=odf.copy()
    
    # (2) Individual Dataframes = vars()[P+'df_'+m+'_'+window] = NETICU01sedoffdf_ll_10secwindows
        PT = []
        for i in odf.index.get_level_values(0):
            x = i.split('_')[0]
            if x not in PT:
                PT.append(x)
        print ('len(PT)=',len(PT))
        for P in PT:
            vars()[P+'df_'+m+'_'+window]=odf.loc[([f'{P}_IT',f'{P}_ST']),:]##EXAMPLES-->>>##odf.loc[(['HC01_IT','HC01_ST'],'0'),:] ##odf.xs(key=('0'), level='windows').loc[['HC01_IT', 'HC01_ST']] ##odf.xs(('HC01_ST'), axis=0, level='IDlist')
            vars()[P+'df_'+m+'_'+window].index = ['_'.join(i) for i in vars()[P+'df_'+m+'_'+window].index] #combine both levels of index into one (i.e., 'HC01_IT_0')
            
            
#####################################################################################################################    
##                                                                                                                 ##
##                    MACHINE LEARNING                                                                             ## 
#####################################################################################################################    
from sklearn.model_selection import StratifiedKFold
import random
random.seed(42)
models = []
#models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
#models.append(('KNN', KNeighborsClassifier()))
#models.append(('CART', DecisionTreeClassifier(random_state=42)))
#models.append(('NB', GaussianNB()))
#models.append(('SVM', SVC(gamma='auto',kernel='rbf',random_state=42))) 
models.append(('SVC', SVC(gamma='scale', kernel='poly',random_state=42))) 

measures=['ll','cwpen']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']

accuracy_dict = {m: {model[0]: [] for model in models} for m in measures} #[X]
accuracy_dict2 = {m: {model[0]: [] for model in models} for m in measures} #[X] <---main
accuracy_dict3 = {m: {model[0]: [] for model in models} for m in measures}
for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        print (f'\n=========================================\nPT_{m}_{window} {odf.shape}\n=========================================')#print (f'\n=========================================I\nssHC_{m}_{window} {odf.shape}        I\n=========================================I')
        df = vars()['PT_'+m+'_'+window].copy()
        allHC_LR_results = []
        #Individual Dataframes
        for p in PT:
            hdf = vars()[p+'df_'+m+'_'+window].copy()
            print (f'{p}df_{m}_{window} {hdf.shape}')# <------------------------')
            X = hdf.drop(columns='Task') #data
            y = hdf['Task'] #labels
            # Accuracy lists (for p)
            LDA_results= []
            SVC_results= []   
            # Stratified 5-Folds cross-validator
            skf = StratifiedKFold(n_splits=5)
            for count,(train_index, test_index) in enumerate(skf.split(X, y)):
                #print (f'Split_{count+1}:\nTrain_index: {train_index}\nTest_index: {test_index}')
                X_train= X.iloc[train_index]
                X_test= X.iloc[test_index]
                y_train= y.iloc[train_index]
                y_test= y.iloc[test_index]
                # Machine Learning Algorithms
                for name, model in models:
                    model.fit(X_train, y_train)
                    predictions = model.predict(X_test)
                    score = accuracy_score(y_test,predictions)
                    #print ('  -',name,score.round(2))
                    vars()[name+'_results'].append(score)
            accuracy_dict3[m]['LDA'].append(LDA_results)
            accuracy_dict3[m]['SVC'].append(SVC_results)
            
            
            #print('_________________________________________________________________')
            #print(f'Model Accuracy Scores and Average across 5 folds:')
            avg_models = []
            stdev_models = []
            for i in ['LDA','SVC']:
                average = round(((sum(vars()[i+'_results']))/len(vars()[i+'_results'])),2)
                stdev = round(np.std(vars()[i+'_results']),2)
                avg_models.append(average)
                stdev_models.append(stdev)
                #print (f"  > {i}: avg={average} stdev={stdev} {i}_results={[r.round(2) for r in vars()[i+'_results']]}") #print (f"  {i}: avg={average} stdev={stdev}")
                accuracy_dict2[m][i].append(vars()[i + '_results'])#[X]
                accuracy_dict[m][i].extend(vars()[i + '_results'])#[X]
            #print('_________________________________________________________________')
            # After calculating the accuracy scores for each model, store them in a dictionary
            etcresults = {'LDA': LDA_results,'SVC': SVC_results}

#####################################################################################################################    
##                                                                                                                 ##
##                    plotting accuracy scores                                                                     ## 
#####################################################################################################################    
#(1)
for m in measures:
    data_to_plot = {name: accuracy_dict2[m][name] for name, _ in models}
    for i in ['LDA','SVC']:
        vars()[i+m+'scores']=data_to_plot[i]
for i in ['LDA','SVC']:
    vars()[i+'_']=[]
    for m in measures:
        scores_m =vars()[i+m+'scores'].copy()
        vars()[i+'_'].append(scores_m)  # list of scores (not a df)  
#(2)***
for i in ['LDA','SVC']:
    print (i)
    hi = vars()[i+'_'].copy()
    hidf=pd.DataFrame(hi)
    hidf=hidf.transpose()
    hidf.columns = measures
    hidf.index=PT
########################################### # # # # # 
    #(3)
    #i have a 10 by 18 dataframe. in each cell there is a list of 5 number. I want these 5 values (for both columns) to be thier own columns with the original column as a multilevel column
    #dfindex=['HC01_fold1','HC01_fold2','HC01_fold3','HC01_fold4','HC01_fold5','HC02_fold1','HC02_fold2','HC02_fold3','HC02_fold4','HC02_fold5','HC03_fold1','HC03_fold2','HC03_fold3','HC03_fold4','HC03_fold5','HC04_fold1','HC04_fold2','HC04_fold3','HC04_fold4','HC04_fold5','HC05_fold1','HC05_fold2','HC05_fold3','HC05_fold4','HC05_fold5','HC06_fold1','HC06_fold2','HC06_fold3','HC06_fold4','HC06_fold5','HC07_fold1','HC07_fold2','HC07_fold3','HC07_fold4','HC07_fold5','HC08_fold1','HC08_fold2','HC08_fold3','HC08_fold4','HC08_fold5','HC09_fold1','HC09_fold2','HC09_fold3','HC09_fold4','HC09_fold5','HC10_fold1','HC10_fold2','HC10_fold3','HC10_fold4','HC10_fold5','HC11_fold1','HC11_fold2','HC11_fold3','HC11_fold4','HC11_fold5','HC12_fold1','HC12_fold2','HC12_fold3','HC12_fold4','HC12_fold5','HC13_fold1','HC13_fold2','HC13_fold3','HC13_fold4','HC13_fold5','HC14_fold1','HC14_fold2','HC14_fold3','HC14_fold4','HC14_fold5','HC15_fold1','HC15_fold2','HC15_fold3','HC15_fold4','HC15_fold5','HC16_fold1','HC16_fold2','HC16_fold3','HC16_fold4','HC16_fold5','HC17_fold1','HC17_fold2','HC17_fold3','HC17_fold4','HC17_fold5','HC18_fold1','HC18_fold2','HC18_fold3','HC18_fold4','HC18_fold5']
    # for i in PT:
    #     print (f"'{i}_fold1',",end='')
    #     print (f"'{i}_fold2',",end='')
    #     print (f"'{i}_fold3',",end='')
    #     print (f"'{i}_fold4',",end='')
    #     print (f"'{i}_fold5',",end='')
    # Creating dfindex from list of PT (PT was created earlier)
    dfindex=[]
    for p in PT: 
        for foldnum in range(1,6):
            ID_foldnum = p+'_fold'+str(foldnum)
            dfindex.append(ID_foldnum)
    #adding dfindex to each df
    fdf=pd.DataFrame(index=dfindex)
    for m in measures:
        Mlist=[]
        for p in PT:
            #print(p,': ',hidf.loc[p,m])
            Mlist.extend(hidf.loc[p,m])
        fdf.insert(loc=len(fdf.columns),column=f'{m}',value=Mlist)    
    vars()['df_'+i]=fdf.copy()
    #(5)
    df = vars()['df_'+i].copy()
    #df.reset_index(inplace=True)
    IDlist=[]
    Foldlist=[]
    for o in df.index:
        a,b = o.split('_')
        IDlist.append(a)
        Foldlist.append(b)
    df.insert(0,'Fold',Foldlist)
    df.insert(0,'IDlist',IDlist)
    #(6) stacked df
    newdf=df.reset_index()
    newdf.set_index(keys='index',
        drop= True,
        append= False,
        inplace=True)
    # newdf.drop(labels='index',axis=1,inplace=True)
    newdf.set_index(keys='IDlist',
        drop= True,
        append= True,
        inplace=True)
    newdf.set_index(keys='Fold',
        drop= True,
        append= True,
        inplace=True)
    # newdf.drop(labels='Fold',axis=1,inplace=True)
    stacked=newdf.stack()
    stackeddf=pd.DataFrame(stacked,columns=['Values'])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    stackeddf=stackeddf.sort_index(axis=0,level=3)
    stackeddf=stackeddf.reset_index(level=3)
    col=list(stackeddf.columns.values)
    col[0]='measures'
    stackeddf.columns = col
    stackeddf=stackeddf.reset_index()
    vars()['stackeddf_'+i]=stackeddf.copy()
    

    #(7) plot
    plt.figure(figsize=(10, 6))
#     sns.catplot(x="IDlist", 
#                 y="Values", 
#                 hue="measures", 
#                 data=stackeddf,
#                 kind='point',
#                 height=6,  
#                 aspect=3)
    sns.lineplot(x='IDlist',y='Values',
                 hue='measures',
                 data=stackeddf,
#                  palette="Set3"
                )
    plt.xlabel('Participants')
    plt.xticks
    plt.ylabel('Accuracy')
    plt.ylim(0.3, 1.0)
    plt.axhline(0.5, color='grey', linestyle='--')
    plt.xticks(rotation=45) 
    plt.title(f'Individual participant Accuracy Scores using {i} ({window})')
    plt.legend(bbox_to_anchor=(1, 1), loc='best')
    plt.show()

# [X] AllPT Scores (linegraph)
# [X] AllPT Outcome 1 vs 0 - Violinplot 
# [X] AllPT Outcome 1 vs 0  - t-test

# [X] SedOFFonly Scores (linegraph)
# [X] SedOFFonly Outcome 1 vs 0 - Violinplot 
# [X] SedOFFonly Outcome 1 vs 0  - t-test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_346746/2837470496.py in <module>
#      34 for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
#      35     for m in measures:
# ---> 36         vars()[m+'_'+window]= pd.read_csv(f'./results/NewDataResults/save/{window}/{m}/{m}_{window}.csv')
#      37         vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
#      38         vars()[m+'_'+window].set_index('ID', inplace=True)
#
# NameError: name 'pd' is not defined

# %%
#(2)


# updated NEWDATA 
#######################
####################### 1234
#######################





#used for outcome scores 
#MAX's way (5) - PT (IT vs ST)                                (not main)
# Window Method
#####################################################################################################################    
##                                                                                                                 ##
##                 LOADING DATAFRAME AND RESHAPING IT                                                              ## 
##################################################################################################################### 
import string
measures = ['ll','cwpen']#['svd1','svd2','approx','sample','detrended','katz','ll','mswpen','bubben','cwpen']
Echan=['E2','E3','E4','E5','E6','E7','E9','E10','E11','E12','E13','E15','E16','E18','E19','E20','E22','E23','E24','E26','E27','E28','E29','E30','E31','E33','E34','E35','E36','E37','E39','E40','E41','E42','E45','E46','E47','E50','E51','E52','E53','E54','E55','E58','E59','E60','E61','E62','E65','E66','E67','E70','E71','E72','E75','E76','E77','E78','E79','E80','E83','E84','E85','E86','E87','E90','E91','E92','E93','E96','E97','E98','E101','E102','E103','E104','E105','E106','E108','E109','E110','E111','E112','E115','E116','E117','E118','E122','E123','E124','Vertex Reference']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
#OLD #Uoutcomedic={'NETICU01':'1','NETICU02':'0','NETICU03':'0','NETICU04':'1','NETICU05':'1','NETICU06':'0','NETICU08':'1','NETICU11':'1','NETICU13':'0','NETICU15':'0','NETICU17':'1','NETICU18':'1','NETICU19':'1','NETICU20':'1','NETICU22':'0','NETICU24':'0','NETICU25':'0','NETICU27':'1','NETICU28':'0','NETICU29':'1','NETICU30':'0','CCTC03':'1','CCTC04':'1','CCTC05':'1','MSICU05':'1','MSICU07':'0','MSICU09':'0','MSICU10':'0','MSICU14':'0','MSICU15':'0','MSICU16':'0','MSICU18':'0','MSICU19':'1','MSICU21':'0','MSICU22':'1','MSICU26':'1','MSICU28':'1','MSICU29':'1','MSICU30':'1','HC01':'1','HC02':'1','HC03':'1','HC04':'1','HC05':'1','HC06':'1','HC07':'1','HC08':'1','HC09':'1','HC10':'1','HC11':'1','HC12':'1','HC13':'1','HC14':'1','HC15':'1','HC16':'1','HC17':'1','HC18':'1'}#outcomesNA = {'NETICU01':'1','NETICU02':'0','NETICU03':'0','NETICU04':'NA','NETICU05':'NA','NETICU06':'0','NETICU08':'1','NETICU11':'1','NETICU13':'0','NETICU15':'NA','NETICU17':'1','NETICU18':'1','NETICU19':'1','NETICU20':'1','NETICU22':'0','NETICU24':'0','NETICU25':'0','NETICU27':'1','NETICU28':'0','NETICU29':'NA','NETICU30':'0','CCTC03':'NA','CCTC04':'1','CCTC05':'NA','MSICU05':'1','MSICU07':'0','MSICU09':'0','MSICU10':'0','MSICU14':'0','MSICU15':'0','MSICU16':'0','MSICU18':'0','MSICU19':'NA','MSICU21':'0','MSICU22':'1','MSICU26':'1','MSICU28':'NA','MSICU29':'NA','MSICU30':'NA','HC01':'1','HC02':'1','HC03':'1','HC04':'1','HC05':'1','HC06':'1','HC07':'1','HC08':'1','HC09':'1','HC10':'1','HC11':'1','HC12':'1','HC13':'1','HC14':'1','HC15':'1','HC16':'1','HC17':'1','HC18':'1'}#outcomesGuess = {'NETICU01':'1','NETICU02':'0','NETICU03':'0','NETICU04':'0','NETICU05':'1','NETICU06':'0','NETICU08':'1','NETICU11':'1','NETICU13':'0','NETICU15':'0','NETICU17':'1','NETICU18':'1','NETICU19':'1','NETICU20':'1','NETICU22':'0','NETICU24':'0','NETICU25':'0','NETICU27':'1','NETICU28':'0','NETICU29':'1','NETICU30':'0','CCTC03':'1','CCTC04':'1','CCTC05':'0','MSICU05':'1','MSICU07':'0','MSICU09':'0','MSICU10':'0','MSICU14':'0','MSICU15':'0','MSICU16':'0','MSICU18':'0','MSICU19':'1','MSICU21':'0','MSICU22':'1','MSICU26':'1','MSICU28':'1','MSICU29':'0','MSICU30':'0','HC01':'1','HC02':'1','HC03':'1','HC04':'1','HC05':'1','HC06':'1','HC07':'1','HC08':'1','HC09':'1','HC10':'1','HC11':'1','HC12':'1','HC13':'1','HC14':'1','HC15':'1','HC16':'1','HC17':'1','HC18':'1'}
VERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30','CCTC03','CCTC04','CCTC05','MSICU05','MSICU07','MSICU09','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
#OLD(60)# PT=['CCTC03','CCTC03part2','CCTC04','CCTC05','MSICU05','MSICU05part2','MSICU07','MSICU09','MSICU09part2','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','NETICU01sedoff','NETICU01sedon1','NETICU02sedoff','NETICU02sedon1','NETICU03sedoff','NETICU03sedon1','NETICU04sedoff','NETICU04sedon1','NETICU05sedoff','NETICU05sedon1','NETICU06sedoff','NETICU06sedon1','NETICU08sedoff','NETICU08sedon2','NETICU11sedoff','NETICU11sedon1','NETICU13sedoff','NETICU13sedon1','NETICU15sedoff','NETICU15sedon1','NETICU17sedoff','NETICU17sedon1','NETICU18sedon1','NETICU19sedoff','NETICU19sedon1','NETICU20sedon1','NETICU22sedoff','NETICU22sedon1','NETICU24sedoff','NETICU24sedon1','NETICU25sedon1','NETICU27sedoff','NETICU27sedon1','NETICU28sedoff','NETICU28sedon1','NETICU29sedoff','NETICU29sedon1','NETICU30sedoff','NETICU30sedon1']
#NEW(78)# PT = ['CCTC03', 'CCTC03part2', 'CCTC04', 'CCTC05', 'CCTC07NETICUsedoff', 'CCTC07NETICUsedon1', 'CCTC07', 'MSICU05', 'MSICU05part2', 'MSICU07', 'MSICU09', 'MSICU09part2', 'MSICU10', 'MSICU14', 'MSICU15', 'MSICU16', 'MSICU18', 'MSICU19', 'MSICU21', 'MSICU22', 'MSICU26', 'MSICU28', 'MSICU29', 'MSICU30', 'MSICU32', 'MSICU38', 'MSICU42', 'MSICU43', 'MSICU47', 'NETICU01sedoff', 'NETICU01sedon1', 'NETICU02sedoff', 'NETICU02sedon1', 'NETICU03sedoff', 'NETICU03sedon1', 'NETICU04sedoff', 'NETICU04sedon1', 'NETICU05sedoff', 'NETICU05sedon1', 'NETICU06sedoff', 'NETICU06sedon1', 'NETICU08sedoff', 'NETICU08sedon2', 'NETICU11sedoff', 'NETICU11sedon1', 'NETICU13sedoff', 'NETICU13sedon1', 'NETICU15sedoff', 'NETICU15sedon1', 'NETICU17sedoff', 'NETICU17sedon1', 'NETICU18sedon1', 'NETICU19sedoff', 'NETICU19sedon1', 'NETICU20sedon1', 'NETICU22sedoff', 'NETICU22sedon1', 'NETICU24sedoff', 'NETICU24sedon1', 'NETICU25sedon1', 'NETICU27sedoff', 'NETICU27sedon1', 'NETICU28sedoff', 'NETICU28sedon1', 'NETICU29sedoff', 'NETICU29sedon1', 'NETICU30sedoff', 'NETICU30sedon1', 'NETICU31sedoff', 'NETICU31sedon1', 'NETICU33sedon1', 'NETICU38sedon1', 'NETICU40sedoff', 'NETICU40sedon1', 'NETICU41sedoff', 'NETICU41sedon1', 'NETICU41sedon2', 'NETICU46sedon1']
EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30
1', 'NETICU18sedon1_ST': '1', 'NETICU19sedoff_IT': '1', 'NETICU19sedoff_RS': '1', 'NETICU19sedoff_ST': '1', 'NETICU19sedon1_IT': '1', 'NETICU19sedon1_RS': '1', 'NETICU19sedon1_ST': '1', 'NETICU20sedoff_RS': '1', 'NETICU20sedon1_IT': '1', 'NETICU20sedon1_RS': '1', 'NETICU20sedon1_ST': '1', 'NETICU22sedoff_IT': '0', 'NETICU22sedoff_RS': '0', 'NETICU22sedoff_ST': '0', 'NETICU22sedon1_IT': '0', 'NETICU22sedon1_RS': '0', 'NETICU22sedon1_ST': '0', 'NETICU24sedoff_IT': '0', 'NETICU24sedoff_RS': '0', 'NETICU24sedoff_ST': '0', 'NETICU24sedon1_IT': '0', 'NETICU24sedon1_RS': '0', 'NETICU24sedon1_ST': '0', 'NETICU25sedoff_RS': '0', 'NETICU25sedon1_IT': '0', 'NETICU25sedon1_RS': '0', 'NETICU25sedon1_ST': '0', 'NETICU27sedoff_IT': '1', 'NETICU27sedoff_RS': '1', 'NETICU27sedoff_ST': '1', 'NETICU27sedon1_IT': '1', 'NETICU27sedon1_RS': '1', 'NETICU27sedon1_ST': '1', 'NETICU28sedoff_IT': '0', 'NETICU28sedoff_RS': '0', 'NETICU28sedoff_ST': '0', 'NETICU28sedon1_IT': '0', 'NETICU28sedon1_RS': '0', 'NETICU28sedon1_ST': '0', 'NETICU29sedoff_IT': '1', 'NETICU29sedoff_RS': '1', 'NETICU29sedoff_ST': '1', 'NETICU29sedon1_IT': '1', 'NETICU29sedon1_RS': '1', 'NETICU29sedon1_ST': '1', 'NETICU30sedoff_IT': '0', 'NETICU30sedoff_RS': '0', 'NETICU30sedoff_ST': '0', 'NETICU30sedon1_IT': '0', 'NETICU30sedon1_RS': '0', 'NETICU30sedon1_ST': '0', 'NETICU31sedoff_IT': '1', 'NETICU31sedoff_RS': '1', 'NETICU31sedoff_ST': '1', 'NETICU31sedon1_IT': '1', 'NETICU31sedon1_ST': '1', 'NETICU31sedon2_RS': '1', 'NETICU33sedoff_RS': '0', 'NETICU33sedon1_IT': '0', 'NETICU33sedon1_RS': '0', 'NETICU33sedon1_ST': '0', 'NETICU38sedon1_IT': '0', 'NETICU38sedon1_RS': '0', 'NETICU38sedon1_ST': '0', 'NETICU40sedoff_IT': '0', 'NETICU40sedoff_RS': '0', 'NETICU40sedoff_ST': '0', 'NETICU40sedon1_IT': '0', 'NETICU40sedon1_RS': '0', 'NETICU40sedon1_ST': '0', 'NETICU41sedoff_IT': '0', 'NETICU41sedoff_RS': '0', 'NETICU41sedoff_ST': '0', 'NETICU41sedon1_IT': '0', 'NETICU41sedon1_RS': '0', 'NETICU41sedon1_ST': '0', 'NETICU41sedon2_IT': '0', 'NETICU41sedon2_RS': '0', 'NETICU41sedon2_ST': '0', 'NETICU46sedoff_RS': '1', 'NETICU46sedon1_IT': '1', 'NETICU46sedon1_RS': '1', 'NETICU46sedon1_ST': '1'}
'OFF', 'NETICU15sedoff_ST': 'OFF', 'NETICU15sedon1_IT': 'ON', 'NETICU15sedon1_RS': 'ON', 'NETICU15sedon1_ST': 'ON', 'NETICU17sedoff_IT': 'OFF', 'NETICU17sedoff_RS': 'OFF', 'NETICU17sedoff_ST': 'OFF', 'NETICU17sedon1_IT': 'ON', 'NETICU17sedon1_RS': 'ON', 'NETICU17sedon1_ST': 'ON', 'NETICU18sedoff_RS': 'OFF', 'NETICU18sedon1_IT': 'ON', 'NETICU18sedon1_RS': 'ON', 'NETICU18sedon1_ST': 'ON', 'NETICU19sedoff_IT': 'OFF', 'NETICU19sedoff_RS': 'OFF', 'NETICU19sedoff_ST': 'OFF', 'NETICU19sedon1_IT': 'ON', 'NETICU19sedon1_RS': 'ON', 'NETICU19sedon1_ST': 'ON', 'NETICU20sedoff_RS': 'OFF', 'NETICU20sedon1_IT': 'ON', 'NETICU20sedon1_RS': 'ON', 'NETICU20sedon1_ST': 'ON', 'NETICU22sedoff_IT': 'OFF', 'NETICU22sedoff_RS': 'OFF', 'NETICU22sedoff_ST': 'OFF', 'NETICU22sedon1_IT': 'ON', 'NETICU22sedon1_RS': 'ON', 'NETICU22sedon1_ST': 'ON', 'NETICU24sedoff_IT': 'OFF', 'NETICU24sedoff_RS': 'OFF', 'NETICU24sedoff_ST': 'OFF', 'NETICU24sedon1_IT': 'ON', 'NETICU24sedon1_RS': 'ON', 'NETICU24sedon1_ST': 'ON', 'NETICU25sedoff_RS': 'OFF', 'NETICU25sedon1_IT': 'ON', 'NETICU25sedon1_RS': 'ON', 'NETICU25sedon1_ST': 'ON', 'NETICU27sedoff_IT': 'OFF', 'NETICU27sedoff_RS': 'OFF', 'NETICU27sedoff_ST': 'OFF', 'NETICU27sedon1_IT': 'ON', 'NETICU27sedon1_RS': 'ON', 'NETICU27sedon1_ST': 'ON', 'NETICU28sedoff_IT': 'OFF', 'NETICU28sedoff_RS': 'OFF', 'NETICU28sedoff_ST': 'OFF', 'NETICU28sedon1_IT': 'ON', 'NETICU28sedon1_RS': 'ON', 'NETICU28sedon1_ST': 'ON', 'NETICU29sedoff_IT': 'OFF', 'NETICU29sedoff_RS': 'OFF', 'NETICU29sedoff_ST': 'OFF', 'NETICU29sedon1_IT': 'ON', 'NETICU29sedon1_RS': 'ON', 'NETICU29sedon1_ST': 'ON', 'NETICU30sedoff_IT': 'OFF', 'NETICU30sedoff_RS': 'OFF', 'NETICU30sedoff_ST': 'OFF', 'NETICU30sedon1_IT': 'ON', 'NETICU30sedon1_RS': 'ON', 'NETICU30sedon1_ST': 'ON', 'NETICU31sedoff_IT': 'OFF', 'NETICU31sedoff_RS': 'OFF', 'NETICU31sedoff_ST': 'OFF', 'NETICU31sedon1_IT': 'ON', 'NETICU31sedon1_ST': 'ON', 'NETICU31sedon2_RS': 'ON', 'NETICU33sedoff_RS': 'OFF', 'NETICU33sedon1_IT': 'ON', 'NETICU33sedon1_RS': 'ON', 'NETICU33sedon1_ST': 'ON', 'NETICU38sedon1_IT': 'ON', 'NETICU38sedon1_RS': 'ON', 'NETICU38sedon1_ST': 'ON', 'NETICU40sedoff_IT': 'OFF', 'NETICU40sedoff_RS': 'OFF', 'NETICU40sedoff_ST': 'OFF', 'NETICU40sedon1_IT': 'ON', 'NETICU40sedon1_RS': 'ON', 'NETICU40sedon1_ST': 'ON', 'NETICU41sedoff_IT': 'OFF', 'NETICU41sedoff_RS': 'OFF', 'NETICU41sedoff_ST': 'OFF', 'NETICU41sedon1_IT': 'ON', 'NETICU41sedon1_RS': 'ON', 'NETICU41sedon1_ST': 'ON', 'NETICU41sedon2_IT': 'ON', 'NETICU41sedon2_RS': 'ON', 'NETICU41sedon2_ST': 'ON', 'NETICU46sedoff_RS': 'OFF', 'NETICU46sedon1_IT': 'ON', 'NETICU46sedon1_RS': 'ON', 'NETICU46sedon1_ST': 'ON'}
GCSdic={'CCTC03_IT': '3', 'CCTC03_RS': '3', 'CCTC03_ST': '3', 'CCTC03part2_IT': '3', 'CCTC03part2_RS': '3', 'CCTC03part2_ST': '3', 'CCTC04_IT': '3', 'CCTC04_RS': '3', 'CCTC04_RSredo': '3', 'CCTC04_ST': '3', 'CCTC05_IT': '3', 'CCTC05_RS': '3', 'CCTC05_ST': '3', 'CCTC07NETICUsedoff_IT': '7', 'CCTC07NETICUsedoff_RS': '7', 'CCTC07NETICUsedoff_ST': '7', 'CCTC07NETICUsedon1_IT': '4', 'CCTC07NETICUsedon1_RS': '4', 'CCTC07NETICUsedon1_ST': '4', 'CCTC07_IT': '5', 'CCTC07_RS': '5', 'CCTC07_ST': '5', 'HC01_IT': '15', 'HC01_ST': '15', 'HC02_IT': '15', 'HC02_ST': '15', 'HC03_IT': '15', 'HC03_ST': '15', 'HC04_IT': '15', 'HC04_ST': '15', 'HC05_IT1st': '15', 'HC05_IT2nd': '15', 'HC05_ST': '15', 'HC06_IT': '15', 'HC06_ST': '15', 'HC07_IT': '15', 'HC07_ST': '15', 'HC08_IT': '15', 'HC08_ST': '15', 'HC09_IT': '15', 'HC09_ST': '15', 'HC10_IT': '15', 'HC10_ST': '15', 'HC11_IT': '15', 'HC11_ST': '15', 'HC12_IT': '15', 'HC12_ST': '15', 'HC13_IT': '15', 'HC13_ST': '15', 'HC14_IT': '15', 'HC14_ST': '15', 'HC15_IT': '15', 'HC15_ST': '15', 'HC16_IT': '15', 'HC16_ST': '15', 'HC17_IT': '15', 'HC17_ST': '15', 'HC18_IT': '15', 'HC18_ST': '15', 'MSICU05_IT': '3', 'MSICU05_RS': '3', 'MSICU05_ST': '3', 'MSICU05part2_IT': '15', 'MSICU05part2_RS': '15', 'MSICU05part2_ST': '15', 'MSICU07_IT': '3', 'MSICU07_RS': '3', 'MSICU07_ST': '3', 'MSICU09_IT': '5', 'MSICU09_RS': '5', 'MSICU09_ST': '5', 'MSICU09part2_IT': '4', 'MSICU09part2_RS': '4', 'MSICU09part2_ST': '4', 'MSICU10_IT': '4', 'MSICU10_RS': '4', 'MSICU10_ST': '4', 'MSICU14_IT': '3', 'MSICU14_RS': '3', 'MSICU14_ST': '3', 'MSICU15_IT': '6', 'MSICU15_RS': '6', 'MSICU15_ST': '6', 'MSICU16_IT': '3', 'MSICU16_RS': '3', 'MSICU16_ST': '3', 'MSICU18_IT': '7', 'MSICU18_RS': '7', 'MSICU18_ST': '7', 'MSICU19_IT': '8', 'MSICU19_RS': '8', 'MSICU19_ST': '8', 'MSICU21_IT': '9', 'MSICU21_RS': '9', 'MSICU21_ST': '9', 'MSICU22_IT': '4', 'MSICU22_RS': '4', 'MSICU22_ST': '4', 'MSICU26_IT': '7', 'MSICU26_RS': '7', 'MSICU26_ST': '7', 'MSICU28_IT': '6', 'MSICU28_RS': '6', 'MSICU28_ST': '6', 'MSICU29_IT': '9', 'MSICU29_RS': '9', 'MSICU29_ST': '9', 'MSICU30_IT': '5', 'MSICU30_RS': '5', 'MSICU30_ST': '5', 'MSICU32_IT': '3', 'MSICU32_RS': '3', 'MSICU32_ST': '3', 'MSICU38_IT': '5', 'MSICU38_RS': '5', 'MSICU38_ST': '5', 'MSICU42_IT': '6', 'MSICU42_RS': '6', 'MSICU42_ST': '6', 'MSICU43_IT': '9', 'MSICU43_RS': '9', 'MSICU43_ST': '9', 'MSICU47_IT': '6', 'MSICU47_RS': '6', 'MSICU47_ST': '6', 'NETICU01sedoff_IT': '3', 'NETICU01sedoff_RS': '3', 'NETICU01sedoff_ST': '3', 'NETICU01sedon1_IT': '3', 'NETICU01sedon1_RS': '3', 'NETICU01sedon1_ST': '3', 'NETICU02sedoff_IT': '10', 'NETICU02sedoff_RS': '10', 'NETICU02sedoff_ST': '10', 'NETICU02sedon1_IT': '3', 'NETICU02sedon1_RS': '3', 'NETICU02sedon1_ST': '3', 'NETICU03sedoff_IT': '6', 'NETICU03sedoff_RS': '6', 'NETICU03sedoff_ST': '6', 'NETICU03sedon1_IT': '6', 'NETICU03sedon1_RS': '6', 'NETICU03sedon1_ST': '6', 'NETICU04sedoff_IT': '3', 'NETICU04sedoff_RS': '3', 'NETICU04sedoff_ST': '3', 'NETICU04sedon1_IT': '3', 'NETICU04sedon1_RS': '3', 'NETICU04sedon1_ST': '3', 'NETICU05sedoff_IT': '3', 'NETICU05sedoff_RS': '3', 'NETICU05sedoff_ST': '3', 'NETICU05sedon1_IT': '3', 'NETICU05sedon1_RS': '3', 'NETICU05sedon1_ST': '3', 'NETICU06sedoff_IT': '6', 'NETICU06sedoff_RS': '6', 'NETICU06sedoff_ST': '6', 'NETICU06sedon1_IT': '3', 'NETICU06sedon1_RS': '3', 'NETICU06sedon1_ST': '3', 'NETICU08sedoff_IT': '9', 'NETICU08sedoff_ST': '9', 'NETICU08sedon2_IT': '3', 'NETICU08sedon2_RS': '3', 'NETICU08sedon2_ST': '3', 'NETICU11sedoff_IT': '4', 'NETICU11sedoff_RS': '4', 'NETICU11sedoff_ST': '4', 'NETICU11sedon1_IT': '3', 'NETICU11sedon1_RS': '3', 'NETICU11sedon1_ST': '3', 'NETICU13sedoff_IT': '4', 'NETICU13sedoff_RS': '4', 'NETICU13sedoff_ST': '4', 'NETICU13sedon1_IT': '3', 'NETICU13sedon1_RS': '3', 'NETICU13sedon1_ST': '3', 'NETICU15sedoff_IT': '3', 'NETICU15sedoff_RS': '3', 'NETICU15sedoff_ST': '3', 'NETICU15sedon1_IT': '3', 'NETICU15sedon1_RS': '3', 'NETICU15sedon1_ST': '3', 'NETICU17sedoff_IT': '10', 'NETICU17sedoff_RS': '10', 'NETICU17sedoff_ST': '10', 'NETICU17sedon1_IT': '3', 'NETICU17sedon1_RS': '3', 'NETICU17sedon1_ST': '3', 'NETICU18sedoff_RS': '11', 'NETICU18sedon1_IT': '3', 'NETICU18sedon1_RS': '3', 'NETICU18sedon1_ST': '3', 'NETICU19sedoff_IT': '7', 'NETICU19sedoff_RS': '7', 'NETICU19sedoff_ST': '7', 'NETICU19sedon1_IT': '3', 'NETICU19sedon1_RS': '3', 'NETICU19sedon1_ST': '3', 'NETICU20sedoff_RS': '11', 'NETICU20sedon1_IT': '3', 'NETICU20sedon1_RS': '3', 'NETICU20sedon1_ST': '3', 'NETICU22sedoff_IT': '3', 'NETICU22sedoff_RS': '3', 'NETICU22sedoff_ST': '3', 'NETICU22sedon1_IT': '3', 'NETICU22sedon1_RS': '3', 'NETICU22sedon1_ST': '3', 'NETICU24sedoff_IT': '3', 'NETICU24sedoff_RS': '3', 'NETICU24sedoff_ST': '3', 'NETICU24sedon1_IT': '3', 'NETICU24sedon1_RS': '3', 'NETICU24sedon1_ST': '3', 'NETICU25sedoff_RS': '8', 'NETICU25sedon1_IT': '6', 'NETICU25sedon1_RS': '6', 'NETICU25sedon1_ST': '6', 'NETICU27sedoff_IT': '3', 'NETICU27sedoff_RS': '3', 'NETICU27sedoff_ST': '3', 'NETICU27sedon1_IT': '3', 'NETICU27sedon1_RS': '3', 'NETICU27sedon1_ST': '3', 'NETICU28sedoff_IT': '3', 'NETICU28sedoff_RS': '3', 'NETICU28sedoff_ST': '3', 'NETICU28sedon1_IT': '3', 'NETICU28sedon1_RS': '3', 'NETICU28sedon1_ST': '3', 'NETICU29sedoff_IT': '11', 'NETICU29sedoff_RS': '11', 'NETICU29sedoff_ST': '11', 'NETICU29sedon1_IT': '3', 'NETICU29sedon1_RS': '3', 'NETICU29sedon1_ST': '3', 'NETICU30sedoff_IT': '6', 'NETICU30sedoff_RS': '6', 'NETICU30sedoff_ST': '6', 'NETICU30sedon1_IT': '3', 'NETICU30sedon1_RS': '3', 'NETICU30sedon1_ST': '3', 'NETICU31sedoff_IT': '10', 'NETICU31sedoff_RS': '10', 'NETICU31sedoff_ST': '10', 'NETICU31sedon1_IT': '3', 'NETICU31sedon1_ST': '3', 'NETICU31sedon2_RS': '6', 'NETICU33sedoff_RS': '5', 'NETICU33sedon1_IT': '3', 'NETICU33sedon1_RS': '3', 'NETICU33sedon1_ST': '3', 'NETICU38sedon1_IT': '3', 'NETICU38sedon1_RS': '3', 'NETICU38sedon1_ST': '3', 'NETICU40sedoff_IT': '9', 'NETICU40sedoff_RS': '9', 'NETICU40sedoff_ST': '9', 'NETICU40sedon1_IT': '3', 'NETICU40sedon1_RS': '3', 'NETICU40sedon1_ST': '3', 'NETICU41sedoff_IT': '3', 'NETICU41sedoff_RS': '3', 'NETICU41sedoff_ST': '3', 'NETICU41sedon1_IT': '3', 'NETICU41sedon1_RS': '3', 'NETICU41sedon1_ST': '3', 'NETICU41sedon2_IT': '3', 'NETICU41sedon2_RS': '3', 'NETICU41sedon2_ST': '3', 'NETICU46sedoff_RS': '8', 'NETICU46sedon1_IT': '3', 'NETICU46sedon1_RS': '3', 'NETICU46sedon1_ST': '3'}

for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        vars()[m+'_'+window]= pd.read_csv(f'./results/NewDataResults/save/{window}/{m}/{m}_{window}.csv')
        vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
        vars()[m+'_'+window].set_index('ID', inplace=True)
        #-----------------------------------------------------------------------------------------#
        df = vars()[m+'_'+window].copy()
        ssfnames = [f for f in df.index if 'HC05_IT1st' not in f]
        #print(f'\n{m}_{window}\n{len(df.index)}-{len(ssfnames)} = {len(df.index)-len(ssfnames)}')
        #-----------------------------------------------------------------------------------------#
        df = df.loc[ssfnames] #using ssfnames
        IDlist=[]
        ID2list = []
        chaa=[]
        T2list=[]
        for f in df.index:
            a,b,c = f.split('_')
            ID = a+'_'+b
            IDlist.append(ID)
            T2=(f.split('_'))[1]
            T2list.append(T2)
            for el in Echan:
                if el == (f.split('_'))[2]:
                    chaa.append(el)
            for E in EVERYONE:
                if E in f:
                    ID2list.append(E)
        df.insert(0,'el',chaa)
        df.insert(0, 'IDlist', IDlist)
        #
        columns=df.columns.tolist()
        columns[2:] = [i for i in range(10,40)]
        df.columns = columns   

        values = [a+b for a in string.ascii_lowercase for b in string.ascii_lowercase]
        mappings = dict(zip(Echan, values))
        mappings2 = dict(zip(values, Echan))
        df['sortby'] = df['el'].map(mappings)
        df.drop('el',inplace=True,axis=1)
        df=df.pivot(index='IDlist',columns = 'sortby')
        df = df.swaplevel(i=-2, j=-1, axis=1)
        df = df.sort_index(axis=1)
        #df.columns = [col[0]+str(col[1]) for col in hi.columns]
        hi=df.swaplevel(i=-2,j=-1,axis=1)
        hi=hi.transpose()
        hi.reset_index(level='sortby', inplace=True)
        hi['el'] = hi['sortby'].map(mappings2)
        hi.drop('sortby',inplace=True,axis=1)
        hi.set_index('el', append=True, inplace=True)
        hi.reset_index(level=0, inplace=True)
        timekeys= [int(i) for i in range(10,40)]
        timevalues = [str(i) for i in range(30)]
        mappings3 = dict(zip(timekeys,timevalues))
        # hi['level_0']=hi['level_0'].astype(str)
        hi['timepoints']=hi['level_0'].map(mappings3)
        hi.drop('level_0',inplace=True,axis=1)
        hi.set_index('timepoints', append=True, inplace=True)
        hi = hi.transpose()
        hi.columns = ['_'.join(col) for col in hi.columns]# <--THis seperates the timepoints from electrode-channels in the columns section
        #hi = hi.add_suffix(f'_{m}')
        vars()[m+'_'+window+'_reorg'] = hi
    # concatinate all dataframes into one (should be 6006000)
    # add labels ()
    #display(ll_10secwindows_reorg)
#####################################################################################################################    
##                                                                                                                 ##
##                    ADDING LABELS                                                                                ## 
#####################################################################################################################    
# EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30
S':'OFF','MSICU05_ST':'OFF','MSICU05part2_IT':'OFF','MSICU05part2_RS':'OFF','MSICU05part2_ST':'OFF','MSICU07_IT':'OFF','MSICU07_RS':'OFF','MSICU07_ST':'OFF','MSICU09_IT':'OFF','MSICU09_RS':'OFF','MSICU09_ST':'OFF','MSICU09part2_IT':'OFF','MSICU09part2_RS':'OFF','MSICU09part2_ST':'OFF','MSICU10_IT':'OFF','MSICU10_RS':'OFF','MSICU10_ST':'OFF','MSICU14_IT':'OFF','MSICU14_RS':'OFF','MSICU14_ST':'OFF','MSICU15_IT':'ON','MSICU15_RS':'ON','MSICU15_ST':'ON','MSICU16_IT':'OFF','MSICU16_RS':'OFF','MSICU16_ST':'OFF','MSICU18_IT':'OFF','MSICU18_RS':'OFF','MSICU18_ST':'OFF','MSICU19_IT':'OFF','MSICU19_RS':'OFF','MSICU19_ST':'OFF','MSICU21_IT':'OFF','MSICU21_RS':'OFF','MSICU21_ST':'OFF','MSICU22_IT':'OFF','MSICU22_RS':'OFF','MSICU22_ST':'OFF','MSICU26_IT':'ON','MSICU26_RS':'ON','MSICU26_ST':'ON','MSICU28_IT':'OFF','MSICU28_RS':'OFF','MSICU28_ST':'OFF','MSICU29_IT':'OFF','MSICU29_RS':'OFF','MSICU29_ST':'OFF','MSICU30_IT':'OFF','MSICU30_RS':'OFF','MSICU30_ST':'OFF','NETICU01sedoff_IT':'ON','NETICU01sedoff_RS':'ON','NETICU01sedoff_ST':'ON','NETICU01sedon1_IT':'ON','NETICU01sedon1_RS':'ON','NETICU01sedon1_ST':'ON','NETICU02sedoff_IT':'OFF','NETICU02sedoff_RS':'OFF','NETICU02sedoff_ST':'OFF','NETICU02sedon1_IT':'ON','NETICU02sedon1_RS':'ON','NETICU02sedon1_ST':'ON','NETICU03sedoff_IT':'OFF','NETICU03sedoff_RS':'OFF','NETICU03sedoff_ST':'OFF','NETICU03sedon1_IT':'ON','NETICU03sedon1_RS':'ON','NETICU03sedon1_ST':'ON','NETICU04sedoff_IT':'OFF','NETICU04sedoff_RS':'OFF','NETICU04sedoff_ST':'OFF','NETICU04sedon1_IT':'ON','NETICU04sedon1_RS':'ON','NETICU04sedon1_ST':'ON','NETICU05sedoff_IT':'OFF','NETICU05sedoff_RS':'OFF','NETICU05sedoff_ST':'OFF','NETICU05sedon1_IT':'ON','NETICU05sedon1_RS':'ON','NETICU05sedon1_ST':'ON','NETICU06sedoff_IT':'OFF','NETICU06sedoff_RS':'OFF','NETICU06sedoff_ST':'OFF','NETICU06sedon1_IT':'ON','NETICU06sedon1_RS':'ON','NETICU06sedon1_ST':'ON','NETICU08sedoff_IT':'OFF','NETICU08sedoff_ST':'OFF','NETICU08sedon2_IT':'ON','NETICU08sedon2_RS':'ON','NETICU08sedon2_ST':'ON','NETICU11sedoff_IT':'OFF','NETICU11sedoff_RS':'OFF','NETICU11sedoff_ST':'OFF','NETICU11sedon1_IT':'ON','NETICU11sedon1_RS':'ON','NETICU11sedon1_ST':'ON','NETICU13sedoff_IT':'OFF','
':'under9','NETICU24sedon1_ST':'under9','NETICU25sedoff_RS':'under9','NETICU25sedon1_IT':'under9','NETICU25sedon1_RS':'under9','NETICU25sedon1_ST':'under9','NETICU27sedoff_IT':'under9','NETICU27sedoff_RS':'under9','NETICU27sedoff_ST':'under9','NETICU27sedon1_IT':'under9','NETICU27sedon1_RS':'under9','NETICU27sedon1_ST':'under9','NETICU28sedoff_IT':'under9','NETICU28sedoff_RS':'under9','NETICU28sedoff_ST':'under9','NETICU28sedon1_IT':'under9','NETICU28sedon1_RS':'under9','NETICU28sedon1_ST':'under9','NETICU29sedoff_IT':'9ABOVE','NETICU29sedoff_RS':'9ABOVE','NETICU29sedoff_ST':'9ABOVE','NETICU29sedon1_IT':'under9','NETICU29sedon1_RS':'under9','NETICU29sedon1_ST':'under9','NETICU30sedoff_IT':'under9','NETICU30sedoff_RS':'under9','NETICU30sedoff_ST':'under9','NETICU30sedon1_IT':'under9','NETICU30sedon1_RS':'under9','NETICU30sedon1_ST':'under9'}
# for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
#     #for m in measures:
#         #print (f'\n{m}_{window}_reorg')
#         #df = vars()[m+'_'+window+'_reorg'].copy()




window ='10secwindows'
for m in measures:
    df = vars()[m+'_'+window+'_reorg'].copy()
    #----------------------------------------#
    GCS = []
    sedlist = []
    sedlist2=[]
    Uoutcomelist=[]
    studylist=[]
    Scan=[]
    Tlist=[]
    hplist = []
    T2list=[]
    ID2list=[]
    IDlist=[]
    for f in df.index:
        ID = ((f.split('_')[0]).split('part2')[0]).split('sed')[0]
        IDlist.append(ID)
        ID2 = f.split('_')[0]
        ID2list.append(ID2)
        #HC or PT 
        hp = 'hc' if 'HC' in f else 'pt'
        hplist.append(hp)
        #Task (RS/ST/IT)
        for Task in ['RS','ST','IT']:
            if Task in f:
                T = Task
                Tlist.append(T)
        T2=(f.split('_'))[1]
        T2list.append(T2)
        #part2/sedon/sedoff/-
        S = 'part2' if 'part2' in f else 'sed'+((f.split('sed')[1]).split('_')[0]) if 'sed' in f else '-'
        Scan.append(S)
        #studylist(NETICU/MIMIC/control)
        NMc = 'NETICU' if 'NETICU' in f else 'control' if 'HC' in f else 'MIMIC'
        studylist.append(NMc)
        #outcomes 
        #for E in EVERYONE:
            #if E+'_' in f or E+'sed' in f or E+'part' in f:
                #UO=Uoutcomedic[E]#O= outcomesNA[E]#outcomeslist.append(O)#O2= outcomesGuess[E]#guessoutcomeslist.append(O2) 
                #Uoutcomelist.append(UO)
        U=Uoutcomedic[f]
        Uoutcomelist.append(U)
        #sed & GCS
        sedlist.append(seddic[f])
        SEDLIST =['OFF' if element == '-' else element for element in sedlist]
        GCS.append(GCSdic[f])
    # Add Labels
    df.insert(0,'sed',SEDLIST)
    df.insert(0,'GCS',GCS)
    df['GCS'] = pd.to_numeric(df['GCS'])
    GCS_8=list(df['GCS'].apply(lambda x: 'under8' if x < 8 else '8ABOVE'))
    GCS_7=list(df['GCS'].apply(lambda x: 'under7' if x < 7 else '7ABOVE'))
    GCS_6=list(df['GCS'].apply(lambda x: 'under6' if x < 6 else '6ABOVE'))
    GCS_5=list(df['GCS'].apply(lambda x: 'under5' if x < 5 else '5ABOVE'))
    df.insert(0,'GCS_8',GCS_8)
    df.insert(0,'GCS_7',GCS_7)
    df.insert(0,'GCS_6',GCS_6)
    df.insert(0,'GCS_5',GCS_5)
    df.insert(0, 'Uoutcome', Uoutcomelist)# df.insert(0, 'outcome', outcomeslist)# df.insert(0, 'GuessOutcome', guessoutcomeslist)
    df.insert(0, 'participant_id', IDlist)
    df.insert(0, 'ID2list', ID2list)
    df.insert(0, 'Task2', T2list)
    df.insert(0, 'Task', Tlist)
    df.insert(0, 'Scan', Scan)
    df.insert(0,'sed2',sedlist)
    df.insert(0, 'study', studylist)
    df.insert(0, 'HP', hplist)
   #----------------------------------------#
tdf = df.copy() 
tdf = df[(df['Task']=='IT') | (df['Task']=='ST')]
tdf = tdf[tdf['HP'] != 'hc']
tdf = tdf[tdf['Task'] != 'ST']
PT=[]
for i in tdf.index:
    i2 = i[:-3]
    PT.append(i2)
tdf.insert(0,'ID',PT)
tdf = tdf.loc[:,'ID':'sed']
tdf.reset_index(drop=True,inplace=True)

# tdf
a = tdf['ID']
b = tdf['Uoutcome']
c = tdf['sed']
d = tdf['GCS']
e = tdf['GCS_8']
f = tdf['participant_id']
# outcomedf
outcomedf = pd.DataFrame(data=a, columns=['ID'])
outcomedf.insert(loc=1, column='outcome', value=b)
outcomedf.insert(loc=2, column='sed', value=c)
outcomedf.insert(loc=3, column='GCS', value=d)
outcomedf.insert(loc=4, column='GCS_8', value=e)
outcomedf.insert(loc=5, column='participant_id', value=f)
outcomedf['outcome'] = pd.to_numeric(outcomedf['outcome'], errors='coerce')
outcomedf['GCS'] = pd.to_numeric(outcomedf['GCS'], errors='coerce')
# cont.
dummy=[]
dummy2=[]
dummy3=[]
for i in outcomedf['ID']:
    dummy.append(0.5)
    dummy2.append(0.4)
    dummy3.append(0.3)
outcomedf.insert(6,'dummy',dummy)
outcomedf.insert(7,'dummy2',dummy2)
outcomedf.insert(8,'dummy3',dummy3)
# print (outcomedf.dtypes)
# outcomedf


# gdf = outcomedf.copy()done
# gdf.drop(['GCS_8','dummy','dummy2','dummy3'], inplace=True, axis=1)
# gdf.to_csv('./gdf_summary_sheet.csv')

# %%
#(3)
## updated NEWDATA
#################









# COMPLETE # COMPLETE # COMPLETE
##############################################################################
### PT: good vs bad outcome (violin plots) (using IT vs ST Acuracy scores) ###
##############################################################################
#creating Datframe
for i in ['LDA','SVC']:
    stackeddf_i = vars()['stackeddf_'+i].copy()
    PTvalues = list(outcomedf['ID'].values)
    for g in ['outcome','sed','GCS','GCS_8','participant_id']:
        values = list(outcomedf[g].values)
        mapping = dict(zip(PTvalues, values))
        stackeddf_i[g] = stackeddf_i['IDlist'].map(mapping)
    vars()['Ustackeddf_'+i]=stackeddf_i.copy()


################
### All PTs  ### 
################  
# # (1) Individual Participant Scores
# for i in ['LDA','SVC']:
#     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='IDlist',y='Values',
#                  hue='measures',
#                  data=Ustackeddf_i)
#     plt.xlabel('Participants')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.4, 1.0)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Individual participant Accuracy Scores using {i} ({window})')
#     plt.legend(bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# # (2) Independent Samples t-test, Mann-Whitney U test <-- Independent samples, Wilcoxon signed-rank test <-- Paired-samples
# # for i in ['LDA','SVC']:
# #     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
#     print(f'____{i}____')
#     m1=Ustackeddf_i[Ustackeddf_i['measures']=='ll']
#     m2=Ustackeddf_i[Ustackeddf_i['measures']=='cwpen']
#     m1good = m1[m1['outcome']==1]['Values']
#     m1bad = m1[m1['outcome']==0]['Values']
#     m2good = m2[m2['outcome']==1]['Values']
#     m2bad = m2[m2['outcome']==0]['Values']
#     # print('ll','good',len(m1good))
#     # print('ll','bad',len(m1bad))
#     # print('cwpen','good',len(m2good))
#     # print('cwpen','bad',len(m2bad))
#     m1stat, m1pval = stats.mannwhitneyu(m1good, m1bad)
#     m2stat, m2pval = stats.mannwhitneyu(m2good, m2bad)
#     if m1pval < 0.05:
#         print(f'   - ll: p = {(m1pval).round(3)}** Significant')
#     else:
#         print(f'   - ll: p = {(m1pval).round(3)}')
#     if m2pval < 0.05:
#         print(f'   - cwpen: p = {(m2pval).round(3)}** Significant')
#     else:
#         print(f'   - cwpen: p = {(m2pval).round(3)}')
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x="measures", y="Values", 
#                    hue="outcome", 
#                    data=Ustackeddf_i, 
#                    bw_method=0.3,#{'scott', 'silverman', float}
#                    cut=0.3,
#                    density_norm='count',#{"area", "count", "width"}
#                    #common_norm=False, #When `True`, normalize the density across all violins.
#                    #width=1,
#                    inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
#                    #dodge=True,
#                    palette="Set3")
#     # for r in range(len(stackedsedoff)):# Adding average line
#     #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
#     plt.xticks([0,1],['ll','cwpen'])# x-axis labels
#     # plt.xlabel('Model Algorithm')
#     plt.xlabel('Complexity Measure')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.05)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     # labels=['ll', 'cwpen']
#     # plt.legend (bbox_to_anchor=(1, 1), loc='best')
#     plt.show()


#################################
### PTw/out sedation (sedOFF) ###
#################################    (       MSICU05 & MSICU09 have repeats (inclduded)      )
# (1) Individual Participant Scores 
for i in ['LDA','SVC']:
    print (f"\n#####################################\n################# {i} ###############\n#####################################")
    Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
    OFFUstackeddf_i = Ustackeddf_i[Ustackeddf_i['sed']=='OFF']
    plt.figure(figsize=(10, 6))
    sns.lineplot(x='IDlist',y='Values',
                 hue='measures',
                 data=OFFUstackeddf_i)
    plt.xlabel('Participants')
    plt.ylabel('Accuracy')
    plt.ylim(0.5, 1.0)
    #plt.axhline(0.5, color='grey', linestyle='--')
    # Define your new labels  #OLD#new_labels = ['p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p07', 'p08', 'p09', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27', 'p28', 'p29', 'p30', 'p31', 'p32']
    new_labels = []
#     for n in range(1,(len(list(OFFUstackeddf_i['IDlist'].value_counts().keys())))+1):
#         newlbl='p'+str(n).zfill(2)
#         new_labels.append(newlbl)
    # Define your new labels using actual pt IDs
    for n in OFFUstackeddf_i['IDlist'].values:#preserves order
        if n not in new_labels:
            new_labels.append(n)
    # Set the x-axis tick labels
    plt.xticks(ticks=range(len(new_labels)), labels=new_labels, rotation=45)
    plt.title(f'Individual participant Accuracy Scores using {i}')
    plt.legend(bbox_to_anchor=(1, 1), loc='best')
    plt.show()

# (2) Independent Samples t-test, Mann-Whitney U test <-- Independent samples, Wilcoxon signed-rank test <-- Paired-samples
# for i in ['LDA','SVC']:
#     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
    print(f'____{i}____')
    m1=OFFUstackeddf_i[OFFUstackeddf_i['measures']=='ll']
    m2=OFFUstackeddf_i[OFFUstackeddf_i['measures']=='cwpen']
    m1good = m1[m1['outcome']==1]['Values']
    m1bad = m1[m1['outcome']==0]['Values']
    m2good = m2[m2['outcome']==1]['Values']
    m2bad = m2[m2['outcome']==0]['Values']
    # print('ll','good',len(m1good))
    # print('ll','bad',len(m1bad))
    # print('cwpen','good',len(m2good))
    # print('cwpen','bad',len(m2bad))
    m1stat, m1pval = stats.mannwhitneyu(m1good, m1bad)
    m2stat, m2pval = stats.mannwhitneyu(m2good, m2bad)
    if m1pval < 0.05:
        print(f'   - ll: tstat={m1stat}, p = {(m1pval).round(3)}** Significant')
    else:
        print(f'   - ll: tstat={m1stat}, p = {(m1pval).round(3)}')
    if m2pval < 0.05:
        print(f'   - cwpen: tstat={m2stat}, p = {(m2pval).round(3)}** Significant')
    else:
        print(f'   - cwpen: tstat={m2stat}, p = {(m2pval).round(3)}')

        
# (3) Violin Plot    # Replace '1' with 'Favorable' and '0' with 'Unfavorable'
    plt.figure(figsize=(10, 6))
    sns.violinplot(x="measures", y="Values", 
                   hue="outcome", 
                   data=OFFUstackeddf_i, 
                   bw_method=0.3,#{'scott', 'silverman', float}
                   cut=0.3,
                   density_norm='count',#{"area", "count", "width"}
                   #common_norm=False, #When `True`, normalize the density across all violins.
                   #width=1,
                   inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
                   #dodge=True,
                   palette="Set3")
    # for r in range(len(stackedsedoff)):# Adding average line
    #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
    plt.xticks([0,1],['ll','cwpen'])# x-axis labels
    # plt.xlabel('Model Algorithm')
    plt.xlabel('Complexity Measure')
    plt.ylabel('Accuracy')
    plt.ylim(0.3, 1.05)
    plt.axhline(0.5, color='grey', linestyle='--')
    plt.xticks(rotation=45) 
    plt.title(f'Group differences of Outcome with {i}')
    # labels=['ll', 'cwpen']
    # plt.legend (bbox_to_anchor=(1, 1), loc='best')
    # Get the current handles and labels
    handles, labels = plt.gca().get_legend_handles_labels()
    # Define your new labels
    new_labels = ['Favorable' if l == '1' else 'Unfavorable' for l in labels]
    # Set the legend with the new labels
    plt.legend(handles, new_labels, bbox_to_anchor=(1, 1), loc='best')
    plt.show()




#'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'

    

    
    
###### LEGACY #####################################################################################################    
# # # (2) Independent Samples t-test
# # for i in ['LDA','SVC']:
# #     OFFUstackeddf_i = vars()['Ustackeddf_'+i].copy()
    
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='IDlist',y='Values',
#                  hue='measures',
#                  data=OFFUstackeddf_i,
#                  #palette="Set3",
#                 )
#     plt.xlabel('Participants')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.0)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
# #     plt.title(f'Individual participant (sedOFF) Accuracy Scores using {i} ({window})')
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     plt.legend(bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x="measures", y="Values", 
#                    hue="outcome", 
#                    data=OFFstackeddf_i, 
#                    bw_method=0.3,#{'scott', 'silverman', float}
#                    cut=0.3,
#                    density_norm='count',#{"area", "count", "width"}
#                    #common_norm=False, #When `True`, normalize the density across all violins.
#                    #width=1,
#                    inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
#                    #dodge=True,
#                    palette="Set3")
#     # for r in range(len(stackedsedoff)):# Adding average line
#     #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
#     plt.xticks([0,1],['ll','cwpen'])# x-axis labels
#     # plt.xlabel('Model Algorithm')
#     plt.xlabel('Complexity Measure')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.05)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     # labels=['ll', 'cwpen']
#     # plt.legend (bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_346746/3151899210.py in <module>
#      17 #creating Datframe
#      18 for i in ['LDA','SVC']:
# ---> 19     stackeddf_i = vars()['stackeddf_'+i].copy()
#      20     PTvalues = list(outcomedf['ID'].values)
#      21     for g in ['outcome','sed','GCS','GCS_8','participant_id']:
#
# KeyError: 'stackeddf_LDA'

# %% [markdown]
# # ====================== END  ===========================
# # ====================== END  ===========================
# # ====================== END  ===========================
# # ====================== END  ===========================
# # ====================== END  ===========================
# # ====================== END  ===========================
# # ====================== END  ===========================

# %% [markdown]
# # <----Below is OLD, Above is NEW---->

# %%
os.listdir('./')
# Out:
# ['C:\\Users\\user\\Desktop\\ICA-0.csv',
#  'wilcpval_has.npy',
#  'MachineLearning nov 20 2023.ipynb',
#  'C:\\Users\\user\\Desktop\\ICA-best.csv',
#  'Poster-feb6(2024).ipynb',
#  'Subgroup.txt',
#  'Statistics-Copy1.ipynb',
#  'Statistics-Copy3.ipynb',
#  '__pycache__',
#  'withMiss.csv',
#  'Crop, Downsample, & Save New Files (complete).ipynb',
#  'whatever.py',
#  'Also Machine learning-TESTING oct25 .ipynb',
#  'normpval_has.npy',
#  'tables_and_figures',
#  'cut_preproc_rawdata',
#  'Untitled1.ipynb',
#  'Loretta.ipynb',
#  'cutdata',
#  '.ipynb_checkpoints',
#  'LEGACY CODE - Preproc, Complexity, Dataframe, & Statistics .ipynb',
#  'Mansour_Project',
#  'withmiss.txt',
#  'Haloperidol.txt',
#  'delete(and delete untitled2).ipynb',
#  'TimeSeries Feature Extraction-updated (complete).ipynb',
#  'Preproc, Complexity, & Dataframe.ipynb',
#  'results',
#  'LEGACY CODE (made oct 25th).ipynb',
#  'my_dataframe.csv',
#  'boxplots.png',
#  'Untitled2.ipynb',
#  '2nd Windowed-Data Machine Learning.ipynb',
#  'Untitled.ipynb',
#  'TimeSeries Feature Extraction.ipynb',
#  'Windowed-Data Machine Learning (Max) (complete).ipynb',
#  'Statistics-Copy2.ipynb',
#  'Statistics-Copy4.ipynb',
#  'Withoutmiss.csv',
#  'Contour Enhanced Funnel plot.jpg',
#  'subForest.png',
#  'A55.csv',
#  'A1cwpenE16E54.csv',
#  'Also Machine learning (complete).ipynb',
#  'untitlesd -  neruokit2 code .ipynb',
#  'GCS_8_sswoutSEDandHC_table.png',
#  'machine learning.ipynb',
#  'data',
#  'jan20,2024.ipynb',
#  'Cochrane.csv',
#  'withoutmiss.txt',
#  'AutoTKV_MouseMRI-master',
#  'histograms.png',
#  'C:\\Users\\user\\Desktop\\ICA-1.csv',
#  'cut_data',
#  'A3',
#  'Statistics.ipynb']

# %% [markdown]
#    myfig = plt.figure(linewidth=1, figsize=size, dpi=dpi)  #Frameon=False, num="Forest plot by PythonMeta",
#     myfig.set_size_inches(size)
#     plt.title(titletxt)
#     ax = gca()
#     ax.spines['right'].set_color('none')
#     ax.spines['top'].set_color('none')
#
#     ax.spines['left'].set_color('none')
#     ax.xaxis.set_ticks_position('bottom')
#     ax.yaxis.set_ticks_position('left')
#     plt.xticks(fontsize=9)
#     plt.yticks(fontsize=9)
#     xlim=[];y_k=0;subgrp=[]
#     for i in range(len(es_w_ci)):
#         xlim.append(es_w_ci[i][3])
#         xlim.append(es_w_ci[i][4])
#         stdname=es_w_ci[i][0]
#         if stdname[0:5]=="<sub>":  #this line is a subgroup
#             subgrp.append(es_w_ci[i])
#
#     xmin= _x_tran0(min(xlim))
#     xmax= _x_tran0(max(xlim))
#     xmax=max(abs(xmin),abs(xmax))
#     xmin=-xmax
#     plt.xlim(xmin*1.1,xmax*1.1)
#     ylabel=[i[0].replace("<sub>","") for i in es_w_ci[1:]]
#     if no_ttl==True :
#         ax.set_yticks(range(len(es_w_ci)))
#         ymax=len(es_w_ci)
#         ylabel.extend([""])
#         y_k=0
#     else:
#         ax.set_yticks(range(len(es_w_ci)+3))
#         ymax=len(es_w_ci)+3
#         ylabel.extend(["","Overall","",""])
#         y_k=3.5
#     plt.ylim(0, ymax)
#     ylabel.reverse()
#     ax.set_yticklabels(ylabel)
#     ax.set_xticklabels([round(_x_tran1(x),2) for x in ax.get_xticks()])
#     plt.plot([0,0], [0,len(es_w_ci)+3], 'black')

# %%
stats_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-179869ad10fe> in <module>
# ----> 1 stats_df
#
# NameError: name 'stats_df' is not defined

# %%
____LDA____
   - ll: tstat=2754.0, p = 0.101
   - cwpen: tstat=3236.0, p = 0.867
___SVC____
   - ll: tstat=3405.5, p = 0.417
   - cwpen: tstat=3081.5, p = 0.71

# %%
ID = ['p{:02d}'.format(i) for i in range(1, 33)]
print(ID)
# Out:
# ['p01', 'p02', 'p03', 'p04', 'p05', 'p06', 'p07', 'p08', 'p09', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23', 'p24', 'p25', 'p26', 'p27', 'p28', 'p29', 'p30', 'p31', 'p32']

# %%
len(list(OFFUstackeddf_i['participant_id'].value_counts()))
# Out:
# 30

# %%
#Plot
fig, ax = plt.subplots(figsize=(12, 6))
# df_unstacked.plot(kind='bar', ax=ax)
sns.barplot(data=df,ax=ax, x='algo', y='values', hue='meas',
            order=None,
            hue_order=None,
            estimator='mean',
            errorbar=('ci', 95),
            n_boot=1000,
            units=None,
            seed=None,
            orient=None,
            color=None,
            palette='Set2',
            saturation=0.75,
            fill=True,
            hue_norm=None,
            width=0.8,
            dodge='auto',
            gap=0,
            log_scale=None,
            native_scale=False,
            formatter=None,
            legend='auto',
            capsize=0,
            err_kws=None)
plt.title('HC Models and measures for individual particpant performance') #'Measures(9) x Algorithms(7)') # ax.set_title('Measures(9) x Algorithms(7)')
plt.ylabel("Accuracy")
plt.xlabel("Models")
plt.ylim(0.4, 1.0)
legend = plt.legend(loc='upper left',bbox_to_anchor=(1, 1))#,fontsize='x-small', labelspacing=0.05)
legend.set_title('Measures')
new_labels = ['Approx','bubbEn','CWPEn','Detrended','Katz','LL','MSWPEn','Sample','SVD']
for t, l in zip(legend.texts, new_labels): t.set_text(l)
plt.show()

# %%
.set_index(['ID', 'meas', 'algo'])

# %%
OFFUstackeddf_i
# Out:
#                     index          IDlist   Fold measures    Values  outcome  \
# 0            CCTC03_fold1          CCTC03  fold1    cwpen  1.000000        1
# 1            CCTC03_fold2          CCTC03  fold2    cwpen  1.000000        1
# 2            CCTC03_fold3          CCTC03  fold3    cwpen  0.916667        1
# 3            CCTC03_fold4          CCTC03  fold4    cwpen  1.000000        1
# 4            CCTC03_fold5          CCTC03  fold5    cwpen  1.000000        1
# ..                    ...             ...    ...      ...       ...      ...
# 595  NETICU30sedon1_fold1  NETICU30sedon1  fold1       ll  0.583333        0
# 596  NETICU30sedon1_fold2  NETICU30sedon1  fold2       ll  0.833333        0
# 597  NETICU30sedon1_fold3  NETICU30sedon1  fold3       ll  0.583333        0
# 598  NETICU30sedon1_fold4  NETICU30sedon1  fold4       ll  0.500000        0
# 599  NETICU30sedon1_fold5  NETICU30sedon1  fold5       ll  0.500000        0
#
#     sed  GCS   GCS_8 participant_id
# 0    ON    3  under8         CCTC03
# 1    ON    3  under8         CCTC03
# 2    ON    3  under8         CCTC03
# 3    ON    3  under8         CCTC03
# 4    ON    3  under8         CCTC03
# ..   ..  ...     ...            ...
# 595  ON    3  under8       NETICU30
# 596  ON    3  under8       NETICU30
# 597  ON    3  under8       NETICU30
# 598  ON    3  under8       NETICU30
# 599  ON    3  under8       NETICU30
#
# [600 rows x 10 columns]

# %%
OFF = OFFUstackeddf_i.copy()

#######
m1 = OFF[OFF['measures']=='ll']
m2 = OFF[OFF['measures']=='cwpen']
m1good = m1[m1['outcome']==1]['Values']
m1bad = m1[m1['outcome']==0]['Values']
m2good = m2[m2['outcome']==1]['Values']
m2bad = m2[m2['outcome']==0]['Values']
#####

OFF.drop(['index','IDlist'],inplace=True,axis=1)
# OFF.set_index(['Fold','participant_id','measures','outcome'],inplace=True)
# # OFFlbls = OFF[[]]
# OFF=OFF[['Values']]
# OFF = OFF.pivot(columns='Fold',index=['participant_id','measures','outcome'])['Values']#,values='Values')
OFF=OFF[['Values','Fold','participant_id','measures']]
display(OFF)
# OFF = OFF.pivot(columns='Fold',index=['measures','participant_id'],values='Values')#['Values']
OFF = OFF.pivot(columns='Fold',index=['participant_id','measures','outcome'])['Values']#,values='Values')

display(OFF)
# Out:
#        Values   Fold participant_id measures
# 20   0.833333  fold1        MSICU05    cwpen
# 21   1.000000  fold2        MSICU05    cwpen
# 22   1.000000  fold3        MSICU05    cwpen
# 23   1.000000  fold4        MSICU05    cwpen
# 24   0.750000  fold5        MSICU05    cwpen
# ..        ...    ...            ...      ...
# 590  0.916667  fold1       NETICU30       ll
# 591  1.000000  fold2       NETICU30       ll
# 592  1.000000  fold3       NETICU30       ll
# 593  1.000000  fold4       NETICU30       ll
# 594  0.583333  fold5       NETICU30       ll
#
# [320 rows x 4 columns]
#        Values   Fold participant_id measures
# 20   0.833333  fold1        MSICU05    cwpen
# 21   1.000000  fold2        MSICU05    cwpen
# 22   1.000000  fold3        MSICU05    cwpen
# 23   1.000000  fold4        MSICU05    cwpen
# 24   0.750000  fold5        MSICU05    cwpen
# ..        ...    ...            ...      ...
# 590  0.916667  fold1       NETICU30       ll
# 591  1.000000  fold2       NETICU30       ll
# 592  1.000000  fold3       NETICU30       ll
# 593  1.000000  fold4       NETICU30       ll
# 594  0.583333  fold5       NETICU30       ll
#
# [320 rows x 4 columns]

# %%
h=vars()['df_'+'LDA'].copy()
ha=list(h.iloc[6:10,0])
sum(ha)/len(ha)
# Out:
# 0.9791666666666666

# %%
0.916667

# %%
df_grouped2 = vars()['df_'+'LDA'].groupby(np.arange(len(vars()['df_'+i]))//5).mean()# Calculate the average of every 5 rows
df_grouped2
# Out:
#           ll     cwpen
# 0   0.950000  0.933333
# 1   0.983333  1.000000
# 2   0.933333  0.950000
# 3   0.866667  0.866667
# 4   0.916667  0.916667
# 5   1.000000  0.950000
# 6   0.916667  0.716667
# 7   0.966667  0.933333
# 8   0.933333  0.733333
# 9   1.000000  0.816667
# 10  0.933333  0.933333
# 11  1.000000  0.733333
# 12  0.900000  0.733333
# 13  0.900000  0.816667
# 14  0.783333  0.800000
# 15  0.916667  0.900000
# 16  0.833333  0.816667
# 17  0.883333  0.633333
# 18  0.883333  0.866667
# 19  0.850000  0.850000
# 20  0.866667  0.850000
# 21  1.000000  0.866667
# 22  1.000000  0.416667
# 23  0.816667  0.633333
# 24  1.000000  0.583333
# 25  0.950000  0.900000
# 26  0.933333  0.866667
# 27  0.966667  0.883333
# 28  1.000000  0.800000
# 29  0.933333  0.866667
# 30  1.000000  1.000000
# 31  1.000000  0.633333
# 32  0.916667  0.650000
# 33  0.883333  0.800000
# 34  0.866667  0.783333
# 35  0.900000  0.816667
# 36  0.916667  0.850000
# 37  1.000000  0.916667
# 38  0.883333  0.950000
# 39  0.883333  0.833333
# 40  0.983333  0.466667
# 41  1.000000  0.933333
# 42  1.000000  0.783333
# 43  0.983333  0.750000
# 44  0.900000  0.666667
# 45  0.966667  0.966667
# 46  0.966667  0.850000
# 47  1.000000  0.916667
# 48  0.916667  0.883333
# 49  0.883333  0.816667
# 50  0.950000  0.650000
# 51  0.950000  0.933333
# 52  0.866667  0.650000
# 53  0.900000  0.733333
# 54  0.883333  0.883333
# 55  0.850000  0.766667
# 56  0.950000  0.683333
# 57  0.916667  0.783333
# 58  0.916667  0.900000
# 59  0.933333  0.883333

# %%
alldf=[]
for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
    df_grouped = vars()['df_'+i].groupby(np.arange(len(vars()['df_'+i]))//5).mean()# Calculate the average of every 5 rows
    df_grouped.index = HC
    df_grouped=df_grouped.stack()
    df_grouped=pd.DataFrame(df_grouped,columns=[i])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    df_grouped=df_grouped.sort_index(axis=0,level=1)
    alldf.append(df_grouped)
result = pd.concat(alldf, axis=1)

# %%
# Out:
#                 svd1    approx    sample  detrended      katz    ll    mswpen  \
# HC01_fold1  0.916667  0.916667  0.916667   0.916667  0.833333  1.00  1.000000
# HC01_fold2  1.000000  1.000000  1.000000   1.000000  1.000000  1.00  1.000000
# HC01_fold3  1.000000  1.000000  1.000000   1.000000  1.000000  1.00  0.833333
# HC01_fold4  1.000000  1.000000  1.000000   1.000000  1.000000  0.75  0.916667
# HC01_fold5  0.916667  0.916667  0.916667   0.916667  0.916667  0.75  1.000000
# ...              ...       ...       ...        ...       ...   ...       ...
# HC18_fold1  0.333333  0.333333  0.333333   0.416667  0.416667  0.50  0.583333
# HC18_fold2  0.666667  0.750000  0.750000   0.833333  0.500000  0.50  0.416667
# HC18_fold3  0.750000  0.833333  0.916667   0.833333  0.916667  0.50  0.666667
# HC18_fold4  0.833333  0.916667  0.916667   0.750000  0.583333  0.50  0.750000
# HC18_fold5  0.583333  0.500000  0.583333   0.583333  0.416667  0.50  0.583333
#
#               bubben     cwpen
# HC01_fold1  0.500000  0.916667
# HC01_fold2  0.583333  1.000000
# HC01_fold3  1.000000  1.000000
# HC01_fold4  1.000000  1.000000
# HC01_fold5  1.000000  1.000000
# ...              ...       ...
# HC18_fold1  0.583333  0.583333
# HC18_fold2  1.000000  1.000000
# HC18_fold3  1.000000  0.916667
# HC18_fold4  0.833333  0.750000
# HC18_fold5  0.750000  0.500000
#
# [90 rows x 9 columns]

# %%
m1[['Values','measures','outcome']]
# Out:
#                     index          IDlist   Fold measures    Values  outcome  \
# 320         MSICU05_fold1         MSICU05  fold1       ll  0.500000        1
# 321         MSICU05_fold2         MSICU05  fold2       ll  1.000000        1
# 322         MSICU05_fold3         MSICU05  fold3       ll  1.000000        1
# 323         MSICU05_fold4         MSICU05  fold4       ll  0.833333        1
# 324         MSICU05_fold5         MSICU05  fold5       ll  0.750000        1
# ..                    ...             ...    ...      ...       ...      ...
# 590  NETICU30sedoff_fold1  NETICU30sedoff  fold1       ll  0.916667        0
# 591  NETICU30sedoff_fold2  NETICU30sedoff  fold2       ll  1.000000        0
# 592  NETICU30sedoff_fold3  NETICU30sedoff  fold3       ll  1.000000        0
# 593  NETICU30sedoff_fold4  NETICU30sedoff  fold4       ll  1.000000        0
# 594  NETICU30sedoff_fold5  NETICU30sedoff  fold5       ll  0.583333        0
#
#      sed  GCS   GCS_8 participant_id
# 320  OFF    3  under8        MSICU05
# 321  OFF    3  under8        MSICU05
# 322  OFF    3  under8        MSICU05
# 323  OFF    3  under8        MSICU05
# 324  OFF    3  under8        MSICU05
# ..   ...  ...     ...            ...
# 590  OFF    6  under8       NETICU30
# 591  OFF    6  under8       NETICU30
# 592  OFF    6  under8       NETICU30
# 593  OFF    6  under8       NETICU30
# 594  OFF    6  under8       NETICU30
#
# [160 rows x 10 columns]

# %%
stats.mannwhitneyu(m1good, m1bad)
# Out:
# MannwhitneyuResult(statistic=3405.5, pvalue=0.41698557612070686)

# %%
print('\n\n\n\n\n#############################################################\nssHC_ssP - Statistics\n#############################################################')
df = stackresult.copy()
data = stackresult.copy()
stackeddf = stackresult.copy()
#******************************************************************#
# Table 1 - Descriptive statistics
#******************************************************************#
meandf = stackeddf.copy()
means = stackeddf.groupby('meas')['values'].mean()# calculate the mean of the 'value' column for each category
meas=means.sort_values(ascending=False)
means2 = stackeddf.groupby('algo')['values'].mean()
algos=means2.sort_values(ascending=False)
# meandf.columns = [col[0]+col[1] for col in meandf.columns]
meandf['group'] = meandf['meas'].astype(str) + '_' + meandf['algo'].astype(str)
mix = meandf.groupby('group')['values'].mean()
mix2=mix.sort_values(ascending=False)
# print(meas)
# print(algos)
# print (mix2,'\n')
# desc_stats = df.groupby(['meas', 'algo'])['values'].describe()
# display(desc_stats)
import scipy.stats as stats #wont workw/out imports
grouped = df.groupby(['meas', 'algo'])
stats_df = pd.DataFrame()
stats_df['Sample Size'] = grouped['values'].count()
stats_df['Mean (M)'] = grouped['values'].mean()
stats_df['Standard Deviation (SD)'] = grouped['values'].std()
stats_df['Standard Error of the Mean (SEM)'] = grouped['values'].sem()
stats_df['Skewness'] = grouped['values'].apply(lambda x: stats.skew(x))
stats_df['Kurtosis'] = grouped['values'].apply(lambda x: stats.kurtosis(x))
display(stats_df)
# stats_df['Mean (M)'].idxmax()



# pgrm = pg.rm_anova(dv='values', within=['meas', 'algo'], subject='ID', data=data)
# pgrm.round(3)

# %%
alldf=[]
for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
    df_grouped = vars()['df_'+i].groupby(np.arange(len(vars()['df_'+i]))//5).mean()# Calculate the average of every 5 rows
    df_grouped.index = HC
    df_grouped=df_grouped.stack()
    df_grouped=pd.DataFrame(df_grouped,columns=[i])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    df_grouped=df_grouped.sort_index(axis=0,level=1)
    alldf.append(df_grouped)
result = pd.concat(alldf, axis=1)
# display(result)
#1
stackresult = result.copy().stack()
stackresult= pd.DataFrame(stackresult,columns=['values'])
stackresult=stackresult.reset_index()
col=list(stackresult.columns.values)
col[0],col[1],col[2]='ID','meas','algo'
stackresult.columns = col
display(stackresult)
# #2
# avgmeasdf = pd.DataFrame(result.mean(axis=1),columns=['values'])
# avgmeasdf.reset_index(inplace=True, names=['ID','meas'])
# display(avgmeasdf)
# #3
# avgalgodf = stackresult.copy().pivot(columns='meas', index=['ID','algo'], values='values')
# avgalgodf = pd.DataFrame(avgalgodf.mean(axis=1),columns=['values'])
# avgalgodf.reset_index(inplace=True, names=['ID','algo'])
# display(avgalgodf)

######################################################################################
# Descriptive statistics (avg) --------------------------------------#
df = stackresult.copy()
# calculate the mean of the 'value' column for each category
means = stackresult.groupby('meas')['values'].mean()
meas=means.sort_values(ascending=False)
print(meas)
means2 = stackresult.groupby('algo')['values'].mean()
algos=means2.sort_values(ascending=False)
print(algos)
# df.columns = [col[0]+col[1] for col in df.columns]
df['group'] = df['meas'].astype(str) + '_' + df['algo'].astype(str)
mix = df.groupby('group')['values'].mean()
mix2=mix.sort_values(ascending=False)
print (mix2,'\n')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-0b115deda106> in <module>
#       2 for i in ['LR','LDA','KNN','CART','NB','SVM','SVC']:
#       3     df_grouped = vars()['df_'+i].groupby(np.arange(len(vars()['df_'+i]))//5).mean()# Calculate the average of every 5 rows
# ----> 4     df_grouped.index = HC
#       5     df_grouped=df_grouped.stack()
#       6     df_grouped=pd.DataFrame(df_grouped,columns=[i])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6000         try:
#    6001             object.__getattribute__(self, name)
# -> 6002             return object.__setattr__(self, name, value)
#    6003         except AttributeError:
#    6004             pass
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     728         """
#     729         labels = ensure_index(labels)
# --> 730         self._mgr.set_axis(axis, labels)
#     731         self._clear_item_cache()
#     732
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     223     def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     224         # Caller is responsible for ensuring we have an Index object.
# --> 225         self._validate_set_axis(axis, new_labels)
#     226         self.axes[axis] = new_labels
#     227
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      68
#      69         elif new_len != old_len:
# ---> 70             raise ValueError(
#      71                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      72                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 60 elements, new values have 18 elements

# %%
stackresult
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-c0ce992efce8> in <module>
# ----> 1 stackresult
#
# NameError: name 'stackresult' is not defined

# %%
vars()['df_'+'LR']
# Out:
#                 svd1    approx    sample  detrended      katz    ll    mswpen  \
# HC01_fold1  0.916667  0.916667  0.916667   0.916667  0.833333  1.00  1.000000
# HC01_fold2  1.000000  1.000000  1.000000   1.000000  1.000000  1.00  1.000000
# HC01_fold3  1.000000  1.000000  1.000000   1.000000  1.000000  1.00  0.833333
# HC01_fold4  1.000000  1.000000  1.000000   1.000000  1.000000  0.75  0.916667
# HC01_fold5  0.916667  0.916667  0.916667   0.916667  0.916667  0.75  1.000000
# ...              ...       ...       ...        ...       ...   ...       ...
# HC18_fold1  0.333333  0.333333  0.333333   0.416667  0.416667  0.50  0.583333
# HC18_fold2  0.666667  0.750000  0.750000   0.833333  0.500000  0.50  0.416667
# HC18_fold3  0.750000  0.833333  0.916667   0.833333  0.916667  0.50  0.666667
# HC18_fold4  0.833333  0.916667  0.916667   0.750000  0.583333  0.50  0.750000
# HC18_fold5  0.583333  0.500000  0.583333   0.583333  0.416667  0.50  0.583333
#
#               bubben     cwpen
# HC01_fold1  0.500000  0.916667
# HC01_fold2  0.583333  1.000000
# HC01_fold3  1.000000  1.000000
# HC01_fold4  1.000000  1.000000
# HC01_fold5  1.000000  1.000000
# ...              ...       ...
# HC18_fold1  0.583333  0.583333
# HC18_fold2  1.000000  1.000000
# HC18_fold3  1.000000  0.916667
# HC18_fold4  0.833333  0.750000
# HC18_fold5  0.750000  0.500000
#
# [90 rows x 9 columns]

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-0ac921c19f1a> in <module>
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
320/5/2
# Out:
# 32.0

# %%
160/5
# Out:
# 32.0

# %%
32*2
# Out:
# 64

# %%
window
# Out:
# '10secwindows'

# %%
a = vars()['Ustackeddf_'+'SVC'].copy()

# %%
vars()['stackeddf_'+'SVC']
# Out:
#                     index          IDlist   Fold measures    Values
# 0            CCTC03_fold1          CCTC03  fold1    cwpen  1.000000
# 1            CCTC03_fold2          CCTC03  fold2    cwpen  1.000000
# 2            CCTC03_fold3          CCTC03  fold3    cwpen  0.916667
# 3            CCTC03_fold4          CCTC03  fold4    cwpen  1.000000
# 4            CCTC03_fold5          CCTC03  fold5    cwpen  1.000000
# ..                    ...             ...    ...      ...       ...
# 595  NETICU30sedon1_fold1  NETICU30sedon1  fold1       ll  0.583333
# 596  NETICU30sedon1_fold2  NETICU30sedon1  fold2       ll  0.833333
# 597  NETICU30sedon1_fold3  NETICU30sedon1  fold3       ll  0.583333
# 598  NETICU30sedon1_fold4  NETICU30sedon1  fold4       ll  0.500000
# 599  NETICU30sedon1_fold5  NETICU30sedon1  fold5       ll  0.500000
#
# [600 rows x 5 columns]

# %%
# check
for i in odf.index.get_level_values(0):
    x = len(i.split('_'))
    if x != 2:
        print (i)

# %%
# PT
PT = []
for i in odf.index.get_level_values(0):
    x = i.split('_')[0]
    if x not in PT:
        PT.append(x)
len(PT)
# Out:
# 60

# %%
#check
c=1
for (i,s) in zip(IT.index, ST.index):
    ia = i.split('_')[0]
    sa = s.split('_')[0]

    if ia==sa:
        print (c,i,s)
        c+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-23f75c3b6f75> in <module>
#       1 #check
#       2 c=1
# ----> 3 for (i,s) in zip(IT.index, ST.index):
#       4     ia = i.split('_')[0]
#       5     sa = s.split('_')[0]
#
# NameError: name 'IT' is not defined

# %%
vars()['Ustackeddf_'+'LDA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-1e3e945c01a5> in <module>
# ----> 1 vars()['Ustackeddf_'+'LDA']
#
# KeyError: 'Ustackeddf_LDA'

# %%
alldata
# Out:
#            index    ID   Fold    meas  algo    values
# 0     HC01_fold1  HC01  fold1  approx    LR  0.916667
# 1     HC01_fold1  HC01  fold1  approx   LDA  1.000000
# 2     HC01_fold1  HC01  fold1  approx   KNN  0.916667
# 3     HC01_fold1  HC01  fold1  approx  CART  0.916667
# 4     HC01_fold1  HC01  fold1  approx    NB  0.916667
# ...          ...   ...    ...     ...   ...       ...
# 5665  HC18_fold5  HC18  fold5    svd1   KNN  0.666667
# 5666  HC18_fold5  HC18  fold5    svd1  CART  0.750000
# 5667  HC18_fold5  HC18  fold5    svd1    NB  0.583333
# 5668  HC18_fold5  HC18  fold5    svd1   SVM  0.583333
# 5669  HC18_fold5  HC18  fold5    svd1   SVC  0.583333
#
# [5670 rows x 6 columns]

# %%
# %matplotlib inline

# %%
project = 'derivative_project05'


import matplotlib
# matplotlib.use('Qt5Agg')
import matplotlib.pyplot as plt
from matplotlib.pyplot import plot, show
#%matplotlib <the one you want>'osx', 'qt4', 'qt5', 'gtk3', 'wx', 'qt', 'gtk', 'tk'  #nbagg
# matplotlib.use('Qt5Agg')
# %matplotlib
# %matplotlib qt
#%matplotlib tk



import antropy as ant
from antropy import lziv_complexity
import pathlib
import mne
import os
import os.path as op
from mne import viz
from mne import io
from mne.preprocessing import (ICA, create_eog_epochs, create_ecg_epochs, corrmap)
import zipfile
import sys
import pandas as pd
import numpy as np
from IPython.utils import io
import neurokit2 as nk
import scipy
from scipy import stats
import scipy.stats
import seaborn as sns
import pickle
import itertools
from whatever import *
import time

from scipy.stats import zscore
def standardize(lst):
    mean = sum(lst) / len(lst)
    variance = sum([((x - mean) ** 2) for x in lst]) / len(lst)
    std_dev = variance ** 0.5
    return [(x - mean) / std_dev for x in lst]


from pandas import read_csv
from pandas.plotting import scatter_matrix
import math
import random
import csv

import sklearn
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import sklearn.externals 
import joblib
from sklearn.svm import SVC 
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
#from sklearn.model_selection import groupKFold, GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
    # from sklearn.metrics import accuracy_score
    # from sklearn.metrics import confusion_matrix
    # from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from IPython.display import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_346746/3765522382.py in <module>
#      14
#      15
# ---> 16 import antropy as ant
#      17 from antropy import lziv_complexity
#      18 import pathlib
#
# ModuleNotFoundError: No module named 'antropy'

# %%
df = pd.DataFrame({
    'ID': ['ID1', 'ID1', 'ID1', 'ID1', 'ID2', 'ID2', 'ID2', 'ID2'],
    'meas': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B'],
    'algo': ['X', 'Y', 'X', 'Y', 'X', 'Y', 'X', 'Y'],
    'values': [1, 2, 3, 4, 5, 6, 7, 8]
}).set_index(['ID', 'meas', 'algo'])


for this df, how do i plot the means?






############################################################## EXAMPLE 2
# Assuming df is your DataFrame with a MultiIndex
df = pd.DataFrame({
    'ID': ['ID1', 'ID1', 'ID1', 'ID1', 'ID2', 'ID2', 'ID2', 'ID2'],
    'Category': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B'],
    'Subcategory': ['X', 'Y', 'X', 'Y', 'X', 'Y', 'X', 'Y'],
    'Value': [1, 2, 3, 4, 5, 6, 7, 8]
}).set_index(['ID', 'Category', 'Subcategory'])
display(df)

# Calculate the mean
df_means = df.groupby(['ID', 'Category']).mean()

# Reset the index to use 'ID' and 'Category' in the plot
df_means = df_means.reset_index()

# Create a bar plot
plt.figure(figsize=(10,6))
for category in df_means['Category'].unique():
    plt.bar(df_means[df_means['Category'] == category]['ID'], 
            df_means[df_means['Category'] == category]['Value'], 
            label=category)

plt.xlabel('ID')
plt.ylabel('Mean Value')
plt.legend()
plt.show()

############################################################## EXAMPLE 1
# Assuming df is your DataFrame with a MultiIndex
df = pd.DataFrame({
    'ID': ['ID1', 'ID1', 'ID1', 'ID1', 'ID2', 'ID2', 'ID2', 'ID2'],
    'Category': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'B'],
    'Subcategory': ['X', 'Y', 'X', 'Y', 'X', 'Y', 'X', 'Y'],
    'Value': [1, 2, 3, 4, 5, 6, 7, 8]
}).set_index(['ID', 'Category', 'Subcategory'])

# Unstack the DataFrame
df_unstacked = df.unstack(level=['Category', 'Subcategory'])

# Create a new figure and a set of subplots with a specific size (width, height)
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar plot of the unstacked DataFrame
df_unstacked.plot(kind='bar', ax=ax)

# Add a title to the plot
ax.set_title('My Plot Title')

# Move the legend to the right of the plot
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %%
#OLDdata - SAME RESULTS IN LOVE CONFERENCE POSTER

#used for outcome scores 

#MAX's way (5) - PT (IT vs ST)                                (not main)
# Window Method
#####################################################################################################################    
##                                                                                                                 ##
##                 LOADING DATAFRAME AND RESHAPING IT                                                              ## 
##################################################################################################################### 
import string
measures = ['svd1','svd2','approx','sample','detrended','katz','ll','mswpen','bubben','cwpen']
EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30','CCTC03','CCTC04','CCTC05','MSICU05','MSICU07','MSICU09','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
Echan=['E2','E3','E4','E5','E6','E7','E9','E10','E11','E12','E13','E15','E16','E18','E19','E20','E22','E23','E24','E26','E27','E28','E29','E30','E31','E33','E34','E35','E36','E37','E39','E40','E41','E42','E45','E46','E47','E50','E51','E52','E53','E54','E55','E58','E59','E60','E61','E62','E65','E66','E67','E70','E71','E72','E75','E76','E77','E78','E79','E80','E83','E84','E85','E86','E87','E90','E91','E92','E93','E96','E97','E98','E101','E102','E103','E104','E105','E106','E108','E109','E110','E111','E112','E115','E116','E117','E118','E122','E123','E124','Vertex Reference']
PT=['CCTC03','CCTC03part2','CCTC04','CCTC05','MSICU05','MSICU05part2','MSICU07','MSICU09','MSICU09part2','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','NETICU01sedoff','NETICU01sedon1','NETICU02sedoff','NETICU02sedon1','NETICU03sedoff','NETICU03sedon1','NETICU04sedoff','NETICU04sedon1','NETICU05sedoff','NETICU05sedon1','NETICU06sedoff','NETICU06sedon1','NETICU08sedoff','NETICU08sedon2','NETICU11sedoff','NETICU11sedon1','NETICU13sedoff','NETICU13sedon1','NETICU15sedoff','NETICU15sedon1','NETICU17sedoff','NETICU17sedon1','NETICU18sedon1','NETICU19sedoff','NETICU19sedon1','NETICU20sedon1','NETICU22sedoff','NETICU22sedon1','NETICU24sedoff','NETICU24sedon1','NETICU25sedon1','NETICU27sedoff','NETICU27sedon1','NETICU28sedoff','NETICU28sedon1','NETICU29sedoff','NETICU29sedon1','NETICU30sedoff','NETICU30sedon1']

for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        vars()[m+'_'+window]= pd.read_csv(f'./results/save/{window}/{m}/{m}_{window}.csv')
        vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
        vars()[m+'_'+window].set_index('ID', inplace=True)
        #-----------------------------------------------------------------------------------------#
        df = vars()[m+'_'+window].copy()
        ssfnames = [f for f in df.index if 'HC05_IT1st' not in f]
        #print(f'\n{m}_{window}\n{len(df.index)}-{len(ssfnames)} = {len(df.index)-len(ssfnames)}')
        #-----------------------------------------------------------------------------------------#
        df = df.loc[ssfnames] #using ssfnames
        IDlist=[]
        ID2list = []
        chaa=[]
        T2list=[]
        for f in df.index:
            a,b,c = f.split('_')
            ID = a+'_'+b
            IDlist.append(ID)
            T2=(f.split('_'))[1]
            T2list.append(T2)
            for el in Echan:
                if el == (f.split('_'))[2]:
                    chaa.append(el)
            for E in EVERYONE:
                if E in f:
                    ID2list.append(E)
        df.insert(0,'el',chaa)
        df.insert(0, 'IDlist', IDlist)
        #
        columns=df.columns.tolist()
        columns[2:] = [i for i in range(10,40)]
        df.columns = columns   

        values = [a+b for a in string.ascii_lowercase for b in string.ascii_lowercase]
        mappings = dict(zip(Echan, values))
        mappings2 = dict(zip(values, Echan))
        df['sortby'] = df['el'].map(mappings)
        df.drop('el',inplace=True,axis=1)
        df=df.pivot(index='IDlist',columns = 'sortby')
        df = df.swaplevel(i=-2, j=-1, axis=1)
        df = df.sort_index(axis=1)
        #df.columns = [col[0]+str(col[1]) for col in hi.columns]
        hi=df.swaplevel(i=-2,j=-1,axis=1)
        hi=hi.transpose()
        hi.reset_index(level='sortby', inplace=True)
        hi['el'] = hi['sortby'].map(mappings2)
        hi.drop('sortby',inplace=True,axis=1)
        hi.set_index('el', append=True, inplace=True)
        hi.reset_index(level=0, inplace=True)
        timekeys= [int(i) for i in range(10,40)]
        timevalues = [str(i) for i in range(30)]
        mappings3 = dict(zip(timekeys,timevalues))
        # hi['level_0']=hi['level_0'].astype(str)
        hi['timepoints']=hi['level_0'].map(mappings3)
        hi.drop('level_0',inplace=True,axis=1)
        hi.set_index('timepoints', append=True, inplace=True)
        hi = hi.transpose()
        hi.columns = ['_'.join(col) for col in hi.columns]# <--THis seperates the timepoints from electrode-channels in the columns section
        #hi = hi.add_suffix(f'_{m}')
        vars()[m+'_'+window+'_reorg'] = hi
    # concatinate all dataframes into one (should be 6006000)
    # add labels ()
#####################################################################################################################    
##                                                                                                                 ##
##                    ADDING LABELS                                                                                ## 
#####################################################################################################################    
EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30','CCTC03','CCTC04','CCTC05','MSICU05','MSICU07','MSICU09','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
Uoutcomedic={'NETICU01':'1','NETICU02':'0','NETICU03':'0','NETICU04':'1','NETICU05':'1','NETICU06':'0','NETICU08':'1','NETICU11':'1','NETICU13':'0','NETICU15':'0','NETICU17':'1','NETICU18':'1','NETICU19':'1','NETICU20':'1','NETICU22':'0','NETICU24':'0','NETICU25':'0','NETICU27':'1','NETICU28':'0','NETICU29':'1','NETICU30':'0','CCTC03':'1','CCTC04':'1','CCTC05':'1','MSICU05':'1','MSICU07':'0','MSICU09':'0','MSICU10':'0','MSICU14':'0','MSICU15':'0','MSICU16':'0','MSICU18':'0','MSICU19':'1','MSICU21':'0','MSICU22':'1','MSICU26':'1','MSICU28':'1','MSICU29':'1','MSICU30':'1','HC01':'1','HC02':'1','HC03':'1','HC04':'1','HC05':'1','HC06':'1','HC07':'1','HC08':'1','HC09':'1','HC10':'1','HC11':'1','HC12':'1','HC13':'1','HC14':'1','HC15':'1','HC16':'1','HC17':'1','HC18':'1'}
studydic={'NETICU01':'NETICU','NETICU02':'NETICU','NETICU03':'NETICU','NETICU04':'NETICU','NETICU05':'NETICU','NETICU06':'NETICU','NETICU08':'NETICU','NETICU11':'NETICU','NETICU13':'NETICU','NETICU15':'NETICU','NETICU17':'NETICU','NETICU18':'NETICU','NETICU19':'NETICU','NETICU20':'NETICU','NETICU22':'NETICU','NETICU24':'NETICU','NETICU25':'NETICU','NETICU27':'NETICU','NETICU28':'NETICU','NETICU29':'NETICU','NETICU30':'NETICU','CCTC03':'MIMIC','CCTC04':'MIMIC','CCTC05':'MIMIC','MSICU05':'MIMIC','MSICU07':'MIMIC','MSICU09':'MIMIC','MSICU10':'MIMIC','MSICU14':'MIMIC','MSICU15':'MIMIC','MSICU16':'MIMIC','MSICU18':'MIMIC','MSICU19':'MIMIC','MSICU21':'MIMIC','MSICU22':'MIMIC','MSICU26':'MIMIC','MSICU28':'MIMIC','MSICU29':'MIMIC','MSICU30':'MIMIC','HC01':'control','HC02':'control','HC03':'control','HC04':'control','HC05':'control','HC06':'control','HC07':'control','HC08':'control','HC09':'control','HC10':'control','HC11':'control','HC12':'control','HC13':'control','HC14':'control','HC15':'control','HC16':'control','HC17':'control','HC18':'control'}
outcomesNA = {'NETICU01':'1','NETICU02':'0','NETICU03':'0','NETICU04':'NA','NETICU05':'NA','NETICU06':'0','NETICU08':'1','NETICU11':'1','NETICU13':'0','NETICU15':'NA','NETICU17':'1','NETICU18':'1','NETICU19':'1','NETICU20':'1','NETICU22':'0','NETICU24':'0','NETICU25':'0','NETICU27':'1','NETICU28':'0','NETICU29':'NA','NETICU30':'0','CCTC03':'NA','CCTC04':'1','CCTC05':'NA','MSICU05':'1','MSICU07':'0','MSICU09':'0','MSICU10':'0','MSICU14':'0','MSICU15':'0','MSICU16':'0','MSICU18':'0','MSICU19':'NA','MSICU21':'0','MSICU22':'1','MSICU26':'1','MSICU28':'NA','MSICU29':'NA','MSICU30':'NA','HC01':'1','HC02':'1','HC03':'1','HC04':'1','HC05':'1','HC06':'1','HC07':'1','HC08':'1','HC09':'1','HC10':'1','HC11':'1','HC12':'1','HC13':'1','HC14':'1','HC15':'1','HC16':'1','HC17':'1','HC18':'1'}
F','MSICU15_IT':'ON','MSICU15_RS':'ON','MSICU15_ST':'ON','MSICU16_IT':'OFF','MSICU16_RS':'OFF','MSICU16_ST':'OFF','MSICU18_IT':'OFF','MSICU18_RS':'OFF','MSICU18_ST':'OFF','MSICU19_IT':'OFF','MSICU19_RS':'OFF','MSICU19_ST':'OFF','MSICU21_IT':'OFF','MSICU21_RS':'OFF','MSICU21_ST':'OFF','MSICU22_IT':'OFF','MSICU22_RS':'OFF','MSICU22_ST':'OFF','MSICU26_IT':'ON','MSICU26_RS':'ON','MSICU26_ST':'ON','MSICU28_IT':'OFF','MSICU28_RS':'OFF','MSICU28_ST':'OFF','MSICU29_IT':'OFF','MSICU29_RS':'OFF','MSICU29_ST':'OFF','MSICU30_IT':'OFF','MSICU30_RS':'OFF','MSICU30_ST':'OFF','NETICU01sedoff_IT':'ON','NETICU01sedoff_RS':'ON','NETICU01sedoff_ST':'ON','NETICU01sedon1_IT':'ON','NETICU01sedon1_RS':'ON','NETICU01sedon1_ST':'ON','NETICU02sedoff_IT':'OFF','NETICU02sedoff_RS':'OFF','NETICU02sedoff_ST':'OFF','NETICU02sedon1_IT':'ON','NETICU02sedon1_RS':'ON','NETICU02sedon1_ST':'ON','NETICU03sedoff_IT':'OFF','NETICU03sedoff_RS':'OFF','NETICU03sedoff_ST':'OFF','NETICU03sedon1_IT':'ON','NETICU03sedon1_RS':'ON','NETICU03sedon1_ST':'ON','NETICU04sedoff_IT':'OFF','NETICU04sedoff_RS':'OFF','NETICU04sedoff_ST':'OFF','NETICU04sedon1_IT':'ON','NETICU04sedon1_RS':'ON','NETICU04sedon1_ST':'ON','NETICU05sedoff_IT':'OFF','NETICU05sedoff_RS':'OFF','NETICU05sedoff_ST':'OFF','NETICU05sedon1_IT':'ON','NETICU05sedon1_RS':'ON','NETICU05sedon1_ST':'ON','NETICU06sedoff_IT':'OFF','NETICU06sedoff_RS':'OFF','NETICU06sedoff_ST':'OFF','NETICU06sedon1_IT':'ON','NETICU06sedon1_RS':'ON','NETICU06sedon1_ST':'ON','NETICU08sedoff_IT':'OFF','NETICU08sedoff_ST':'OFF','NETICU08sedon2_IT':'ON','NETICU08sedon2_RS':'ON','NETICU08sedon2_ST':'ON','NETICU11sedoff_IT':'OFF','NETICU11sedoff_RS':'OFF','NETICU11sedoff_ST':'OFF','NETICU11sedon1_IT':'ON','NETICU11sedon1_RS':'ON','NETICU11sedon1_ST':'ON','NETICU13sedoff_IT':'OFF','NETICU13sedoff_RS':'OFF','NETICU13sedoff_ST':'OFF','NETICU13sedon1_IT':'ON','NETICU13sedon1_RS':'ON','NETICU13sedon1_ST':'ON','NETICU15sedoff_IT':'OFF','NETICU15sedoff_RS':'OFF','NETICU15sedoff_ST':'OFF','NETICU15sedon1_IT':'ON','NETICU15sedon1_RS':'ON','NETICU15sedon1_ST':'ON','NETICU17sedoff_IT':'OFF','NETICU17sedoff_RS':'OFF','NETICU17sedoff_ST':'OFF','NETICU17sedon1_IT':'ON','NETICU17sedon1_RS':'ON','NETIC
window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
#     for m in measures:
#         print (f'\n{m}_{window}_reorg')
#         df = vars()[m+'_'+window+'_reorg'].copy()
window ='10secwindows'
for m in measures:
    df = vars()[m+'_'+window+'_reorg'].copy()
    #----------------------------------------#
    IDlist=[]
    ID2list=[]
    T2list=[]
    Tlist=[]
    Scan=[]
    sedlist = []
    sedlist2=[]
    GCS = []
    GCS_6 = []
    GCS_7 = []
    GCS_8 = []
    GCS_9 = []
    studylist=[]
    hplist = []
    Uoutcomelist=[]
    outcomeslist=[]
    guessoutcomeslist=[]
    for f in df.index:
        ID = ((f.split('_')[0]).split('part2')[0]).split('sed')[0]
        IDlist.append(ID)
        ID2 = f.split('_')[0]
        ID2list.append(ID2)
        T2=(f.split('_'))[1]
        T2list.append(T2)
        #HC or PT
        if 'HC' in f:
            hp='hc'
        if 'HC' not in f:
            hp='pt'
        hplist.append(hp)
        #RS/ST/IT
        for Task in ['RS','ST','IT']:
            if Task in f:
                T = Task
                Tlist.append(T)
        #part2/sedon/sedoff/-
        if 'part2' in f:
            S='part2'
        elif 'sed' in f:
            S='sed'+((f.split('sed')[1]).split('_')[0])
        else:
            S='-'
        Scan.append(S)
        #outcomes and studylist
        for E in EVERYONE:
            if E in f:
                NMc = studydic[E]
                UO=Uoutcomedic[E]
                O= outcomesNA[E]
                O2= outcomesGuess[E]
                outcomeslist.append(O)
                guessoutcomeslist.append(O2)
                Uoutcomelist.append(UO)
                studylist.append(NMc)
        #GCS and sed
        sedlist.append(seddic[f])
        sedlist2.append(seddic2[f])
        GCS.append(GCSdic[f])
        GCS_6.append(GCS_6dic[f])
        GCS_7.append(GCS_7dic[f])
        GCS_8.append(GCS_8dic[f])
        GCS_9.append(GCS_9dic[f])
        #print (f'{f} {hp} {ID} {ID2} {T2} {T} {S} {O} {O2} {UO} {NMc}')
    # Add Labels
    df.insert(0,'sed',sedlist)
    df.insert(0,'GCS_9',GCS_9)
    df.insert(0,'GCS_8',GCS_8)
    df.insert(0,'GCS_7',GCS_7)
    df.insert(0,'GCS_6',GCS_6)
    df.insert(0,'GCS',GCS)
    df.insert(0, 'Uoutcome', Uoutcomelist)
    df.insert(0, 'outcome', outcomeslist)
    df.insert(0, 'GuessOutcome', guessoutcomeslist)
    df.insert(0, 'participant_id', IDlist)
    df.insert(0, 'ID2list', ID2list)
    df.insert(0, 'Task2', T2list)
    df.insert(0, 'Task', Tlist)
    df.insert(0, 'Scan', Scan)
    df.insert(0,'sed2',sedlist2)
    df.insert(0, 'study', studylist)
    df.insert(0, 'HP', hplist)
    #----------------------------------------#
    
tdf=df.copy()
tdf = tdf[(tdf['Task']=='IT') | (tdf['Task']=='ST')]
tdf = tdf[tdf['HP'] != 'hc']
tdf = tdf[tdf['Task'] != 'ST']
tdf.insert(0,'ID',PT)
tdf = tdf.loc[:,'ID':'sed']
tdf.reset_index(drop=True,inplace=True)
# tdf
a = tdf['ID']
b = tdf['Uoutcome']
c = tdf['sed']
d = tdf['GCS']
e = tdf['GCS_8']
f = tdf['participant_id']
# outcomedf
outcomedf = pd.DataFrame(data=a, columns=['ID'])
outcomedf.insert(loc=1, column='outcome', value=b)
outcomedf.insert(loc=2, column='sed', value=c)
outcomedf.insert(loc=3, column='GCS', value=d)
outcomedf.insert(loc=4, column='GCS_8', value=e)
outcomedf.insert(loc=5, column='participant_id', value=f)
outcomedf['outcome'] = pd.to_numeric(outcomedf['outcome'], errors='coerce')
outcomedf['GCS'] = pd.to_numeric(outcomedf['GCS'], errors='coerce')
# cont.
dummy=[]
dummy2=[]
dummy3=[]
for i in outcomedf['ID']:
    dummy.append(0.5)
    dummy2.append(0.4)
    dummy3.append(0.3)
outcomedf.insert(6,'dummy',dummy)
outcomedf.insert(7,'dummy2',dummy2)
outcomedf.insert(8,'dummy3',dummy3)





print (outcomedf.dtypes)
outcomedf







#jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- 

#MAX's way (5) - PT (IT vs ST)                        ( MAIN )
#####################################################################################################################    
##                                                                                                                 ##
##                 LOADING DATAFRAME AND RESHAPING IT                                                              ## 
##################################################################################################################### 
import string
measures = ['ll','cwpen']#['svd1','svd2','approx','sample','detrended','katz','ll','mswpen','bubben','cwpen']
EVERYONE = ['NETICU01','NETICU02','NETICU03','NETICU04','NETICU05','NETICU06','NETICU08','NETICU11','NETICU13','NETICU15','NETICU17','NETICU18','NETICU19','NETICU20','NETICU22','NETICU24','NETICU25','NETICU27','NETICU28','NETICU29','NETICU30','CCTC03','CCTC04','CCTC05','MSICU05','MSICU07','MSICU09','MSICU10','MSICU14','MSICU15','MSICU16','MSICU18','MSICU19','MSICU21','MSICU22','MSICU26','MSICU28','MSICU29','MSICU30','HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']
Echan=['E2','E3','E4','E5','E6','E7','E9','E10','E11','E12','E13','E15','E16','E18','E19','E20','E22','E23','E24','E26','E27','E28','E29','E30','E31','E33','E34','E35','E36','E37','E39','E40','E41','E42','E45','E46','E47','E50','E51','E52','E53','E54','E55','E58','E59','E60','E61','E62','E65','E66','E67','E70','E71','E72','E75','E76','E77','E78','E79','E80','E83','E84','E85','E86','E87','E90','E91','E92','E93','E96','E97','E98','E101','E102','E103','E104','E105','E106','E108','E109','E110','E111','E112','E115','E116','E117','E118','E122','E123','E124','Vertex Reference']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']

for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        vars()[m+'_'+window]= pd.read_csv(f'./results/save/{window}/{m}/{m}_{window}.csv')
        vars()[m+'_'+window].rename(columns={vars()[m+'_'+window].columns[0]: 'ID'}, inplace=True)
        vars()[m+'_'+window].set_index('ID', inplace=True)
        #------------------------------------------------------------------------------------------###
        df = vars()[m+'_'+window].copy()#                                                          ###
        ssfnames = [f for f in df.index if 'HC05_IT1st' not in f]#                                 ###
        #print(f'\n{m}_{window}\n{len(df.index)}-{len(ssfnames)} = {len(df.index)-len(ssfnames)}') ###
        #---------------------------------------######################################################
        df = df.loc[ssfnames] #using ssfnames   ###
        odf = df.copy()#old datafrmae           ###
        #odf = odf[odf.index.str.contains('HC')]###
        ###########################################
        IDlist=[]
        chaa=[]
        for f in odf.index:
            a,b,c = f.split('_')
            if 'HC05_IT2nd' in f:
                ID = a+'_'+b[:-3]
            else:
                ID = a+'_'+b
            IDlist.append(ID)
            for el in Echan:
                if el == c:
                    chaa.append(el)
        odf.insert(0,'el',chaa)
        odf.insert(0, 'IDlist', IDlist)
        # did i need to rename colunmns to range(10,40) for sorting????or is it already sorted?
        columns=odf.columns.tolist()
        columns[2:] = [str(i) for i in range(10,40)]
        odf.columns = columns  
        values = [a+b for a in string.ascii_lowercase for b in string.ascii_lowercase]
        mappings = dict(zip(Echan, values))
        mappings2 = dict(zip(values, Echan))
        odf['sortby'] = odf['el'].map(mappings)
        odf.drop('el',inplace=True,axis=1)
        odf=odf.pivot(index='sortby',columns = 'IDlist',values=[str(i) for i in range(10,40)])
        odf = odf.swaplevel(i=-2, j=-1, axis=1)
        odf = odf.sort_index(axis=1)
        odf.reset_index(level='sortby', inplace=True)
        odf['el'] = odf['sortby'].map(mappings2)
        odf.set_index('el', append=False, inplace=True)
        with io.capture_output() as captured:
            odf.drop('sortby',inplace=True,axis=1)
        odf=odf.transpose()
        odf.reset_index(level=1, inplace=True) # Moving timpoints/index-level_1 from index to column to (1) rename them & (2) to create Task-List from index-level_0 for Task Column
        timekeys= [str(i) for i in range(10,40)]#    (1)
        timevalues = [str(i) for i in range(30)]
        mappings3 = dict(zip(timekeys,timevalues))
        odf['windows']=odf['level_1'].map(mappings3)
        Tlist=[]#                                    (2)
        for f in odf.index:
            for Task in ['RS','ST','IT']:
                if Task in f:
                    T = Task
                    Tlist.append(T)
        odf.insert(0, 'Task', Tlist)
        odf.set_index('windows', append=True, inplace=True)
        # odf = odf.add_suffix(f'_{m}')
        odf.drop('level_1',inplace=True,axis=1)
        odf = odf[(odf['Task']=='IT') | (odf['Task']=='ST')]
        odf = odf[~odf.index.get_level_values('IDlist').str.contains('HC')]

        # Final Dataframe ______________________________________________________________________ #
        vars()['PT_'+m+'_'+window]=odf.copy()
        #Individual Dataframes
        PT = []
        for i in odf.index.get_level_values(0):
            x = i.split('_')[0]
            if x not in PT:
                PT.append(x)
        print ('len(PT)=',len(PT))
        for P in PT:
            vars()[P+'df_'+m+'_'+window]=odf.loc[([f'{P}_IT',f'{P}_ST']),:]##EXAMPLES-->>>##odf.loc[(['HC01_IT','HC01_ST'],'0'),:] ##odf.xs(key=('0'), level='windows').loc[['HC01_IT', 'HC01_ST']] ##odf.xs(('HC01_ST'), axis=0, level='IDlist')
            vars()[P+'df_'+m+'_'+window].index = ['_'.join(i) for i in vars()[P+'df_'+m+'_'+window].index] #combine both levels of index into one (i.e., 'HC01_IT_0')
            
            
#####################################################################################################################    
##                                                                                                                 ##
##                    MACHINE LEARNING                                                                             ## 
#####################################################################################################################    
from sklearn.model_selection import StratifiedKFold
import random
random.seed(42)
models = []
#models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
#models.append(('KNN', KNeighborsClassifier()))
#models.append(('CART', DecisionTreeClassifier(random_state=42)))
#models.append(('NB', GaussianNB()))
#models.append(('SVM', SVC(gamma='auto',kernel='rbf',random_state=42))) 
models.append(('SVC', SVC(gamma='scale', kernel='poly',random_state=42))) 

measures=['ll','cwpen']
HC=['HC01','HC02','HC03','HC04','HC05','HC06','HC07','HC08','HC09','HC10','HC11','HC12','HC13','HC14','HC15','HC16','HC17','HC18']

accuracy_dict = {m: {model[0]: [] for model in models} for m in measures} #[X]
accuracy_dict2 = {m: {model[0]: [] for model in models} for m in measures} #[X] <---main
accuracy_dict3 = {m: {model[0]: [] for model in models} for m in measures}
for window in ['10secwindows']:#['10secwindows','5secwindows','2secwindows']:
    for m in measures:
        print (f'\n=========================================\nPT_{m}_{window} {odf.shape}\n=========================================')#print (f'\n=========================================I\nssHC_{m}_{window} {odf.shape}        I\n=========================================I')
        df = vars()['PT_'+m+'_'+window].copy()
        allHC_LR_results = []
        #Individual Dataframes
        for p in PT:
            hdf = vars()[p+'df_'+m+'_'+window].copy()
            print (f'{p}df_{m}_{window} {hdf.shape}')# <------------------------')
            X = hdf.drop(columns='Task') #data
            y = hdf['Task'] #labels
            # Accuracy lists (for p)
            LDA_results= []
            SVC_results= []   
            # Stratified 5-Folds cross-validator
            skf = StratifiedKFold(n_splits=5)
            count = 1
            for train_index, test_index in skf.split(X, y):
                #print (f'Split_{count}:\nTrain_index: {train_index}\nTest_index: {test_index}')
                X_train= X.iloc[train_index]
                X_test= X.iloc[test_index]
                y_train= y.iloc[train_index]
                y_test= y.iloc[test_index]
                count += 1
                # Machine Learning Algorithms
                for name, model in models:
                    model.fit(X_train, y_train)
                    predictions = model.predict(X_test)
                    score = accuracy_score(y_test,predictions)
                    #print ('  -',name,score.round(2))
                    vars()[name+'_results'].append(score)
            accuracy_dict3[m]['LDA'].append(LDA_results)
            accuracy_dict3[m]['SVC'].append(SVC_results)
            
            
            #print('_________________________________________________________________')
            #print(f'Model Accuracy Scores and Average across 5 folds:')
            avg_models = []
            stdev_models = []
            for i in ['LDA','SVC']:
                average = round(((sum(vars()[i+'_results']))/len(vars()[i+'_results'])),2)
                stdev = round(np.std(vars()[i+'_results']),2)
                avg_models.append(average)
                stdev_models.append(stdev)
                #print (f"  > {i}: avg={average} stdev={stdev} {i}_results={[r.round(2) for r in vars()[i+'_results']]}") #print (f"  {i}: avg={average} stdev={stdev}")
                accuracy_dict2[m][i].append(vars()[i + '_results'])#[X]
                accuracy_dict[m][i].extend(vars()[i + '_results'])#[X]
            #print('_________________________________________________________________')
            # After calculating the accuracy scores for each model, store them in a dictionary
            etcresults = {'LDA': LDA_results,'SVC': SVC_results}

#####################################################################################################################    
##                                                                                                                 ##
##                    plotting accuracy scores                                                                     ## 
#####################################################################################################################    
#(1)
for m in measures:
    data_to_plot = {name: accuracy_dict2[m][name] for name, _ in models}
    for i in ['LDA','SVC']:
        vars()[i+m+'scores']=data_to_plot[i]
for i in ['LDA','SVC']:
    vars()[i+'_']=[]
    for m in measures:
        scores_m =vars()[i+m+'scores'].copy()
        vars()[i+'_'].append(scores_m)  # list of scores (not a df)  
#(2)***
for i in ['LDA','SVC']:
    print (i)
    hi = vars()[i+'_'].copy()
    hidf=pd.DataFrame(hi)
    hidf=hidf.transpose()
    hidf.columns = measures
    hidf.index=PT
    fdf=pd.DataFrame(index=dfindex)
    for m in measures:
        Mlist=[]
        for p in PT:
            #print(p,': ',hidf.loc[p,m])
            Mlist.extend(hidf.loc[p,m])
        fdf.insert(loc=len(fdf.columns),column=f'{m}',value=Mlist)    
    vars()['df_'+i]=fdf.copy()
    #(5)
    df = vars()['df_'+i].copy()
    #df.reset_index(inplace=True)
    IDlist=[]
    Foldlist=[]
    for o in df.index:
        a,b = o.split('_')
        IDlist.append(a)
        Foldlist.append(b)
    df.insert(0,'Fold',Foldlist)
    df.insert(0,'IDlist',IDlist)
    #(6) stacked df
    newdf=df.reset_index()
    newdf.set_index(keys='index',
        drop= True,
        append= False,
        inplace=True)
    # newdf.drop(labels='index',axis=1,inplace=True)
    newdf.set_index(keys='IDlist',
        drop= True,
        append= True,
        inplace=True)
    newdf.set_index(keys='Fold',
        drop= True,
        append= True,
        inplace=True)
    # newdf.drop(labels='Fold',axis=1,inplace=True)
    stacked=newdf.stack()
    stackeddf=pd.DataFrame(stacked,columns=['Values'])
    # stackeddf=stackeddf.swaplevel(i=-2, j=-1, axis=0)
    stackeddf=stackeddf.sort_index(axis=0,level=3)
    stackeddf=stackeddf.reset_index(level=3)
    col=list(stackeddf.columns.values)
    col[0]='measures'
    stackeddf.columns = col
    stackeddf=stackeddf.reset_index()
    vars()['stackeddf_'+i]=stackeddf.copy()
    

#     #(7) plot
#     plt.figure(figsize=(10, 6))
# #     sns.catplot(x="IDlist", 
# #                 y="Values", 
# #                 hue="measures", 
# #                 data=stackeddf,
# #                 kind='point',
# #                 height=6,  
# #                 aspect=3)
#     sns.lineplot(x='IDlist',y='Values',
#                  hue='measures',
#                  data=stackeddf,
# #                  palette="Set3"
#                 )
#     plt.xlabel('Participants')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.0)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Individual participant Accuracy Scores using {i} ({window})')
#     plt.legend(bbox_to_anchor=(1, 1), loc='best')
#     plt.show()

# [X] AllPT Scores (linegraph)
# [X] AllPT Outcome 1 vs 0 - Violinplot 
# [X] AllPT Outcome 1 vs 0  - t-test

# [X] SedOFFonly Scores (linegraph)
# [X] SedOFFonly Outcome 1 vs 0 - Violinplot 
# [X] SedOFFonly Outcome 1 vs 0  - t-test


#jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- jan20,2024 --------- 


# COMPLETE # COMPLETE # COMPLETE
##############################################################################
### PT: good vs bad outcome (violin plots) (using IT vs ST Acuracy scores) ###
##############################################################################
#creating Datframe
for i in ['LDA','SVC']:
    stackeddf_i = vars()['stackeddf_'+i].copy()
    PTvalues = list(outcomedf['ID'].values)
    for g in ['outcome','sed','GCS','GCS_8','participant_id']:
        values = list(outcomedf[g].values)
        mapping = dict(zip(PTvalues, values))
        stackeddf_i[g] = stackeddf_i['IDlist'].map(mapping)
    vars()['Ustackeddf_'+i]=stackeddf_i.copy()


################
### All PTs  ### 
################  
# # (1) Individual Participant Scores
# for i in ['LDA','SVC']:
#     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='IDlist',y='Values',
#                  hue='measures',
#                  data=Ustackeddf_i)
#     plt.xlabel('Participants')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.4, 1.0)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Individual participant Accuracy Scores using {i} ({window})')
#     plt.legend(bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# # (2) Independent Samples t-test, Mann-Whitney U test <-- Independent samples, Wilcoxon signed-rank test <-- Paired-samples
# # for i in ['LDA','SVC']:
# #     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
#     print(f'____{i}____')
#     m1=Ustackeddf_i[Ustackeddf_i['measures']=='ll']
#     m2=Ustackeddf_i[Ustackeddf_i['measures']=='cwpen']
#     m1good = m1[m1['outcome']==1]['Values']
#     m1bad = m1[m1['outcome']==0]['Values']
#     m2good = m2[m2['outcome']==1]['Values']
#     m2bad = m2[m2['outcome']==0]['Values']
#     # print('ll','good',len(m1good))
#     # print('ll','bad',len(m1bad))
#     # print('cwpen','good',len(m2good))
#     # print('cwpen','bad',len(m2bad))
#     m1stat, m1pval = stats.mannwhitneyu(m1good, m1bad)
#     m2stat, m2pval = stats.mannwhitneyu(m2good, m2bad)
#     if m1pval < 0.05:
#         print(f'   - ll: p = {(m1pval).round(3)}** Significant')
#     else:
#         print(f'   - ll: p = {(m1pval).round(3)}')
#     if m2pval < 0.05:
#         print(f'   - cwpen: p = {(m2pval).round(3)}** Significant')
#     else:
#         print(f'   - cwpen: p = {(m2pval).round(3)}')
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x="measures", y="Values", 
#                    hue="outcome", 
#                    data=Ustackeddf_i, 
#                    bw_method=0.3,#{'scott', 'silverman', float}
#                    cut=0.3,
#                    density_norm='count',#{"area", "count", "width"}
#                    #common_norm=False, #When `True`, normalize the density across all violins.
#                    #width=1,
#                    inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
#                    #dodge=True,
#                    palette="Set3")
#     # for r in range(len(stackedsedoff)):# Adding average line
#     #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
#     plt.xticks([0,1],['ll','cwpen'])# x-axis labels
#     # plt.xlabel('Model Algorithm')
#     plt.xlabel('Complexity Measure')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.05)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     # labels=['ll', 'cwpen']
#     # plt.legend (bbox_to_anchor=(1, 1), loc='best')
#     plt.show()


# #########################
# ### PTw/out sedation  ###
# #########################    (       MSICU05 & MSICU09 have repeats (inclduded)      )
# (1) Individual Participant Scores 
for i in ['LDA','SVC']:
    Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
    OFFUstackeddf_i = Ustackeddf_i[Ustackeddf_i['sed']=='OFF']
    plt.figure(figsize=(10, 6))
    sns.lineplot(x='IDlist',y='Values',
                 hue='measures',
                 data=OFFUstackeddf_i)
    plt.xlabel('Participants')
    plt.ylabel('Accuracy')
    plt.ylim(0.4, 1.0)
    plt.axhline(0.5, color='grey', linestyle='--')
    plt.xticks(rotation=45) 
    plt.title(f'Individual participant Accuracy Scores using {i} ({window})')
    plt.legend(bbox_to_anchor=(1, 1), loc='best')
    plt.show()

# (2) Independent Samples t-test, Mann-Whitney U test <-- Independent samples, Wilcoxon signed-rank test <-- Paired-samples
# for i in ['LDA','SVC']:
#     Ustackeddf_i = vars()['Ustackeddf_'+i].copy()
    print(f'____{i}____')
    m1=OFFUstackeddf_i[OFFUstackeddf_i['measures']=='ll']
    m2=OFFUstackeddf_i[OFFUstackeddf_i['measures']=='cwpen']
    m1good = m1[m1['outcome']==1]['Values']
    m1bad = m1[m1['outcome']==0]['Values']
    m2good = m2[m2['outcome']==1]['Values']
    m2bad = m2[m2['outcome']==0]['Values']
    # print('ll','good',len(m1good))
    # print('ll','bad',len(m1bad))
    # print('cwpen','good',len(m2good))
    # print('cwpen','bad',len(m2bad))
    m1stat, m1pval = stats.mannwhitneyu(m1good, m1bad)
    m2stat, m2pval = stats.mannwhitneyu(m2good, m2bad)
    if m1pval < 0.05:
        print(f'   - ll: p = {(m1pval).round(3)}** Significant')
    else:
        print(f'   - ll: p = {(m1pval).round(3)}')
    if m2pval < 0.05:
        print(f'   - cwpen: p = {(m2pval).round(3)}** Significant')
    else:
        print(f'   - cwpen: p = {(m2pval).round(3)}')

# (3) Violin Plot    
    plt.figure(figsize=(10, 6))
    sns.violinplot(x="measures", y="Values", 
                   hue="outcome", 
                   data=OFFUstackeddf_i, 
                   bw_method=0.3,#{'scott', 'silverman', float}
                   cut=0.3,
                   density_norm='count',#{"area", "count", "width"}
                   #common_norm=False, #When `True`, normalize the density across all violins.
                   #width=1,
                   inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
                   #dodge=True,
                   palette="Set3")
    # for r in range(len(stackedsedoff)):# Adding average line
    #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
    plt.xticks([0,1],['ll','cwpen'])# x-axis labels
    # plt.xlabel('Model Algorithm')
    plt.xlabel('Complexity Measure')
    plt.ylabel('Accuracy')
    plt.ylim(0.3, 1.05)
    plt.axhline(0.5, color='grey', linestyle='--')
    plt.xticks(rotation=45) 
    plt.title(f'Group differences of Outcome with {i} ({window})')
    # labels=['ll', 'cwpen']
    # plt.legend (bbox_to_anchor=(1, 1), loc='best')
    plt.show()

    
    

    
    
###### LEGACY #####################################################################################################    
# # # (2) Independent Samples t-test
# # for i in ['LDA','SVC']:
# #     OFFUstackeddf_i = vars()['Ustackeddf_'+i].copy()
    
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='IDlist',y='Values',
#                  hue='measures',
#                  data=OFFUstackeddf_i,
#                  #palette="Set3",
#                 )
#     plt.xlabel('Participants')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.0)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
# #     plt.title(f'Individual participant (sedOFF) Accuracy Scores using {i} ({window})')
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     plt.legend(bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# # (3) Violin Plot    
#     plt.figure(figsize=(10, 6))
#     sns.violinplot(x="measures", y="Values", 
#                    hue="outcome", 
#                    data=OFFstackeddf_i, 
#                    bw_method=0.3,#{'scott', 'silverman', float}
#                    cut=0.3,
#                    density_norm='count',#{"area", "count", "width"}
#                    #common_norm=False, #When `True`, normalize the density across all violins.
#                    #width=1,
#                    inner='box', #{"box", "quartile", "point", "stick", None}, optional Representation of the datapoints in the violin interior. If ``box``, draw a miniature boxplot. If ``quartiles``, draw the quartiles of the distribution.  If ``point`` or ``stick``, show each underlying datapoint. Using ``None`` will draw unadorned violins
#                    #dodge=True,
#                    palette="Set3")
#     # for r in range(len(stackedsedoff)):# Adding average line
#     #     ax.hlines(y=np.mean(stackedsedoff[r]), xmin=i-0.4, xmax=i+0.4, color='blue', linestyle='--')
#     plt.xticks([0,1],['ll','cwpen'])# x-axis labels
#     # plt.xlabel('Model Algorithm')
#     plt.xlabel('Complexity Measure')
#     plt.ylabel('Accuracy')
#     plt.ylim(0.3, 1.05)
#     plt.axhline(0.5, color='grey', linestyle='--')
#     plt.xticks(rotation=45) 
#     plt.title(f'Group differences of Outcome with {i} ({window})')
#     # labels=['ll', 'cwpen']
#     # plt.legend (bbox_to_anchor=(1, 1), loc='best')
#     plt.show()
# Out:
# ID                 object
# outcome             int64
# sed                object
# GCS                 int64
# GCS_8              object
# participant_id     object
# dummy             float64
# dummy2            float64
# dummy3            float64
# dtype: object
# len(PT)= 60
# len(PT)= 60
#
# =========================================
# PT_ll_10secwindows (3600, 92)
# =========================================
# CCTC03df_ll_10secwindows (60, 92)
# CCTC03part2df_ll_10secwindows (60, 92)
# CCTC04df_ll_10secwindows (60, 92)
# CCTC05df_ll_10secwindows (60, 92)
# MSICU05df_ll_10secwindows (60, 92)
# MSICU05part2df_ll_10secwindows (60, 92)
# MSICU07df_ll_10secwindows (60, 92)
# MSICU09df_ll_10secwindows (60, 92)
# MSICU09part2df_ll_10secwindows (60, 92)
# MSICU10df_ll_10secwindows (60, 92)
# MSICU14df_ll_10secwindows (60, 92)
# MSICU15df_ll_10secwindows (60, 92)
# MSICU16df_ll_10secwindows (60, 92)
# MSICU18df_ll_10secwindows (60, 92)
# MSICU19df_ll_10secwindows (60, 92)
# MSICU21df_ll_10secwindows (60, 92)
# MSICU22df_ll_10secwindows (60, 92)
# MSICU26df_ll_10secwindows (60, 92)
# MSICU28df_ll_10secwindows (60, 92)
# MSICU29df_ll_10secwindows (60, 92)
# MSICU30df_ll_10secwindows (60, 92)
# NETICU01sedoffdf_ll_10secwindows (60, 92)
# NETICU01sedon1df_ll_10secwindows (60, 92)
# NETICU02sedoffdf_ll_10secwindows (60, 92)
# NETICU02sedon1df_ll_10secwindows (60, 92)
# NETICU03sedoffdf_ll_10secwindows (60, 92)
# NETICU03sedon1df_ll_10secwindows (60, 92)
# NETICU04sedoffdf_ll_10secwindows (60, 92)
# NETICU04sedon1df_ll_10secwindows (60, 92)
# NETICU05sedoffdf_ll_10secwindows (60, 92)
# NETICU05sedon1df_ll_10secwindows (60, 92)
# NETICU06sedoffdf_ll_10secwindows (60, 92)
# NETICU06sedon1df_ll_10secwindows (60, 92)
# NETICU08sedoffdf_ll_10secwindows (60, 92)
# NETICU08sedon2df_ll_10secwindows (60, 92)
# NETICU11sedoffdf_ll_10secwindows (60, 92)
# NETICU11sedon1df_ll_10secwindows (60, 92)
# NETICU13sedoffdf_ll_10secwindows (60, 92)
# NETICU13sedon1df_ll_10secwindows (60, 92)
# NETICU15sedoffdf_ll_10secwindows (60, 92)
# NETICU15sedon1df_ll_10secwindows (60, 92)
# NETICU17sedoffdf_ll_10secwindows (60, 92)
# NETICU17sedon1df_ll_10secwindows (60, 92)
# NETICU18sedon1df_ll_10secwindows (60, 92)
# NETICU19sedoffdf_ll_10secwindows (60, 92)
# NETICU19sedon1df_ll_10secwindows (60, 92)
# NETICU20sedon1df_ll_10secwindows (60, 92)
# NETICU22sedoffdf_ll_10secwindows (60, 92)
# NETICU22sedon1df_ll_10secwindows (60, 92)
# NETICU24sedoffdf_ll_10secwindows (60, 92)
# NETICU24sedon1df_ll_10secwindows (60, 92)
# NETICU25sedon1df_ll_10secwindows (60, 92)
# NETICU27sedoffdf_ll_10secwindows (60, 92)
# NETICU27sedon1df_ll_10secwindows (60, 92)
# NETICU28sedoffdf_ll_10secwindows (60, 92)
# NETICU28sedon1df_ll_10secwindows (60, 92)
# NETICU29sedoffdf_ll_10secwindows (60, 92)
# NETICU29sedon1df_ll_10secwindows (60, 92)
# NETICU30sedoffdf_ll_10secwindows (60, 92)
# NETICU30sedon1df_ll_10secwindows (60, 92)
#
# =========================================
# PT_cwpen_10secwindows (3600, 92)
# =========================================
# CCTC03df_cwpen_10secwindows (60, 92)
# CCTC03part2df_cwpen_10secwindows (60, 92)
# CCTC04df_cwpen_10secwindows (60, 92)
# CCTC05df_cwpen_10secwindows (60, 92)
# MSICU05df_cwpen_10secwindows (60, 92)
# MSICU05part2df_cwpen_10secwindows (60, 92)
# MSICU07df_cwpen_10secwindows (60, 92)
# MSICU09df_cwpen_10secwindows (60, 92)
# MSICU09part2df_cwpen_10secwindows (60, 92)
# MSICU10df_cwpen_10secwindows (60, 92)
# MSICU14df_cwpen_10secwindows (60, 92)
# MSICU15df_cwpen_10secwindows (60, 92)
# MSICU16df_cwpen_10secwindows (60, 92)
# MSICU18df_cwpen_10secwindows (60, 92)
# MSICU19df_cwpen_10secwindows (60, 92)
# MSICU21df_cwpen_10secwindows (60, 92)
# MSICU22df_cwpen_10secwindows (60, 92)
# MSICU26df_cwpen_10secwindows (60, 92)
# MSICU28df_cwpen_10secwindows (60, 92)
# MSICU29df_cwpen_10secwindows (60, 92)
# MSICU30df_cwpen_10secwindows (60, 92)
# NETICU01sedoffdf_cwpen_10secwindows (60, 92)
# NETICU01sedon1df_cwpen_10secwindows (60, 92)
# NETICU02sedoffdf_cwpen_10secwindows (60, 92)
# NETICU02sedon1df_cwpen_10secwindows (60, 92)
# NETICU03sedoffdf_cwpen_10secwindows (60, 92)
# NETICU03sedon1df_cwpen_10secwindows (60, 92)
# NETICU04sedoffdf_cwpen_10secwindows (60, 92)
# NETICU04sedon1df_cwpen_10secwindows (60, 92)
# NETICU05sedoffdf_cwpen_10secwindows (60, 92)
# NETICU05sedon1df_cwpen_10secwindows (60, 92)
# NETICU06sedoffdf_cwpen_10secwindows (60, 92)
# NETICU06sedon1df_cwpen_10secwindows (60, 92)
# NETICU08sedoffdf_cwpen_10secwindows (60, 92)
# NETICU08sedon2df_cwpen_10secwindows (60, 92)
# NETICU11sedoffdf_cwpen_10secwindows (60, 92)
# NETICU11sedon1df_cwpen_10secwindows (60, 92)
# NETICU13sedoffdf_cwpen_10secwindows (60, 92)
# NETICU13sedon1df_cwpen_10secwindows (60, 92)
# NETICU15sedoffdf_cwpen_10secwindows (60, 92)
# NETICU15sedon1df_cwpen_10secwindows (60, 92)
# NETICU17sedoffdf_cwpen_10secwindows (60, 92)
# NETICU17sedon1df_cwpen_10secwindows (60, 92)
# NETICU18sedon1df_cwpen_10secwindows (60, 92)
# NETICU19sedoffdf_cwpen_10secwindows (60, 92)
# NETICU19sedon1df_cwpen_10secwindows (60, 92)
# NETICU20sedon1df_cwpen_10secwindows (60, 92)
# NETICU22sedoffdf_cwpen_10secwindows (60, 92)
# NETICU22sedon1df_cwpen_10secwindows (60, 92)
# NETICU24sedoffdf_cwpen_10secwindows (60, 92)
# NETICU24sedon1df_cwpen_10secwindows (60, 92)
# NETICU25sedon1df_cwpen_10secwindows (60, 92)
# NETICU27sedoffdf_cwpen_10secwindows (60, 92)
# NETICU27sedon1df_cwpen_10secwindows (60, 92)
# NETICU28sedoffdf_cwpen_10secwindows (60, 92)
# NETICU28sedon1df_cwpen_10secwindows (60, 92)
# NETICU29sedoffdf_cwpen_10secwindows (60, 92)
# NETICU29sedon1df_cwpen_10secwindows (60, 92)
# NETICU30sedoffdf_cwpen_10secwindows (60, 92)
# NETICU30sedon1df_cwpen_10secwindows (60, 92)
# LDA
# SVC
# ____LDA____
#    - ll: p = 0.101
#    - cwpen: p = 0.867
# ____SVC____
#    - ll: p = 0.417
#    - cwpen: p = 0.71
